# %%
import json
import logging
from re import sub
from multiprocessing import cpu_count

import numpy as np
import pandas as pd

import gensim.downloader as api
from gensim.utils import simple_preprocess
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.models import WordEmbeddingSimilarityIndex
from gensim.similarities import SparseTermSimilarityMatrix
from gensim.similarities import SoftCosineSimilarity

from ast import literal_eval

# %%
import nltk

# Import and download stopwords from NLTK.
nltk.download('stopwords')  # Download stopwords list.
stopwords = set(nltk.corpus.stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Shivaani
# [nltk_data]     K\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(doc):
    # Tokenize, clean up input document string
#     doc = sub(r'<img[^<>]+(>|$)', " image_token ", doc)
#     doc = sub(r'<[^<>]+(>|$)', " ", doc)
#     doc = sub(r'\[img_assist[^]]*?\]', " ", doc)
#     doc = sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', " url_token ", doc)
    return [token for token in simple_preprocess(doc, min_len=0, max_len=float("inf")) if token not in stopwords]

# %%
import csv 

# Load test data
df = pd.read_csv('whitespce_based.csv')

titles = [item for item in df['company_name']]
#documents = [literal_eval(item) for item in df['tokenized text']]
desc = [item for item in df['cleaned_description']]
tokens = [preprocess(item) for item in df['cleaned_description']]
print(f'{len(tokens)} documents')
# Out:
# 2996 documents

# %%
if 'glove' not in locals():  # only load if not already in memory
    glove = api.load("glove-wiki-gigaword-50")
    
similarity_index = WordEmbeddingSimilarityIndex(glove)

# %%
corpus = []
query_string = tokens[0]
documents = tokens[1:]

corpus = [document for document in documents]
query = query_string

# %%
documents
# Out:
# [['venture', 'capital'],
#  ['live',
#   'data',
#   'platform',
#   'ingest',
#   'process',
#   'respond',
#   'operate',
#   'live',
#   'data',
#   'system',
#   'scale'],
#  ['terawatts', 'clean', 'energy', 'software', 'company'],
#  ['diq',
#   'make',
#   'beyond',
#   'easy',
#   'recruiter',
#   'edit',
#   'format',
#   'get',
#   'realtime',
#   'feedback',
#   'candidate',
#   'submittals'],
#  ['p', 'touch', 'medium', 'mobile', 'application', 'development', 'startup'],
#  ['di',
#   'data',
#   'analytics',
#   'platform',
#   'architecture',
#   'engineering',
#   'construction',
#   'industry'],
#  ['abya',
#   'developer',
#   'provider',
#   'technological',
#   'component',
#   'creation',
#   'graphic',
#   'virtualization',
#   'cloudgaming',
#   'solution'],
#  ['accelitude',
#   'llc',
#   'company',
#   'deal',
#   'digital',
#   'cloud',
#   'service',
#   'solution'],
#  ['accelor',
#   'provides',
#   'hardware',
#   'solution',
#   'intended',
#   'blockchain',
#   'ai',
#   'business'],
#  ['accounting',
#   'panel',
#   'cloudbased',
#   'accounting',
#   'tool',
#   'designed',
#   'help',
#   'entrepreneur',
#   'control',
#   'business',
#   'finance',
#   'anytime',
#   'anywhere'],
#  ['ace',
#   'iot',
#   'solution',
#   'offer',
#   'secure',
#   'managed',
#   'platform',
#   'collecting',
#   'aggregating',
#   'visualizing',
#   'facility',
#   'operation'],
#  ['acsibi',
#   'studio',
#   'mobile',
#   'game',
#   'development',
#   'company',
#   'located',
#   'acton'],
#  ['actio',
#   'modular',
#   'based',
#   'software',
#   'service',
#   'analytics',
#   'platform',
#   'designed',
#   'restaurant',
#   'service'],
#  ['activeconnect',
#   'work',
#   'type',
#   'device',
#   'operating',
#   'system',
#   'every',
#   'transaction',
#   'including',
#   'io',
#   'android',
#   'window',
#   'mac'],
#  ['lightweight',
#   'project',
#   'portfolio',
#   'management',
#   'ppm',
#   'software',
#   'new',
#   'pmos'],
#  ['deliver',
#   'insight',
#   'help',
#   'asset',
#   'manager',
#   'plan',
#   'react',
#   'extreme',
#   'weather',
#   'event'],
#  ['ad',
#   'fontes',
#   'medium',
#   'public',
#   'benefit',
#   'corporation',
#   'rate',
#   'news',
#   'founded',
#   'vanessa',
#   'otero',
#   'creator',
#   'medium',
#   'bias',
#   'chart'],
#  ['ad',
#   'genius',
#   'provides',
#   'marketing',
#   'solution',
#   'based',
#   'exceptional',
#   'technical',
#   'talent',
#   'creative',
#   'power'],
#  ['automated', 'microfulfillment', 'center', 'drone', 'rover', 'delivery'],
#  ['agamon',
#   'aipowered',
#   'healthcare',
#   'platform',
#   'convert',
#   'clinical',
#   'text',
#   'structured',
#   'data'],
#  ['agape',
#   'platform',
#   'scientifically',
#   'designed',
#   'strengthen',
#   'romantic',
#   'relationship',
#   'personalized',
#   'daily',
#   'question'],
#  ['agave', 'free', 'hiring', 'platform', 'offer', 'job', 'posting'],
#  ['agita',
#   'lab',
#   'develops',
#   'privacyenhanced',
#   'computing',
#   'architecture',
#   'facilitate',
#   'creation',
#   'new',
#   'data',
#   'market'],
#  ['artificial', 'intelligence'],
#  ['agoric',
#   'provides',
#   'framework',
#   'programming',
#   'smart',
#   'contract',
#   'securely',
#   'ease',
#   'beyond',
#   'anything',
#   'available',
#   'today'],
#  ['search', 'faster', 'close', 'end'],
#  ['akava',
#   'specializes',
#   'software',
#   'engineering',
#   'devops',
#   'design',
#   'product',
#   'project',
#   'management',
#   'service',
#   'client'],
#  ['akita',
#   'build',
#   'dynamic',
#   'application',
#   'programming',
#   'interface',
#   'model',
#   'software',
#   'programming',
#   'integration'],
#  ['aligned',
#   'carbon',
#   'supplier',
#   'aligned',
#   'carbon',
#   'nanotube',
#   'enabling',
#   'x',
#   'improvement',
#   'computing'],
#  ['allelica',
#   'genomics',
#   'software',
#   'company',
#   'driving',
#   'transition',
#   'polygenic',
#   'risk',
#   'score',
#   'genomic',
#   'research',
#   'clinical',
#   'application'],
#  ['ampcontrolio',
#   'aibased',
#   'optimization',
#   'software',
#   'electric',
#   'vehicle',
#   'charging',
#   'build',
#   'charging',
#   'station',
#   'low',
#   'cost'],
#  ['anna',
#   'first',
#   'aipowered',
#   'selfcheckout',
#   'solution',
#   'designed',
#   'meet',
#   'specific',
#   'need',
#   'cannabis',
#   'retailer'],
#  ['annotex',
#   'pdf',
#   'annotator',
#   'software',
#   'allows',
#   'user',
#   'write',
#   'math',
#   'equation',
#   'chemical',
#   'structure'],
#  ['u',
#   'intelligence',
#   'agencygrade',
#   'forensic',
#   'analysis',
#   'critical',
#   'intel'],
#  ['ansatz',
#   'ai',
#   'develops',
#   'machine',
#   'learning',
#   'tool',
#   'design',
#   'optimization',
#   'chemical',
#   'material',
#   'technology'],
#  ['anylog',
#   'building',
#   'next',
#   'generation',
#   'decentralized',
#   'iot',
#   'platform',
#   'data',
#   'owner',
#   'capture',
#   'full',
#   'value',
#   'data',
#   'blockchain'],
#  ['set', 'tool', 'help', 'conquer', 'google', 'bing', 'facebook', 'ad'],
#  ['apaly',
#   'health',
#   'enables',
#   'employer',
#   'provider',
#   'direct',
#   'contract',
#   'scale'],
#  ['apex',
#   'app',
#   'enables',
#   'user',
#   'select',
#   'driver',
#   'choice',
#   'favorite',
#   'uberlyft',
#   'driver',
#   'advance',
#   'rideshare',
#   'delivery'],
#  ['apiphani',
#   'offer',
#   'strategic',
#   'operational',
#   'consulting',
#   'database',
#   'management',
#   'managed',
#   'service'],
#  ['apoll',
#   'open',
#   'platform',
#   'surfacing',
#   'need',
#   'education',
#   'institution',
#   'collaborating',
#   'reaching',
#   'consensus',
#   'establish',
#   'standard'],
#  ['app',
#   'growth',
#   'expert',
#   'help',
#   'mobile',
#   'app',
#   'publisher',
#   'developer',
#   'discover',
#   'increase',
#   'app',
#   'performance',
#   'sustainability'],
#  ['apprentiscope', 'computer', 'software', 'company'],
#  ['appyhour', 'smart', 'marketing', 'business', 'management', 'platform'],
#  ['apres',
#   'analytics',
#   'platform',
#   'built',
#   'scale',
#   'explain',
#   'ai',
#   'decision',
#   'making'],
#  ['aquifer',
#   'motion',
#   'saas',
#   'platform',
#   'enables',
#   'creator',
#   'team',
#   'create',
#   'studiolevel',
#   'animated',
#   'video',
#   'without',
#   'studio'],
#  ['ara',
#   'sound',
#   'lab',
#   'develops',
#   'audio',
#   'technology',
#   'various',
#   'application'],
#  ['arbilex',
#   'leverage',
#   'predictive',
#   'analytics',
#   'empower',
#   'lawyer',
#   'litigation',
#   'funders',
#   'make',
#   'datadriven',
#   'decision',
#   'crossborder',
#   'dispute'],
#  ['arch',
#   'digitally',
#   'manages',
#   'private',
#   'investment',
#   'operation',
#   'investor',
#   'investment',
#   'advisor'],
#  ['archeads',
#   'real',
#   'estate',
#   'property',
#   'management',
#   'firm',
#   'dealing',
#   'floorplans',
#   'service'],
#  ['ari',
#   'coach',
#   'mission',
#   'make',
#   'healthy',
#   'eating',
#   'simple',
#   'accessible',
#   'everyone'],
#  ['ari',
#   'recruiting',
#   'intelligent',
#   'recruiting',
#   'software',
#   'track',
#   'athlete',
#   'provides',
#   'feedback',
#   'enhanced',
#   'decision',
#   'making'],
#  ['aria',
#   'intel',
#   'operates',
#   'digital',
#   'medium',
#   'platform',
#   'tech',
#   'medium',
#   'gaming'],
#  ['armarius',
#   'software',
#   'provides',
#   'robotic',
#   'process',
#   'automation',
#   'data',
#   'loss',
#   'prevention',
#   'enhanced',
#   'capability',
#   'website',
#   'filtering',
#   'service'],
#  ['arpio',
#   'protects',
#   'eliminates',
#   'downtime',
#   'aws',
#   'application',
#   'making',
#   'easy',
#   'recover',
#   'outage',
#   'minute'],
#  ['delivering',
#   'peace',
#   'mind',
#   'replacing',
#   'traditional',
#   'networking',
#   'software',
#   'defined',
#   'security',
#   'solution'],
#  ['asizer', 'app', 'measure', 'body'],
#  ['assembler',
#   'lab',
#   'detroit',
#   'startup',
#   'studio',
#   'working',
#   'local',
#   'talent',
#   'build',
#   'venturescale',
#   'business'],
#  ['astellent',
#   'consulting',
#   'company',
#   'improves',
#   'software',
#   'designed',
#   'developed',
#   'delivered',
#   'help',
#   'organization',
#   'achieve'],
#  ['ethereum', 'smart', 'contract', 'wallet', 'dapp', 'browser'],
#  ['development',
#   'stage',
#   'startup',
#   'enabling',
#   'next',
#   'generation',
#   'precision',
#   'medicine',
#   'fusing',
#   'biochip',
#   'ai',
#   'technology'],
#  ['atelier', 'home', 'design', 'mobile', 'app'],
#  ['atlerts',
#   'stateoftheart',
#   'communication',
#   'platform',
#   'manages',
#   'incident',
#   'report',
#   'injury',
#   'documentation',
#   'athletic',
#   'department'],
#  ['atom',
#   'computing',
#   'build',
#   'truly',
#   'scalable',
#   'quantum',
#   'computer',
#   'individual',
#   'atom'],
#  ['atomata',
#   'provides',
#   'iot',
#   'hardware',
#   'software',
#   'solution',
#   'grower',
#   'scale'],
#  ['atticus',
#   'simplifying',
#   'probate',
#   'estate',
#   'settlement',
#   'individual',
#   'institutional',
#   'advisor'],
#  ['attila',
#   'ai',
#   'platform',
#   'offering',
#   'solution',
#   'retail',
#   'financial',
#   'institution',
#   'automate',
#   'sale',
#   'financial',
#   'service'],
#  ['attunely',
#   'produce',
#   'machine',
#   'learning',
#   'model',
#   'debt',
#   'collection',
#   'decreasing',
#   'waste',
#   'improving',
#   'recovery',
#   'yield'],
#  ['leading',
#   'free',
#   'opensource',
#   'io',
#   'mac',
#   'based',
#   'audiomusic',
#   'developer',
#   'tool',
#   'proudly',
#   'power',
#   'million',
#   'app',
#   'installs'],
#  ['augmented',
#   'radar',
#   'imaging',
#   'delivers',
#   'radar',
#   'advanced',
#   'machine',
#   'learning',
#   'algorithm',
#   'power',
#   'autonomous',
#   'vehicle',
#   'warehouse',
#   'robot'],
#  ['augmented',
#   'review',
#   'help',
#   'review',
#   'validate',
#   'design',
#   'realtime',
#   'augmented',
#   'reality'],
#  ['aura',
#   'salonware',
#   'provider',
#   'salon',
#   'management',
#   'software',
#   'elevate',
#   'salon',
#   'experience'],
#  ['aurelius',
#   'data',
#   'provide',
#   'patient',
#   'consumer',
#   'healthcare',
#   'provider',
#   'best',
#   'cannabinoid',
#   'treatment'],
#  ['autopartsz', 'best', 'auto', 'part', 'finder', 'app'],
#  ['autymate',
#   'develops',
#   'software',
#   'solution',
#   'like',
#   'accounting',
#   'hr',
#   'healthcare',
#   'automation',
#   'apps',
#   'help',
#   'reduce',
#   'time'],
#  ['auxon',
#   'software',
#   'company',
#   'enables',
#   'ai',
#   'system',
#   'engineer',
#   'build',
#   'safe',
#   'resilient',
#   'system'],
#  ['auxxit',
#   'nextgeneration',
#   'digital',
#   'marketplace',
#   'platform',
#   'leverage',
#   'engaging',
#   'experience',
#   'realtime',
#   'group',
#   'chat',
#   'live',
#   'streaming'],
#  ['avail',
#   'boutique',
#   'firm',
#   'manages',
#   'telecom',
#   'technology',
#   'asset',
#   'delivers',
#   'expense',
#   'success'],
#  ['avansa',
#   'computer',
#   'software',
#   'company',
#   'specializes',
#   'blockchain',
#   'cryptocurrency',
#   'software'],
#  ['avlaki',
#   'information',
#   'technology',
#   'firm',
#   'specializes',
#   'advisory',
#   'consulting',
#   'solution',
#   'technology',
#   'business'],
#  ['avo', 'insight', 'augmented', 'reality', 'based', 'marketing', 'company'],
#  ['awecom', 'aipowered', 'streaming', 'optimizer'],
#  ['axel',
#   'technology',
#   'software',
#   'developer',
#   'investing',
#   'technology',
#   'infrastructure'],
#  ['axellero',
#   'software',
#   'development',
#   'company',
#   'provides',
#   'product',
#   'design',
#   'web',
#   'development',
#   'io',
#   'machine',
#   'learning',
#   'service'],
#  ['axia',
#   'cpq',
#   'salesforce',
#   'partner',
#   'help',
#   'achieving',
#   'greatest',
#   'possible',
#   'return',
#   'salesforce',
#   'investment'],
#  ['babsorbed',
#   'technology',
#   'enables',
#   'business',
#   'create',
#   'immersive',
#   'experience',
#   'interacting',
#   'physical',
#   'object',
#   'world'],
#  ['badge',
#   'u',
#   'company',
#   'develops',
#   'biometric',
#   'cryptocurrency',
#   'based',
#   'unique',
#   'identification',
#   'software',
#   'store',
#   'one',
#   'cryptographic',
#   'key'],
#  ['bankd',
#   'app',
#   'make',
#   'tracking',
#   'managing',
#   'digital',
#   'asset',
#   'effortless'],
#  ['mobile',
#   'solution',
#   'increasing',
#   'efficiency',
#   'sale',
#   'bar',
#   'club',
#   'nightlife',
#   'venue'],
#  ['barshift', 'firstever', 'point', 'promotion', 'software'],
#  ['bartrack',
#   'offer',
#   'digital',
#   'platform',
#   'tracking',
#   'inventory',
#   'optimizing',
#   'quality',
#   'draft',
#   'product'],
#  ['base',
#   'firstever',
#   'software',
#   'platform',
#   'built',
#   'specifically',
#   'executive',
#   'assistant'],
#  ['baseai',
#   'offer',
#   'business',
#   'process',
#   'automation',
#   'software',
#   'several',
#   'industry'],
#  ['basenube',
#   'company',
#   'specializes',
#   'development',
#   'healthcare',
#   'software',
#   'product'],
#  ['basil',
#   'security',
#   'develops',
#   'enterprise',
#   'software',
#   'product',
#   'enable',
#   'security',
#   'policy',
#   'management'],
#  ['bayou',
#   'midstream',
#   'fullservice',
#   'midstream',
#   'company',
#   'providing',
#   'customized',
#   'solution',
#   'oil',
#   'gas',
#   'producer'],
#  ['travel', 'curation', 'platform'],
#  ['beagle',
#   'learning',
#   'provides',
#   'software',
#   'accelerates',
#   'learning',
#   'strategic',
#   'decision',
#   'making',
#   'using',
#   'custom',
#   'built',
#   'ai'],
#  ['beanstalk',
#   'network',
#   'research',
#   'development',
#   'company',
#   'privacy',
#   'preserving',
#   'financial',
#   'transaction'],
#  ['passive', 'income', 'market'],
#  ['help',
#   'early',
#   'growth',
#   'stage',
#   'startup',
#   'hire',
#   'right',
#   'senior',
#   'talent',
#   'help',
#   'easily',
#   'cross',
#   'chasm',
#   'arr'],
#  ['bedrock', 'private', 'personal', 'super', 'computer', 'company'],
#  ['bein',
#   'carib',
#   'software',
#   'solution',
#   'company',
#   'carribean',
#   'product',
#   'food',
#   'entertainment',
#   'travel',
#   'lifestyle'],
#  ['fold',
#   'us',
#   'machine',
#   'learning',
#   'provide',
#   'automatic',
#   'context',
#   'news',
#   'article'],
#  ['bema',
#   'creative',
#   'delivers',
#   'branding',
#   'website',
#   'creation',
#   'animation',
#   'logo',
#   'design',
#   'trade',
#   'show',
#   'social',
#   'medium',
#   'campaign',
#   'service'],
#  ['bensen',
#   'build',
#   'software',
#   'help',
#   'restaurant',
#   'brand',
#   'sell',
#   'stuff',
#   'voice',
#   'platform',
#   'like',
#   'alexa',
#   'google',
#   'assistant'],
#  ['machine',
#   'learning',
#   'model',
#   'serving',
#   'platform',
#   'creator',
#   'opensource',
#   'bentoml'],
#  ['bid',
#   'event',
#   'provider',
#   'mobile',
#   'event',
#   'coordination',
#   'application'],
#  ['billseye',
#   'realtime',
#   'mobile',
#   'billing',
#   'solution',
#   'application',
#   'professional',
#   'bill',
#   'client',
#   'call'],
#  ['something', 'wicked', 'way', 'come'],
#  ['binit',
#   'develops',
#   'aibased',
#   'tech',
#   'revolutionize',
#   'waste',
#   'segregation'],
#  ['biocanic',
#   'first',
#   'kind',
#   'health',
#   'program',
#   'intelligence',
#   'system',
#   'designed',
#   'streamline',
#   'health',
#   'program',
#   'integrative',
#   'practitioner'],
#  ['bionica',
#   'lab',
#   'digital',
#   'health',
#   'hardware',
#   'development',
#   'company',
#   'build',
#   'wearable',
#   'monitoring',
#   'system',
#   'solve',
#   'problem',
#   'doctor'],
#  ['bird',
#   'brain',
#   'developer',
#   'enterprise',
#   'platform',
#   'intended',
#   'serve',
#   'pest',
#   'control',
#   'industry'],
#  ['bitcoin',
#   'energy',
#   'ultimate',
#   'health',
#   'energy',
#   'drink',
#   'made',
#   'hustler',
#   'grinder',
#   'entrepreneur'],
#  ['bitcoindb',
#   'database',
#   'designed',
#   'store',
#   'data',
#   'bitcoin',
#   'cash',
#   'blockchain'],
#  ['developer',
#   'enterprise',
#   'software',
#   'designed',
#   'aggregate',
#   'access',
#   'information',
#   'across',
#   'multiple',
#   'source'],
#  ['bit', 'hash', 'digital', 'marketing', 'agency'],
#  ['bit',
#   'disk',
#   'data',
#   'engineering',
#   'consultancy',
#   'dedicated',
#   'building',
#   'robust',
#   'performant',
#   'data',
#   'system'],
#  ['bizdeviq',
#   'platform',
#   'connect',
#   'student',
#   'paid',
#   'artificial',
#   'intelligence',
#   'machine',
#   'learning',
#   'data',
#   'science',
#   'project'],
#  ['privacy',
#   'preserving',
#   'face',
#   'recognition',
#   'technology',
#   'personalized',
#   'customer',
#   'experience',
#   'increased',
#   'venue',
#   'safety'],
#  ['blinkup',
#   'geolocation',
#   'app',
#   'enables',
#   'user',
#   'connect',
#   'network',
#   'easily',
#   'locate',
#   'proximity'],
#  ['blitziq',
#   'develops',
#   'insight',
#   'platform',
#   'allows',
#   'user',
#   'assist',
#   'sale',
#   'team',
#   'run',
#   'consistent',
#   'sale',
#   'process'],
#  ['block',
#   'party',
#   'studio',
#   'technology',
#   'manages',
#   'spam',
#   'troll',
#   'social',
#   'medium',
#   'network'],
#  ['blockchain',
#   'art',
#   'collective',
#   'provides',
#   'unparalleled',
#   'provenance',
#   'tracking',
#   'artist',
#   'collector',
#   'dealer',
#   'institution'],
#  ['industrial', 'blockchain', 'network', 'infrastructure'],
#  ['blockchain',
#   'buffalo',
#   'conduct',
#   'group',
#   'discussion',
#   'meeting',
#   'conference',
#   'blockchain',
#   'technology',
#   'service'],
#  ['blockchan',
#   'online',
#   'social',
#   'medium',
#   'platform',
#   'enables',
#   'user',
#   'publish',
#   'monetize',
#   'content',
#   'connect',
#   'others'],
#  ['blockinterop',
#   'information',
#   'technology',
#   'solution',
#   'company',
#   'specializing',
#   'analysis',
#   'implementation',
#   'healthcare',
#   'resource'],
#  ['bloomberg', 'crypto', 'asset'],
#  ['blockpad', 'online', 'platform', 'document', 'spreadsheet'],
#  ['block',
#   'telegraph',
#   'leading',
#   'source',
#   'blockchain',
#   'cryptocurrency',
#   'news',
#   'finance',
#   'technology',
#   'reader',
#   'outside',
#   'industry'],
#  ['blocktown',
#   'capital',
#   'investment',
#   'fund',
#   'focused',
#   'exclusively',
#   'blockchain',
#   'venture',
#   'digital',
#   'currency',
#   'application',
#   'token'],
#  ['blocktricity',
#   'capital',
#   'investment',
#   'firm',
#   'specializes',
#   'cryptocurrencies',
#   'digital',
#   'asset'],
#  ['blockvigil',
#   'help',
#   'build',
#   'scale',
#   'blockchain',
#   'apps',
#   'line',
#   'code'],
#  ['blocky',
#   'help',
#   'people',
#   'trust',
#   'data',
#   'technology',
#   'zipperchain',
#   'scale',
#   'million',
#   'txssecond',
#   'extremely',
#   'low',
#   'predictable',
#   'cost'],
#  ['blocnets', 'privately', 'funded', 'software', 'technology', 'company'],
#  ['bloom',
#   'artificial',
#   'intelligence',
#   'company',
#   'guide',
#   'user',
#   'towards',
#   'happier',
#   'healthier',
#   'fulfilling',
#   'life'],
#  ['bludot',
#   'customer',
#   'loyalty',
#   'program',
#   'us',
#   'advanced',
#   'facial',
#   'recognition',
#   'technology'],
#  ['boardroom',
#   'alpha',
#   'develops',
#   'analytics',
#   'set',
#   'standard',
#   'assessment',
#   'public',
#   'company',
#   'director',
#   'officer',
#   'corporate',
#   'governance'],
#  ['bola',
#   'ai',
#   'voice',
#   'assistant',
#   'company',
#   'develops',
#   'solution',
#   'reduce',
#   'documentation',
#   'burden',
#   'dental',
#   'medical',
#   'provider'],
#  ['boldcode', 'web', 'software', 'development', 'company'],
#  ['boldvue', 'provides', 'elearning', 'service', 'solution'],
#  ['bolt',
#   'lab',
#   'provides',
#   'instant',
#   'private',
#   'payment',
#   'everyday',
#   'purchase'],
#  ['bolton',
#   'secure',
#   'provider',
#   'soc',
#   'noc',
#   'staffing',
#   'coverage',
#   'cybersecurity',
#   'service',
#   'tool',
#   'analysis'],
#  ['authenticating', 'supply', 'chain', 'using', 'blockchain', 'technology'],
#  ['bonbloc',
#   'blockchain',
#   'software',
#   'company',
#   'focus',
#   'corporate',
#   'government',
#   'solution'],
#  ['childhood', 'literacy', 'platform', 'reading', 'log', 'reward', 'system'],
#  ['bookelicious',
#   'promotes',
#   'literacy',
#   'helping',
#   'child',
#   'find',
#   'great',
#   'book',
#   'topic',
#   'passionate'],
#  ['borgo',
#   'cloudbased',
#   'hris',
#   'payroll',
#   'management',
#   'solution',
#   'small',
#   'midsized',
#   'business'],
#  ['bot',
#   'image',
#   'medical',
#   'software',
#   'company',
#   'utilizes',
#   'artificial',
#   'intelligence',
#   'imaging',
#   'interpretation'],
#  ['botanisol',
#   'analytics',
#   'improves',
#   'measurement',
#   'analytics',
#   'engineering',
#   'science'],
#  ['botisimo',
#   'crossplatform',
#   'chatbot',
#   'viewer',
#   'engagement',
#   'tool',
#   'suite',
#   'available',
#   'twitch',
#   'mixer',
#   'youtube',
#   'discord'],
#  ['short',
#   'term',
#   'hourly',
#   'daily',
#   'storage',
#   'around',
#   'urban',
#   'area',
#   'hosted',
#   'local',
#   'business'],
#  ['giving', 'people', 'experience', 'want', 'want', 'starting', 'dating'],
#  ['bound',
#   'enables',
#   'insurance',
#   'company',
#   'brokerage',
#   'agency',
#   'offer',
#   'insurance',
#   'product'],
#  ['boxlet',
#   'storage',
#   'develops',
#   'peertopeer',
#   'network',
#   'software',
#   'offer',
#   'customizable',
#   'short',
#   'term',
#   'storage',
#   'solution'],
#  ['helping',
#   'world',
#   'best',
#   'consumer',
#   'brand',
#   'build',
#   'deeper',
#   'customer',
#   'relationship',
#   'scale'],
#  ['saas',
#   'marketing',
#   'platform',
#   'enables',
#   'brand',
#   'setup',
#   'manage',
#   'measure',
#   'chat',
#   'conversation',
#   'best',
#   'customer'],
#  ['breaking',
#   'normal',
#   'social',
#   'networking',
#   'party',
#   'game',
#   'app',
#   'capitalizes',
#   'real',
#   'human',
#   'connection'],
#  ['techenabled',
#   'consulting',
#   'platform',
#   'connecting',
#   'business',
#   'industry',
#   'professional',
#   'share',
#   'knowledge',
#   'ondemand'],
#  ['bringing',
#   'transformative',
#   'power',
#   'map',
#   'internet',
#   'make',
#   'entire',
#   'web',
#   'collaborative',
#   'learning',
#   'experience'],
#  ['brightback',
#   'offer',
#   'entreprenurial',
#   'advice',
#   'subscriptionbased',
#   'business',
#   'customer',
#   'lifetime',
#   'value'],
#  ['brilliant',
#   'hire',
#   'recruiting',
#   'solution',
#   'efficient',
#   'unbiased',
#   'candidate',
#   'screening'],
#  ['brokerassist',
#   'mobilefirst',
#   'saas',
#   'marketplace',
#   'product',
#   'connecting',
#   'realtors',
#   'fractional',
#   'assistance',
#   'referral',
#   'networking',
#   'gig'],
#  ['provides', 'technical', 'financial', 'service', 'nationwide'],
#  ['budgetshred',
#   'expertise',
#   'paper',
#   'document',
#   'shredding',
#   'computer',
#   'destruction',
#   'electronics',
#   'recycling',
#   'service'],
#  ['behind',
#   'buildee',
#   'work',
#   'greatest',
#   'mind',
#   'building',
#   'science',
#   'partnership',
#   'market',
#   'driver',
#   'company'],
#  ['buildr',
#   'provides',
#   'solution',
#   'bridging',
#   'job',
#   'site',
#   'cloud',
#   'task',
#   'automation',
#   'faster',
#   'project',
#   'closeout',
#   'datadriven',
#   'contractor'],
#  ['easily', 'invest', 'spare', 'change', 'cryptocurrency'],
#  ['buttonwood',
#   'software',
#   'platform',
#   'help',
#   'elite',
#   'latestage',
#   'startup',
#   'efficiently',
#   'raise',
#   'growth',
#   'capital'],
#  ['buyjour',
#   'new',
#   'type',
#   'marketing',
#   'platform',
#   'dramatically',
#   'increase',
#   'effectiveness',
#   'abm',
#   'strategy'],
#  ['buywith',
#   'online',
#   'shopping',
#   'livestream',
#   'platform',
#   'brand',
#   'retailer',
#   'influencers',
#   'expert',
#   'host',
#   'live',
#   'shopping',
#   'event'],
#  ['get', 'buzzing'],
#  ['byteboard',
#   'redesigns',
#   'technical',
#   'interview',
#   'reflective',
#   'engineer',
#   'job',
#   'projectbased',
#   'approach'],
#  ['calendarer',
#   'offer',
#   'calendar',
#   'synchronization',
#   'professional',
#   'contact',
#   'management',
#   'contact',
#   'scaling',
#   'contact',
#   'organization'],
#  ['california',
#   'cannabis',
#   'market',
#   'information',
#   'technology',
#   'service',
#   'company'],
#  ['camberline',
#   'technology',
#   'sensordriven',
#   'platform',
#   'help',
#   'community',
#   'read',
#   'electricity',
#   'usage',
#   'support',
#   'energy',
#   'conservation'],
#  ['cameyo',
#   'cloudnative',
#   'window',
#   'application',
#   'transformation',
#   'platform',
#   'atp',
#   'delivers',
#   'window',
#   'application',
#   'device',
#   'browser'],
#  ['take', 'chat', 'live'],
#  ['mobile',
#   'stock',
#   'market',
#   'application',
#   'pattern',
#   'recognition',
#   'technology',
#   'watchlist',
#   'push',
#   'notification'],
#  ['candoo', 'workflow', 'management', 'software', 'drone', 'business'],
#  ['financial', 'solution', 'cannabis', 'cbd', 'company'],
#  ['canncurrent',
#   'provides',
#   'softwareasaservice',
#   'solution',
#   'cannabis',
#   'industry'],
#  ['canopy',
#   'software',
#   'company',
#   'specializing',
#   'making',
#   'data',
#   'breach',
#   'impact',
#   'assessment'],
#  ['carbon',
#   'cash',
#   'behavioral',
#   'energy',
#   'efficiency',
#   'app',
#   'reward',
#   'student',
#   'conserving',
#   'electricity',
#   'reducing',
#   'carbon',
#   'footprint'],
#  ['carbonado',
#   'connects',
#   'verified',
#   'talent',
#   'new',
#   'opportunity',
#   'guided',
#   'skill',
#   'fit',
#   'use',
#   'advanced',
#   'tool',
#   'technology',
#   'leveraging',
#   'ai'],
#  ['secure', 'blockchain', 'clinical', 'network'],
#  ['carbyn',
#   'platform',
#   'service',
#   'tech',
#   'environment',
#   'assembled',
#   'installed',
#   'corporation',
#   'fund',
#   'real',
#   'estate',
#   'workspace'],
#  ['bringing', 'ondemand', 'inhome', 'nursing', 'care'],
#  ['castamash',
#   'mobile',
#   'app',
#   'allows',
#   'create',
#   'collaborative',
#   'video',
#   'friend',
#   'around',
#   'world'],
#  ['catalyst',
#   'education',
#   'elearning',
#   'platform',
#   'provides',
#   'education',
#   'stem',
#   'course',
#   'lab'],
#  ['cattle', 'management', 'mobile', 'application'],
#  ['cawlo', 'startup', 'currently', 'stealth'],
#  ['cblocks',
#   'creates',
#   'product',
#   'make',
#   'easy',
#   'save',
#   'spend',
#   'earn',
#   'cryptocurrency'],
#  ['cbm',
#   'marketing',
#   'solution',
#   'provides',
#   'advertising',
#   'seo',
#   'digital',
#   'marketing',
#   'service'],
#  ['reservationless', 'hotel'],
#  ['data',
#   'science',
#   'analytics',
#   'enterprise',
#   'software',
#   'ai',
#   'machine',
#   'learning',
#   'data',
#   'platform',
#   'ml',
#   'operationalization',
#   'etl',
#   'data',
#   'warehousing'],
#  ['celitech',
#   'enables',
#   'online',
#   'business',
#   'app',
#   'offer',
#   'cellular',
#   'data',
#   'esim',
#   'using',
#   'mobile',
#   'connectivity',
#   'analytics'],
#  ['fullservice',
#   'strategic',
#   'consultancy',
#   'mobile',
#   'web',
#   'technology',
#   'architecture',
#   'focus',
#   'humancentered',
#   'design'],
#  ['cerca',
#   'mobile',
#   'technology',
#   'enables',
#   'user',
#   'find',
#   'connect',
#   'people',
#   'move',
#   'forward'],
#  ['chat',
#   'goose',
#   'help',
#   'company',
#   'responsive',
#   'community',
#   'managing',
#   'chat',
#   'channel',
#   'first',
#   'product',
#   'bot',
#   'manager'],
#  ['easiest', 'way', 'create', 'paid', 'chat', 'group'],
#  ['chattr',
#   'retail',
#   'chatbot',
#   'platform',
#   'reinventing',
#   'way',
#   'candidate',
#   'employer',
#   'create',
#   'meaningful',
#   'connection',
#   'scale'],
#  ['checkplis', 'develops', 'software', 'restaurant', 'industry'],
#  ['mint', 'photo', 'blockchain'],
#  ['cherry', 'office', 'perk', 'solution', 'modern', 'startup'],
#  ['allinone', 'platform'],
#  ['cide',
#   'kic',
#   'provides',
#   'solution',
#   'serious',
#   'pain',
#   'point',
#   'within',
#   'hospitality',
#   'industry'],
#  ['clean',
#   'water',
#   'ai',
#   'ai',
#   'detects',
#   'dangerous',
#   'bacteria',
#   'ecoli',
#   'cholera',
#   'well',
#   'harmful',
#   'particle'],
#  ['clearat',
#   'technology',
#   'startup',
#   'provides',
#   'automated',
#   'sale',
#   'process',
#   'allows',
#   'u',
#   'save',
#   'time'],
#  ['clearcam',
#   'provides',
#   'clinician',
#   'innovative',
#   'tool',
#   'technology',
#   'improve',
#   'vision',
#   'skill',
#   'operating',
#   'room'],
#  ['clearlaw',
#   'provides',
#   'seamless',
#   'design',
#   'artificial',
#   'intelligence',
#   'innovative',
#   'natural',
#   'language',
#   'processing',
#   'tool'],
#  ['clerkie',
#   'ai',
#   'financial',
#   'planner',
#   'underserved',
#   'american',
#   'looking',
#   'answer'],
#  ['clerksy',
#   'new',
#   'outlook',
#   'human',
#   'capital',
#   'service',
#   'modern',
#   'company',
#   'inclusivehr'],
#  ['mobile', 'app', 'digital', 'medium', 'fashion', 'beauty', 'style'],
#  ['digital', 'health', 'clinic', 'workflow', 'solution'],
#  ['cloud',
#   'cien',
#   'firm',
#   'delivering',
#   'cloud',
#   'technology',
#   'customized',
#   'service'],
#  ['productiongrade', 'development', 'environment', 'coding', 'analytics'],
#  ['coderecipe',
#   'marketplace',
#   'developer',
#   'grab',
#   'ready',
#   'use',
#   'cloud',
#   'solution'],
#  ['coegil',
#   'help',
#   'anyone',
#   'load',
#   'visualize',
#   'predict',
#   'data',
#   'second',
#   'made',
#   'path',
#   'spreadsheet',
#   'big',
#   'data'],
#  ['cognaisent',
#   'specializes',
#   'field',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'artificial',
#   'intelligence',
#   'drug',
#   'discovery',
#   'molecular',
#   'analysis'],
#  ['cognida',
#   'network',
#   'open',
#   'source',
#   'platform',
#   'enable',
#   'enterprise',
#   'securely',
#   'manage',
#   'connected',
#   'device'],
#  ['command',
#   'e',
#   'develops',
#   'unified',
#   'desktop',
#   'search',
#   'tool',
#   'help',
#   'us',
#   'quickly',
#   'scour',
#   'file',
#   'data',
#   'source',
#   'across',
#   'nearly',
#   'every',
#   'app',
#   'use'],
#  ['blockchain', 'decentralized', 'organization', 'crypto', 'cryptocurrencies'],
#  ['commonwealth',
#   'lab',
#   'governance',
#   'startup',
#   'offering',
#   'new',
#   'twist',
#   'token',
#   'airdrop'],
#  ['companionmx', 'digital', 'health', 'technology', 'company'],
#  ['comprehensive',
#   'solution',
#   'business',
#   'size',
#   'complete',
#   'tech',
#   'solution',
#   'actively',
#   'manage',
#   'endtoend',
#   'need'],
#  ['innovative',
#   'writing',
#   'platform',
#   'available',
#   'designed',
#   'make',
#   'selfpublishing',
#   'easy',
#   'accessible',
#   'shareable',
#   'across',
#   'device'],
#  ['compt',
#   'perk',
#   'management',
#   'software',
#   'help',
#   'company',
#   'create',
#   'manage',
#   'streamline',
#   'perk',
#   'stipend',
#   'delight',
#   'employee'],
#  ['conalogix',
#   'llc',
#   'specializes',
#   'biotech',
#   'pharmaceutical',
#   'lifescience',
#   'focused',
#   'consulting',
#   'solution'],
#  ['concreit', 'provides', 'real', 'estate', 'software'],
#  ['condeto',
#   'nimble',
#   'property',
#   'management',
#   'tool',
#   'built',
#   'modern',
#   'age'],
#  ['confetti', 'collective', 'retailing', 'company'],
#  ['conflict',
#   'coach',
#   'receive',
#   'indepth',
#   'coaching',
#   'personalized',
#   'quick',
#   'reference',
#   'guide',
#   'constructive',
#   'conflict',
#   'conversation'],
#  ['software',
#   'mobile',
#   'app',
#   'development',
#   'web',
#   'design',
#   'digital',
#   'marketing'],
#  ['connector',
#   'secure',
#   'mobilefirst',
#   'webbased',
#   'platform',
#   'allows',
#   'surgical',
#   'team',
#   'easily',
#   'communicate',
#   'manage',
#   'patient',
#   'surgical',
#   'lifecycle'],
#  ['consentual',
#   'provides',
#   'videobased',
#   'esignature',
#   'platform',
#   'used',
#   'peertopeer',
#   'consent',
#   'agreement',
#   'contract'],
#  ['constellation',
#   'kidney',
#   'group',
#   'offer',
#   'software',
#   'solution',
#   'healthcare',
#   'industry'],
#  ['consumeroptix',
#   'front',
#   'office',
#   'insurtech',
#   'company',
#   'brings',
#   'intelligent',
#   'automation',
#   'personalization',
#   'consumer',
#   'insurance',
#   'distribution'],
#  ['contracthub',
#   'legal',
#   'operation',
#   'platform',
#   'streamlines',
#   'process',
#   'managing',
#   'document'],
#  ['conundrum',
#   'software',
#   'company',
#   'develops',
#   'social',
#   'networking',
#   'apps',
#   'software',
#   'iphone'],
#  ['convuent',
#   'software',
#   'development',
#   'company',
#   'provides',
#   'review',
#   'feedback',
#   'online',
#   'reputation',
#   'management',
#   'service'],
#  ['coosta',
#   'mortgage',
#   'collateral',
#   'transform',
#   'platform',
#   'secondary',
#   'market'],
#  ['datadriven',
#   'saas',
#   'platform',
#   'marketplace',
#   'b',
#   'b',
#   'b',
#   'furnishing',
#   'industry'],
#  ['coral',
#   'app',
#   'designed',
#   'help',
#   'cultivate',
#   'sexuality',
#   'transform',
#   'relationship',
#   'sex'],
#  ['coral',
#   'humancentric',
#   'robotics',
#   'company',
#   'designing',
#   'robot',
#   'people',
#   'enhance',
#   'everyday',
#   'life'],
#  ['corsha',
#   'api',
#   'security',
#   'platform',
#   'prevents',
#   'network',
#   'attack',
#   'dynamic',
#   'fully',
#   'automated',
#   'multifactor',
#   'authentication',
#   'apis'],
#  ['cortez',
#   'lab',
#   'software',
#   'company',
#   'engaged',
#   'development',
#   'salesforce',
#   'application'],
#  ['cost'],
#  ['counterfeittechnology', 'kill', 'counterfeiter', 'dead', 'track'],
#  ['coup',
#   'mobile',
#   'messaging',
#   'service',
#   'allows',
#   'consumer',
#   'send',
#   'text',
#   'discover',
#   'thousand',
#   'local',
#   'deal',
#   'nearby'],
#  ['coveware',
#   'aggregate',
#   'global',
#   'ransomware',
#   'cyber',
#   'extortion',
#   'data',
#   'minimize',
#   'related',
#   'cost',
#   'downtime'],
#  ['cowan',
#   'agency',
#   'made',
#   'expert',
#   'team',
#   'artist',
#   'player',
#   'work',
#   'turn',
#   'face',
#   'firm',
#   'creating',
#   'worldclass',
#   'service'],
#  ['cpnetio',
#   'brings',
#   'industry',
#   'technology',
#   'traditional',
#   'manufacturing',
#   'vertical'],
#  ['cr', 'score', 'college', 'admission', 'coach', 'pocket'],
#  ['digital', 'marketing', 'made', 'simple'],
#  ['developing', 'tool', 'service', 'solution', 'business', 'customer'],
#  ['cream',
#   'analytics',
#   'gotomarket',
#   'analytics',
#   'tool',
#   'provides',
#   'automated',
#   'answer',
#   'improve',
#   'financial',
#   'health'],
#  ['credit',
#   'washington',
#   'specializes',
#   'deep',
#   'application',
#   'research',
#   'precise',
#   'implementation',
#   'ai',
#   'machine',
#   'learning',
#   'data',
#   'science'],
#  ['cresance',
#   'us',
#   'ai',
#   'cut',
#   'cloud',
#   'operating',
#   'cost',
#   'using',
#   'algorithm',
#   'detect',
#   'wastage'],
#  ['datadriven',
#   'saas',
#   'platform',
#   'marketplace',
#   'b',
#   'b',
#   'b',
#   'furnishing',
#   'industry'],
#  ['coosta',
#   'mortgage',
#   'collateral',
#   'transform',
#   'platform',
#   'secondary',
#   'market'],
#  ['convuent',
#   'software',
#   'development',
#   'company',
#   'provides',
#   'review',
#   'feedback',
#   'online',
#   'reputation',
#   'management',
#   'service'],
#  ['conundrum',
#   'software',
#   'company',
#   'develops',
#   'social',
#   'networking',
#   'apps',
#   'software',
#   'iphone'],
#  ['contracthub',
#   'legal',
#   'operation',
#   'platform',
#   'streamlines',
#   'process',
#   'managing',
#   'document'],
#  ['consumeroptix',
#   'front',
#   'office',
#   'insurtech',
#   'company',
#   'brings',
#   'intelligent',
#   'automation',
#   'personalization',
#   'consumer',
#   'insurance',
#   'distribution'],
#  ['constellation',
#   'kidney',
#   'group',
#   'offer',
#   'software',
#   'solution',
#   'healthcare',
#   'industry'],
#  ['consentual',
#   'provides',
#   'videobased',
#   'esignature',
#   'platform',
#   'used',
#   'peertopeer',
#   'consent',
#   'agreement',
#   'contract'],
#  ['connector',
#   'secure',
#   'mobilefirst',
#   'webbased',
#   'platform',
#   'allows',
#   'surgical',
#   'team',
#   'easily',
#   'communicate',
#   'manage',
#   'patient',
#   'surgical',
#   'lifecycle'],
#  ['software',
#   'mobile',
#   'app',
#   'development',
#   'web',
#   'design',
#   'digital',
#   'marketing'],
#  ['conflict',
#   'coach',
#   'receive',
#   'indepth',
#   'coaching',
#   'personalized',
#   'quick',
#   'reference',
#   'guide',
#   'constructive',
#   'conflict',
#   'conversation'],
#  ['confetti', 'collective', 'retailing', 'company'],
#  ['condeto',
#   'nimble',
#   'property',
#   'management',
#   'tool',
#   'built',
#   'modern',
#   'age'],
#  ['concreit', 'provides', 'real', 'estate', 'software'],
#  ['conalogix',
#   'llc',
#   'specializes',
#   'biotech',
#   'pharmaceutical',
#   'lifescience',
#   'focused',
#   'consulting',
#   'solution'],
#  ['compt',
#   'perk',
#   'management',
#   'software',
#   'help',
#   'company',
#   'create',
#   'manage',
#   'streamline',
#   'perk',
#   'stipend',
#   'delight',
#   'employee'],
#  ['innovative',
#   'writing',
#   'platform',
#   'available',
#   'designed',
#   'make',
#   'selfpublishing',
#   'easy',
#   'accessible',
#   'shareable',
#   'across',
#   'device'],
#  ['comprehensive',
#   'solution',
#   'business',
#   'size',
#   'complete',
#   'tech',
#   'solution',
#   'actively',
#   'manage',
#   'endtoend',
#   'need'],
#  ['companionmx', 'digital', 'health', 'technology', 'company'],
#  ['commonwealth',
#   'lab',
#   'governance',
#   'startup',
#   'offering',
#   'new',
#   'twist',
#   'token',
#   'airdrop'],
#  ['blockchain', 'decentralized', 'organization', 'crypto', 'cryptocurrencies'],
#  ['crossliner', 'healthcare', 'firm', 'operating', 'stealth', 'mode'],
#  ['crimpd',
#   'climbingspecific',
#   'training',
#   'application',
#   'us',
#   'training',
#   'knowledge',
#   'data',
#   'analytics',
#   'lattice',
#   'training'],
#  ['cresance',
#   'us',
#   'ai',
#   'cut',
#   'cloud',
#   'operating',
#   'cost',
#   'using',
#   'algorithm',
#   'detect',
#   'wastage'],
#  ['credit',
#   'washington',
#   'specializes',
#   'deep',
#   'application',
#   'research',
#   'precise',
#   'implementation',
#   'ai',
#   'machine',
#   'learning',
#   'data',
#   'science'],
#  ['cream',
#   'analytics',
#   'gotomarket',
#   'analytics',
#   'tool',
#   'provides',
#   'automated',
#   'answer',
#   'improve',
#   'financial',
#   'health'],
#  ['developing', 'tool', 'service', 'solution', 'business', 'customer'],
#  ['digital', 'marketing', 'made', 'simple'],
#  ['cr', 'score', 'college', 'admission', 'coach', 'pocket'],
#  ['cpnetio',
#   'brings',
#   'industry',
#   'technology',
#   'traditional',
#   'manufacturing',
#   'vertical'],
#  ['cowan',
#   'agency',
#   'made',
#   'expert',
#   'team',
#   'artist',
#   'player',
#   'work',
#   'turn',
#   'face',
#   'firm',
#   'creating',
#   'worldclass',
#   'service'],
#  ['coveware',
#   'aggregate',
#   'global',
#   'ransomware',
#   'cyber',
#   'extortion',
#   'data',
#   'minimize',
#   'related',
#   'cost',
#   'downtime'],
#  ['coup',
#   'mobile',
#   'messaging',
#   'service',
#   'allows',
#   'consumer',
#   'send',
#   'text',
#   'discover',
#   'thousand',
#   'local',
#   'deal',
#   'nearby'],
#  ['counterfeittechnology', 'kill', 'counterfeiter', 'dead', 'track'],
#  ['cost'],
#  ['cortez',
#   'lab',
#   'software',
#   'company',
#   'engaged',
#   'development',
#   'salesforce',
#   'application'],
#  ['corsha',
#   'api',
#   'security',
#   'platform',
#   'prevents',
#   'network',
#   'attack',
#   'dynamic',
#   'fully',
#   'automated',
#   'multifactor',
#   'authentication',
#   'apis'],
#  ['cyber',
#   'list',
#   'offer',
#   'company',
#   'cybersecurity',
#   'protection',
#   'education',
#   'training',
#   'phishing',
#   'exercise'],
#  ['customerdb',
#   'software',
#   'firm',
#   'offer',
#   'saas',
#   'analytics',
#   'tool',
#   'productmarket',
#   'fit',
#   'optimizing',
#   'growth',
#   'market'],
#  ['curie',
#   'develops',
#   'artificial',
#   'intelligencebased',
#   'respiratory',
#   'health',
#   'monitoring',
#   'technology'],
#  ['cuore',
#   'platform',
#   'created',
#   'empower',
#   'financial',
#   'agent',
#   'providing',
#   'complete',
#   'digital',
#   'operational',
#   'hub',
#   'based',
#   'worldclass',
#   'technology'],
#  ['culture',
#   'genesis',
#   'digital',
#   'studio',
#   'focused',
#   'remixing',
#   'digital',
#   'technology',
#   'urban',
#   'multicultural',
#   'audience'],
#  ['culturalyst',
#   'software',
#   'company',
#   'build',
#   'digital',
#   'infrastructure',
#   'local',
#   'cultural',
#   'ecosystem'],
#  ['culdesac',
#   'offer',
#   'quick',
#   'easy',
#   'way',
#   'discover',
#   'new',
#   'outdoor',
#   'game',
#   'within',
#   'peer',
#   'group'],
#  ['cue',
#   'intelligence',
#   'provides',
#   'sale',
#   'service',
#   'scripting',
#   'software',
#   'conversational',
#   'intelligence'],
#  ['cuanto',
#   'allows',
#   'latin',
#   'american',
#   'creator',
#   'monetize',
#   'audience',
#   'sell',
#   'social',
#   'medium'],
#  ['cryptonet',
#   'service',
#   'global',
#   'leader',
#   'providing',
#   'innovative',
#   'web',
#   'hosting',
#   'solution',
#   'personal',
#   'commercial',
#   'businessrelated',
#   'need'],
#  ['crypto',
#   'key',
#   'stack',
#   'software',
#   'based',
#   'hardware',
#   'wallet',
#   'help',
#   'protect',
#   'key',
#   'transacting'],
#  ['crypto',
#   'disrupted',
#   'cryptocurrency',
#   'blockchain',
#   'youtube',
#   'channel',
#   'podcast',
#   'greg',
#   'kerr',
#   'trent',
#   'lapinski'],
#  ['saas',
#   'platform',
#   'enabling',
#   'equipment',
#   'dealer',
#   'conveniently',
#   'offer',
#   'financing',
#   'customer'],
#  ['daytoday',
#   'guide',
#   'patient',
#   'medical',
#   'procedure',
#   'help',
#   'recover',
#   'return',
#   'normal',
#   'life'],
#  ['saas', 'project', 'management', 'platform', 'construction'],
#  ['realtime',
#   'unstructured',
#   'data',
#   'transformation',
#   'inference',
#   'edge',
#   'cloud',
#   'saas',
#   'platform',
#   'providing',
#   'data',
#   'management',
#   'service'],
#  ['datanchor',
#   'develops',
#   'novel',
#   'cryptotechnology',
#   'anchor',
#   'data',
#   'consumption',
#   'within',
#   'network',
#   'boundary'],
#  ['datamode', 'data', 'pipeline', 'visibility', 'tool', 'data', 'engineer'],
#  ['databased',
#   'software',
#   'company',
#   'provides',
#   'automation',
#   'analytics',
#   'crm',
#   'solution',
#   'sale',
#   'team',
#   'understand',
#   'evaluate',
#   'develop'],
#  ['dashing',
#   'home',
#   'service',
#   'platform',
#   'us',
#   'blockchain',
#   'technology',
#   'create',
#   'ecosystem',
#   'homeowner',
#   'service',
#   'provider'],
#  ['dashcma',
#   'provides',
#   'interactive',
#   'dashboard',
#   'allows',
#   'give',
#   'meaningful',
#   'pricing',
#   'conversation',
#   'agent',
#   'client'],
#  ['dash',
#   'app',
#   'provides',
#   'mobile',
#   'payment',
#   'customer',
#   'engagement',
#   'platform',
#   'restaurant'],
#  ['dagda',
#   'partner',
#   'impact',
#   'investing',
#   'information',
#   'technology',
#   'company'],
#  ['dagan',
#   'provides',
#   'agricultural',
#   'environmental',
#   'data',
#   'service',
#   'support',
#   'expansion',
#   'regenerative',
#   'agriculture'],
#  ['data',
#   'vendor',
#   'reference',
#   'data',
#   'dacin',
#   'digital',
#   'asset',
#   'class',
#   'dlt',
#   'blockchain',
#   'capital',
#   'market',
#   'software',
#   'solution',
#   'data',
#   'management',
#   'b',
#   'b',
#   'service'],
#  ['devflight', 'business', 'model', 'opensource', 'software'],
#  ['destiny', 'debt', 'management', 'platform'],
#  ['deployhub',
#   'offer',
#   'hosted',
#   'next',
#   'generation',
#   'software',
#   'deployment',
#   'kubernetes',
#   'agile',
#   'devops',
#   'team'],
#  ['dentistai',
#   'software',
#   'automatically',
#   'detects',
#   'pathology',
#   'dental',
#   'imaging'],
#  ['denovium',
#   'artificial',
#   'intelligence',
#   'company',
#   'pioneering',
#   'novel',
#   'ai',
#   'method',
#   'accelerate',
#   'innovation',
#   'biopharma'],
#  ['denovers',
#   'company',
#   'specialized',
#   'uiux',
#   'design',
#   'b',
#   'b',
#   'design',
#   'development'],
#  ['demandstar',
#   'connects',
#   'business',
#   'local',
#   'government',
#   'contracting',
#   'opportunity'],
#  ['demand',
#   'iq',
#   'provides',
#   'software',
#   'managed',
#   'service',
#   'clean',
#   'energy',
#   'industry'],
#  ['delic',
#   'psychedelics',
#   'corporation',
#   'specializes',
#   'education',
#   'content',
#   'event',
#   'psychoactive',
#   'compound'],
#  ['delfin', 'virtual', 'advisor', 'energy', 'industry'],
#  ['deepwalk',
#   'research',
#   'develops',
#   'mobile',
#   'application',
#   'supplement',
#   'construction',
#   'survey',
#   'precision',
#   'model'],
#  ['deephow',
#   'develops',
#   'aipowered',
#   'learning',
#   'platform',
#   'manufacturing',
#   'service',
#   'repair'],
#  ['intelligent', 'instrumentation', 'synthetic', 'biology'],
#  ['deepcuris', 'build', 'ai', 'engine', 'smallmolecule', 'drug', 'discovery'],
#  ['photorealistic', 'avatar', 'scale'],
#  ['displayride',
#   'innovator',
#   'focused',
#   'enhancing',
#   'rideshare',
#   'experience'],
#  ['discreetai',
#   'build',
#   'service',
#   'privacypreserving',
#   'machine',
#   'learning',
#   'mobile',
#   'web',
#   'server'],
#  ['dirt',
#   'protocol',
#   'decentralized',
#   'information',
#   'curation',
#   'us',
#   'token',
#   'staking',
#   'incentivize',
#   'honesty'],
#  ['suggestion', 'box', 'reimagined'],
#  ['software',
#   'help',
#   'direct',
#   'seller',
#   'save',
#   'time',
#   'managing',
#   'growing',
#   'business'],
#  ['saas', 'law', 'enforcement', 'public', 'safety', 'mobile', 'apps'],
#  ['digital',
#   'water',
#   'work',
#   'engineering',
#   'technology',
#   'solution',
#   'provider',
#   'dedicated',
#   'innovating',
#   'exclusively',
#   'global',
#   'water',
#   'industry'],
#  ['digital',
#   'capital',
#   'management',
#   'fund',
#   'management',
#   'firm',
#   'offering',
#   'portfolio',
#   'management',
#   'digital',
#   'asset',
#   'fund',
#   'plan',
#   'different',
#   'investor'],
#  ['drum',
#   'new',
#   'gig',
#   'economy',
#   'platform',
#   'aim',
#   'improve',
#   'life',
#   'million'],
#  ['drslinq',
#   'developing',
#   'mobile',
#   'ekg',
#   'device',
#   'platform',
#   'appropriately',
#   'triage',
#   'chest',
#   'pain',
#   'patient',
#   'er'],
#  ['dropshot',
#   'capital',
#   'management',
#   'investment',
#   'firm',
#   'offer',
#   'ai',
#   'machine',
#   'learning',
#   'solution',
#   'systematic',
#   'trading',
#   'investment'],
#  ['drop',
#   'cowboy',
#   'direct',
#   'voicemail',
#   'worldwide',
#   'mass',
#   'messaging',
#   'system'],
#  ['drivewayz', 'mobile', 'app', 'show', 'parking', 'option', 'city'],
#  ['drivetime',
#   'provides',
#   'online',
#   'platform',
#   'designed',
#   'help',
#   'user',
#   'play',
#   'game',
#   'drive'],
#  ['driver',
#   'hardwarefree',
#   'mobile',
#   'app',
#   'allows',
#   'user',
#   'video',
#   'record',
#   'trip',
#   'receiving',
#   'safety',
#   'alert'],
#  ['healthcare', 'saas'],
#  ['dragonglass',
#   'hardware',
#   'design',
#   'manufacturing',
#   'company',
#   'blockchain',
#   'cloud',
#   'computing',
#   'space'],
#  ['shop',
#   'mobile',
#   'shopping',
#   'network',
#   'showcase',
#   'product',
#   'original',
#   'hilarious',
#   'characterdriven',
#   'content'],
#  ['dowallet',
#   'rapidly',
#   'growing',
#   'decentralized',
#   'financial',
#   'service',
#   'hub',
#   'hold',
#   'manage',
#   'crypto',
#   'fiat',
#   'asset'],
#  ['purveyor', 'friendly', 'competition'],
#  ['dottid',
#   'commercial',
#   'real',
#   'estate',
#   'softwareasaservice',
#   'technology',
#   'platform'],
#  ['doppler',
#   'provides',
#   'application',
#   'management',
#   'platform',
#   'used',
#   'help',
#   'developer',
#   'manage',
#   'api',
#   'key',
#   'across',
#   'project'],
#  ['team', 'health', 'platform'],
#  ['donut', 'mobile', 'app', 'save', 'earn', 'high', 'yield', 'defi'],
#  ['donorup',
#   'first',
#   'giving',
#   'platform',
#   'focus',
#   'individual',
#   'donor',
#   'help',
#   'refine',
#   'imprint',
#   'world'],
#  ['eiffel',
#   'group',
#   'team',
#   'consultant',
#   'developer',
#   'specialized',
#   'odoo',
#   'integration',
#   'erp',
#   'software'],
#  ['diy',
#   'online',
#   'supply',
#   'chain',
#   'platform',
#   'diy',
#   'custom',
#   'clearance',
#   'process'],
#  ['edupixel',
#   'online',
#   'education',
#   'platform',
#   'dedicated',
#   'empowering',
#   'creative',
#   'workforce',
#   'teaching',
#   'new',
#   'skill',
#   'tool'],
#  ['eddii',
#   'virtual',
#   'app',
#   'character',
#   'designed',
#   'engage',
#   'people',
#   'living',
#   'diabetes',
#   'track',
#   'record',
#   'health'],
#  ['founded',
#   'passion',
#   'education',
#   'whether',
#   'academic',
#   'student',
#   'lifelong',
#   'learner',
#   'help',
#   'create',
#   'next',
#   'learning',
#   'moment'],
#  ['echoar',
#   'delivers',
#   'augmented',
#   'reality',
#   'training',
#   'experience',
#   'mental',
#   'health',
#   'care'],
#  ['bringing', 'people', 'food', 'together', 'software'],
#  ['blockchain',
#   'education',
#   'professional',
#   'development',
#   'continuing',
#   'ed'],
#  ['entangled',
#   'velocity',
#   'education',
#   'management',
#   'company',
#   'help',
#   'earlystage',
#   'education',
#   'learning',
#   'technology',
#   'company',
#   'catalyze',
#   'growth'],
#  ['ensu',
#   'help',
#   'people',
#   'automatically',
#   'track',
#   'manage',
#   'emotional',
#   'health',
#   'using',
#   'machine',
#   'learning',
#   'natural',
#   'language',
#   'processing'],
#  ['ensight',
#   'technology',
#   'parking',
#   'management',
#   'system',
#   'provides',
#   'parking',
#   'guidance',
#   'occupancy',
#   'counting',
#   'service'],
#  ['enjoytech',
#   'usa',
#   'specializes',
#   'developing',
#   'manufacturing',
#   'distributing',
#   'interactive',
#   'technology',
#   'product'],
#  ['engine',
#   'ml',
#   'build',
#   'distributed',
#   'deep',
#   'learning',
#   'infrastructure',
#   'train',
#   'machine',
#   'learning',
#   'model',
#   'minute',
#   'hour',
#   'day'],
#  ['encora',
#   'help',
#   'people',
#   'neurodegenerative',
#   'movement',
#   'disorder',
#   'regain',
#   'independence',
#   'control',
#   'life'],
#  ['encarte',
#   'browser',
#   'extension',
#   'bringing',
#   'oneclick',
#   'checkout',
#   'ecommerce',
#   'store'],
#  ['encaptiv',
#   'audience',
#   'engagement',
#   'platform',
#   'virtual',
#   'hybrid',
#   'inperson',
#   'presentation',
#   'event'],
#  ['exchangily',
#   'decentralized',
#   'exchange',
#   'model',
#   'based',
#   'fast',
#   'access',
#   'blockchain'],
#  ['everypig',
#   'groundbreaking',
#   'management',
#   'app',
#   'pig',
#   'owner',
#   'producer',
#   'veterinarian'],
#  ['blockchain',
#   'app',
#   'offer',
#   'service',
#   'anytime',
#   'anywhere',
#   'conversely',
#   'access',
#   'respond',
#   'demand',
#   'service'],
#  ['creating', 'data', 'hero', 'automated', 'data', 'pipeline'],
#  ['ethion',
#   'website',
#   'builder',
#   'tool',
#   'developing',
#   'sharing',
#   'website',
#   'across',
#   'various',
#   'social',
#   'medium'],
#  ['etherflyer', 'decentralized', 'exchange', 'built', 'ethereum'],
#  ['eternal',
#   'develops',
#   'avatar',
#   'social',
#   'network',
#   'offer',
#   'new',
#   'social',
#   'networking',
#   'experience'],
#  ['etailpet',
#   'facilitates',
#   'online',
#   'sale',
#   'creating',
#   'custom',
#   'online',
#   'store',
#   'independent',
#   'pet',
#   'retailer'],
#  ['fastai',
#   'elearning',
#   'site',
#   'offer',
#   'easy',
#   'use',
#   'software',
#   'developer',
#   'end',
#   'user',
#   'develops',
#   'educational',
#   'framework',
#   'model'],
#  ['fast',
#   'ship',
#   'analytics',
#   'providing',
#   'cutting',
#   'edge',
#   'data',
#   'strategy',
#   'data',
#   'engineering',
#   'data',
#   'science',
#   'solution'],
#  ['farmbee',
#   'application',
#   'help',
#   'financial',
#   'planning',
#   'insight',
#   'direct',
#   'sale',
#   'operation',
#   'marketing',
#   'small',
#   'local',
#   'farm'],
#  ['far', 'technology', 'aibased', 'cloud', 'software', 'platform', 'company'],
#  ['fantasy',
#   'quick',
#   'pick',
#   'allows',
#   'sport',
#   'fan',
#   'enjoy',
#   'contend',
#   'fantasy',
#   'sport',
#   'contest',
#   'offering',
#   'simple',
#   'fun',
#   'fair',
#   'format'],
#  ['peertopeer', 'parking', 'service'],
# ...
#   'community'],
#  ['scriptly',
#   'rx',
#   'brings',
#   'ethically',
#   'sourced',
#   'prescription',
#   'drug',
#   'discount',
#   'making',
#   'antibig',
#   'pharma',
#   'way',
#   'save',
#   'prescription',
#   'drug'],
#  ['scriptassist',
#   'pharmacy',
#   'online',
#   'retail',
#   'pharmacy',
#   'company',
#   'provides',
#   'medication',
#   'management',
#   'vitamin',
#   'supplement'],
#  ['screen', 'door', 'laboratory'],
#  ['scrappycito',
#   'job',
#   'search',
#   'tool',
#   'veteran',
#   'looking',
#   'transition',
#   'civilian',
#   'workforce'],
#  ['scout',
#   'fm',
#   'handcurated',
#   'podcast',
#   'radio',
#   'station',
#   'personalized',
#   'power',
#   'data',
#   'artificial',
#   'intelligence'],
#  ['scoremedia', 'platform', 'measure', 'score', 'thing', 'done', 'life'],
#  ['scoot',
#   'science',
#   'us',
#   'ai',
#   'deliver',
#   'accurate',
#   'underwater',
#   'weather',
#   'numerical',
#   'ocean',
#   'data',
#   'use',
#   'fish',
#   'farmer'],
#  ['scire',
#   'strategy',
#   'consultancy',
#   'specialzies',
#   'project',
#   'management',
#   'strategic',
#   'planning',
#   'performance',
#   'management',
#   'service'],
#  ['schoolrio',
#   'creating',
#   'new',
#   'market',
#   'online',
#   'education',
#   'student',
#   'simple',
#   'affordable',
#   'way',
#   'get',
#   'personalized',
#   'solution'],
#  ['schaller',
#   'garvin',
#   'associate',
#   'provides',
#   'billing',
#   'service',
#   'business',
#   'decision',
#   'support',
#   'medical',
#   'industry'],
#  ['scenethink',
#   'connects',
#   'event',
#   'creator',
#   'directly',
#   'local',
#   'influencers',
#   'drive',
#   'attendance',
#   'event'],
#  ['satisfactor',
#   'tool',
#   'spanish',
#   'measure',
#   'loyalty',
#   'customer',
#   'company',
#   'offer',
#   'survey',
#   'via',
#   'web',
#   'email'],
#  ['satira', 'provider', 'professional', 'comedy', 'coaching', 'service'],
#  ['transparent',
#   'riskmanaged',
#   'cryptocurrency',
#   'investment',
#   'fund',
#   'plus',
#   'digital',
#   'asset',
#   'education',
#   'investor',
#   'financial',
#   'advisor'],
#  ['santacom', 'official', 'site', 'santa', 'oh', 'yes', 'im', 'real'],
#  ['sander',
#   'consulting',
#   'provides',
#   'managed',
#   'service',
#   'cybersecurity',
#   'training',
#   'consulting',
#   'service',
#   'small',
#   'business'],
#  ['sandbox',
#   'system',
#   'software',
#   'company',
#   'created',
#   'collaborative',
#   'online',
#   'ide',
#   'called',
#   'makai'],
#  ['salvo',
#   'software',
#   'offer',
#   'software',
#   'erp',
#   'web',
#   'development',
#   'software',
#   'consulting',
#   'service'],
#  ['saltycloud',
#   'provides',
#   'access',
#   'workflow',
#   'automation',
#   'tool',
#   'help',
#   'maximize',
#   'impact',
#   'security',
#   'risk',
#   'team'],
#  ['salt',
#   'city',
#   'tech',
#   'offer',
#   'wide',
#   'range',
#   'consulting',
#   'information',
#   'technology',
#   'management',
#   'managed',
#   'service'],
#  ['salespype',
#   'software',
#   'solution',
#   'combine',
#   'crm',
#   'builtin',
#   'automation',
#   'solution'],
#  ['business', 'development', 'training', 'education', 'saas'],
#  ['premier',
#   'resource',
#   'peer',
#   'community',
#   'salesrevenue',
#   'leader',
#   'chicago',
#   'top',
#   'highgrowth',
#   'tech',
#   'company'],
#  ['local', 'data', 'science', 'firm'],
#  ['every', 'patient', 'deserves', 'safe', 'effective', 'medication'],
#  ['rxbridge',
#   'information',
#   'technology',
#   'health',
#   'care',
#   'service',
#   'industry',
#   'specialized',
#   'transparency',
#   'white',
#   'glove',
#   'customer',
#   'service'],
#  ['royce',
#   'technical',
#   'consulting',
#   'firm',
#   'specializes',
#   'search',
#   'recruiting'],
#  ['royal',
#   'specializes',
#   'document',
#   'management',
#   'printing',
#   'infrastructure',
#   'service'],
#  ['routefire',
#   'provider',
#   'trade',
#   'execution',
#   'infrastructure',
#   'digital',
#   'asset',
#   'space'],
#  ['route',
#   'dynamic',
#   'develops',
#   'platform',
#   'intended',
#   'automate',
#   'aviation',
#   'routing'],
#  ['rosint', 'lab', 'solves', 'problem', 'software', 'technology'],
#  ['rosebud',
#   'woman',
#   'make',
#   'exquisite',
#   'intimate',
#   'skin',
#   'body',
#   'care',
#   'formulation'],
#  ['root',
#   'banking',
#   'mobile',
#   'application',
#   'provides',
#   'digital',
#   'banking',
#   'financial',
#   'service'],
#  ['roomnett',
#   'shared',
#   'accommodation',
#   'roommate',
#   'finder',
#   'website',
#   'app',
#   'find',
#   'likeminded',
#   'roommate',
#   'share',
#   'home'],
#  ['rocketmomo', 'web', 'design', 'development', 'company'],
#  ['company', 'use', 'rocket', 'solve', 'recruiting', 'need'],
#  ['ondemand', 'mobile', 'store'],
#  ['roboamp', 'application', 'web', 'lightning', 'fast'],
#  ['robhat',
#   'lab',
#   'developer',
#   'online',
#   'web',
#   'browsing',
#   'tool',
#   'intended',
#   'tackle',
#   'spread',
#   'fake',
#   'news',
#   'misinformation'],
#  ['roastertools',
#   'keep',
#   'roastery',
#   'running',
#   'smoothly',
#   'business',
#   'profitable',
#   'focus',
#   'roasting',
#   'great',
#   'coffee'],
#  ['roam',
#   'research',
#   'tool',
#   'offer',
#   'service',
#   'notetaking',
#   'graph',
#   'database'],
#  ['rivet',
#   'lab',
#   'automation',
#   'software',
#   'develops',
#   'recurring',
#   'revenue',
#   'cash',
#   'forecasting',
#   'application'],
#  ['riskcast',
#   'solution',
#   'productivity',
#   'forecasting',
#   'tool',
#   'provides',
#   'way',
#   'project',
#   'manager',
#   'track',
#   'labor',
#   'material',
#   'equipment'],
#  ['risk',
#   'lab',
#   'open',
#   'source',
#   'protocol',
#   'synthetic',
#   'risk',
#   'transfer'],
#  ['rip',
#   'city',
#   'software',
#   'provides',
#   'microservices',
#   'architecture',
#   'coaching',
#   'education',
#   'service'],
#  ['accounting',
#   'firm',
#   'provider',
#   'cloud',
#   'accounting',
#   'software',
#   'growing',
#   'organization',
#   'florida',
#   'southeastern',
#   'u'],
#  ['rightair', 'developing', 'noninvasive', 'ventilator', 'copd', 'patient'],
#  ['rig',
#   'callout',
#   'cloudbased',
#   'communication',
#   'platform',
#   'provides',
#   'shipping',
#   'logistics',
#   'service'],
#  ['medium', 'based', 'review', 'site'],
#  ['ridealong',
#   'software',
#   'tool',
#   'give',
#   'patrol',
#   'officer',
#   'key',
#   'information',
#   'people',
#   'mental',
#   'illness'],
#  ['rhabits',
#   'lightweight',
#   'easytouse',
#   'platform',
#   'transforms',
#   'feedback',
#   'powerful',
#   'performance',
#   'insight',
#   'employee',
#   'manager',
#   'leadership'],
#  ['streamlined',
#   'procurement',
#   'distribution',
#   'used',
#   'supply',
#   'structure',
#   'access',
#   'egress',
#   'industrial',
#   'company'],
#  ['rewardzzz', 'blockchain', 'app'],
#  ['revokind',
#   'provides',
#   'blockchain',
#   'network',
#   'solution',
#   'developing',
#   'artificially',
#   'intelligent',
#   'autonomous',
#   'communication',
#   'system'],
#  ['review',
#   'maiden',
#   'creative',
#   'tool',
#   'review',
#   'management',
#   'allows',
#   'local',
#   'company',
#   'receive',
#   'feedback',
#   'automatically',
#   'current',
#   'customer'],
#  ['reverie', 'lab', 'machine', 'learningdriven', 'pharma', 'company'],
#  ['reveal',
#   'us',
#   'ai',
#   'advanced',
#   'natural',
#   'language',
#   'processing',
#   'advanced',
#   'analytics',
#   'address',
#   'threat',
#   'brand',
#   'reputation'],
#  ['retinaai',
#   'develop',
#   'artificial',
#   'intelligence',
#   'software',
#   'diagnosing',
#   'retinal',
#   'disease',
#   'image',
#   'retina'],
#  ['respirogen',
#   'feature',
#   'device',
#   'technology',
#   'provides',
#   'oxygen',
#   'independent',
#   'damaged',
#   'lung',
#   'like',
#   'acute',
#   'respiratory',
#   'distress',
#   'syndrome'],
#  ['scale',
#   'quality',
#   'customer',
#   'support',
#   'affordable',
#   'flexible',
#   'service',
#   'available'],
#  ['resermine', 'aienabled', 'platform', 'decision', 'making', 'surveillance'],
#  ['repetere',
#   'generates',
#   'automated',
#   'sale',
#   'product',
#   'mix',
#   'forecast',
#   'machine',
#   'learning',
#   'artificial',
#   'intelligence'],
#  ['rengen',
#   'lab',
#   'easiest',
#   'trusted',
#   'place',
#   'connect',
#   'company',
#   'issuing',
#   'private',
#   'equity',
#   'security',
#   'token',
#   'offering'],
#  ['remote', 'meeting', 'reinvented'],
#  ['remedia', 'advanced', 'medical', 'data', 'analytics', 'company'],
#  ['reliable',
#   'web',
#   'solution',
#   'platform',
#   'providing',
#   'wide',
#   'spectrum',
#   'service',
#   'related',
#   'creation',
#   'mobile',
#   'responsive',
#   'design',
#   'seo'],
#  ['relex',
#   'world',
#   'first',
#   'cryptocurrency',
#   'based',
#   'real',
#   'estate',
#   'developer',
#   'opportunity'],
#  ['related',
#   'work',
#   'research',
#   'product',
#   'strategy',
#   'firm',
#   'provides',
#   'data',
#   'research',
#   'product',
#   'strategy',
#   'company'],
#  ['refirm',
#   'lab',
#   'group',
#   'iot',
#   'security',
#   'expert',
#   'develops',
#   'new',
#   'method',
#   'vetting',
#   'validating',
#   'firmware'],
#  ['earn', 'cash', 'back', 'commission', 'thousand', 'store', 'brand'],
#  ['social', 'platform', 'bringing', 'wine', 'appreciation', 'everyone'],
#  ['redemption',
#   'technology',
#   'source',
#   'ecommerce',
#   'marketplace',
#   'platform',
#   'anonymously',
#   'allows',
#   'subscriber',
#   'pay',
#   'cryptocurrency',
#   'anywhere'],
#  ['red',
#   'sunflower',
#   'specializes',
#   'website',
#   'ecommerce',
#   'mobile',
#   'apps',
#   'ux',
#   'design',
#   'cybersecurity',
#   'help',
#   'business',
#   'improve',
#   'web',
#   'presence'],
#  ['red',
#   'mountain',
#   'scientific',
#   'provides',
#   'data',
#   'needed',
#   'effectively',
#   'manage',
#   'wind',
#   'turbine',
#   'cell',
#   'tower',
#   'asset'],
#  ['ai',
#   'based',
#   'application',
#   'personalizes',
#   'gift',
#   'purchasing',
#   'experience',
#   'special',
#   'life',
#   'event',
#   'like',
#   'birthday',
#   'anniversary'],
#  ['professional', 'networking', 'saas'],
#  ['recruitchute', 'recruiting', 'platform', 'college', 'soccer'],
#  ['recruitbot',
#   'provides',
#   'recruitment',
#   'service',
#   'using',
#   'big',
#   'data',
#   'machine',
#   'learning',
#   'technology'],
#  ['web', 'application'],
#  ['realty',
#   'shine',
#   'software',
#   'real',
#   'estate',
#   'integrated',
#   'website',
#   'property',
#   'management',
#   'marketing'],
#  ['realtime', 'digital', 'innovation', 'software', 'company'],
#  ['realitynext',
#   'education',
#   'technology',
#   'teen',
#   'make',
#   'share',
#   'vr',
#   'storygames'],
#  ['read',
#   'doc',
#   'focus',
#   'writing',
#   'high',
#   'quality',
#   'documentation',
#   'restructuredtext',
#   'markdown',
#   'specification'],
#  ['rare',
#   'bit',
#   'zerofee',
#   'peertopeer',
#   'marketplace',
#   'buy',
#   'sell',
#   'discover',
#   'crypto',
#   'good'],
#  ['rapid',
#   'imaging',
#   'provides',
#   'innovative',
#   'imaging',
#   'solution',
#   'significant',
#   'problem'],
#  ['real', 'estate', 'admin', 'made', 'simple'],
#  ['rannko',
#   'offer',
#   'full',
#   'stack',
#   'software',
#   'review',
#   'reputation',
#   'management',
#   'digital',
#   'presence',
#   'social',
#   'medium'],
#  ['help', 'nonprofit', 'acquire', 'retain', 'donor'],
#  ['raise',
#   'barr',
#   'technology',
#   'company',
#   'creates',
#   'corporate',
#   'diversity',
#   'inclusion',
#   'training'],
#  ['radix', 'lab', 'aim', 'operating', 'system', 'laboratory'],
#  ['one', 'pas', 'race', 'worldwide'],
#  ['r',
#   'score',
#   'mobile',
#   'responsive',
#   'collaborative',
#   'application',
#   'enables',
#   'government',
#   'efficiently',
#   'enforce',
#   'fair',
#   'hiring',
#   'legislation'],
#  ['data', 'orchestration', 'platform', 'consumer', 'fintech'],
#  ['quickze', 'restaurant', 'app'],
#  ['use',
#   'one',
#   'service',
#   'explore',
#   'broadcast',
#   'social',
#   'medium',
#   'currently',
#   'stealth',
#   'mode',
#   'launching',
#   'soon'],
#  ['quantum',
#   'softech',
#   'group',
#   'focus',
#   'development',
#   'erp',
#   'system',
#   'accounting',
#   'software',
#   'solution'],
#  ['complete', 'iot', 'platform', 'electronic', 'hobby', 'enthusiast'],
#  ['quantum',
#   'insight',
#   'find',
#   'hidden',
#   'meaning',
#   'complex',
#   'data',
#   'using',
#   'physic',
#   'quantum',
#   'mechanic'],
#  ['quantiport',
#   'innovative',
#   'technology',
#   'quickly',
#   'easily',
#   'accurately',
#   'measure',
#   'blood',
#   'volume'],
#  ['utilizing', 'new', 'technology', 'advance', 'medical', 'research'],
#  ['qlogix',
#   'entertainment',
#   'edtech',
#   'engages',
#   'child',
#   'background',
#   'learn',
#   'stem',
#   'fun',
#   'interactive',
#   'innovative',
#   'play'],
#  ['qknow',
#   'get',
#   'employee',
#   'engaged',
#   'learning',
#   'help',
#   'employee',
#   'remember',
#   'training',
#   'automates',
#   'process',
#   'save',
#   'time'],
#  ['q',
#   'empowers',
#   'healthcare',
#   'team',
#   'insightful',
#   'actionable',
#   'data',
#   'drive',
#   'improvement',
#   'patient',
#   'engagement',
#   'treatment',
#   'plan',
#   'adherence'],
#  ['pyrus',
#   'consulting',
#   'group',
#   'offer',
#   'enterprise',
#   'resource',
#   'planning',
#   'solution',
#   'service'],
#  ['modern', 'sale', 'operation', 'platform', 'retail'],
#  ['purepost',
#   'publicbenefit',
#   'corporation',
#   'veteran',
#   'veteran',
#   'champion'],
#  ['civic',
#   'engagement',
#   'platform',
#   'connecting',
#   'citizen',
#   'elected',
#   'representative'],
#  ['protosure',
#   'cloudbased',
#   'programmingfree',
#   'submit',
#   'underwrite',
#   'rate',
#   'quote',
#   'policy',
#   'issuance',
#   'system'],
#  ['propfuel', 'voice', 'member', 'platform', 'built', 'association'],
#  ['one', 'shortterm', 'rental', 'compliance'],
#  ['promanage',
#   'technology',
#   'company',
#   'working',
#   'iiot',
#   'ar',
#   'ai',
#   'technology',
#   'area',
#   'manufacturing',
#   'operation',
#   'management'],
#  ['prologmobile', 'mobile', 'device', 'analytics', 'transaction', 'company'],
#  ['projectric',
#   'combine',
#   'resource',
#   'management',
#   'project',
#   'management',
#   'single',
#   'project',
#   'portfolio',
#   'management',
#   'software',
#   'solution'],
#  ['build', 'meaningful', 'relationship'],
#  ['project',
#   'phoenix',
#   'software',
#   'company',
#   'develops',
#   'universal',
#   'business',
#   'web',
#   'service',
#   'toolset',
#   'every',
#   'developer',
#   'use'],
#  ['process',
#   'server',
#   'technology',
#   'powerful',
#   'webbased',
#   'platform',
#   'mobile',
#   'app',
#   'instantly',
#   'connects',
#   'law',
#   'firm'],
#  ['probability',
#   'statistic',
#   'provides',
#   'blockchain',
#   'development',
#   'artificial',
#   'intelligence',
#   'software',
#   'development',
#   'service'],
#  ['privops',
#   'offer',
#   'digital',
#   'transformation',
#   'platform',
#   'control',
#   'data'],
#  ['prime',
#   'foray',
#   'offer',
#   'cloud',
#   'computing',
#   'consulting',
#   'information',
#   'technology',
#   'marketing',
#   'service'],
#  ['prescribe', 'fit', 'promotes', 'adaptation', 'healthy', 'lifestyle'],
#  ['app',
#   'development',
#   'mobile',
#   'development',
#   'aws',
#   'io',
#   'app',
#   'development',
#   'android',
#   'app',
#   'development',
#   'backend',
#   'development',
#   'spring',
#   'angular'],
#  ['prepaid',
#   'program',
#   'management',
#   'prepaid',
#   'card',
#   'program',
#   'management',
#   'firm',
#   'develops',
#   'manages',
#   'payment',
#   'processing',
#   'solution'],
#  ['prelude',
#   'autonomous',
#   'red',
#   'team',
#   'tool',
#   'packaged',
#   'desktop',
#   'application'],
#  ['online',
#   'referral',
#   'marketplace',
#   'world',
#   'go',
#   'hire',
#   'refer',
#   'friend',
#   'find',
#   'job'],
#  ['predictmx',
#   'enables',
#   'company',
#   'make',
#   'informed',
#   'decision',
#   'operational',
#   'readiness',
#   'maintenance',
#   'need',
#   'mobile',
#   'equipment'],
#  ['predictive',
#   'trading',
#   'system',
#   'aipowered',
#   'datadriven',
#   'cloudbased',
#   'decision',
#   'making',
#   'investment',
#   'management'],
#  ['predictionhealth',
#   'automates',
#   'documentation',
#   'bringing',
#   'machine',
#   'learning',
#   'daily',
#   'clinical',
#   'practice'],
#  ['predictim',
#   'provides',
#   'new',
#   'innovative',
#   'way',
#   'vet',
#   'people',
#   'instantly',
#   'using',
#   'artificial',
#   'intelligence',
#   'alternative',
#   'data'],
#  ['precizion',
#   'solution',
#   'provides',
#   'data',
#   'science',
#   'analytics',
#   'service'],
#  ['virtual', 'socializing', 'recognition', 'platform', 'business', 'team'],
#  ['preceptor',
#   'security',
#   'group',
#   'developing',
#   'class',
#   'physical',
#   'security',
#   'program',
#   'system',
#   'technology',
#   'solution'],
#  ['prana',
#   'software',
#   'software',
#   'development',
#   'company',
#   'offer',
#   'custom',
#   'software',
#   'solution',
#   'enterprise'],
#  ['pozotron', 'develops', 'software', 'computer', 'speech', 'processing'],
#  ['potent',
#   'system',
#   'game',
#   'software',
#   'industry',
#   'provides',
#   'gambling',
#   'app',
#   'development',
#   'video',
#   'game'],
#  ['postalytics',
#   'selfserve',
#   'direct',
#   'mail',
#   'automation',
#   'tool',
#   'look',
#   'act',
#   'feel',
#   'like',
#   'digital',
#   'channel'],
#  ...]

# %%
dictionary = Dictionary(corpus+[query])
tfidf = TfidfModel(dictionary=dictionary)


# Create the term similarity matrix. 
# The nonzero_limit enforces sparsity by limiting the number of non-zero terms in each column. 
# For my application, I got best results by removing the default value of 100
similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)

# %%
# Compute Soft Cosine Measure between the query and the documents.
query_tf = tfidf[dictionary.doc2bow(query)]

index = SoftCosineSimilarity(
            tfidf[[dictionary.doc2bow(document) for document in corpus]],
            similarity_matrix)

doc_similarity_scores = index[query_tf]

# %%
# Output the similarity scores for top 15 documents
sorted_indexes = np.argsort(doc_similarity_scores)[::-1]
print(f'Query: \t {0} \t {titles[0]} \t {desc[0]}')
for idx in sorted_indexes[:15]:
    print(f'{idx} \t {doc_similarity_scores[idx]:0.3f} \t {titles[idx]} \t {desc[idx]}')
# Out:
# Query: 	 0 	 1 Accord Technologies 	 1 accord technology providing professional support business strive give client enterpriselevel service
# 2050 	 0.545 	 Double Loop Games 	 double loop game mobile studio dedicated making delightful relaxing experience biggest audience game
# 2334 	 0.518 	 ninecoves 	 strive help business get reliable timely insight make informationdriven decision develop datadriven culture
# 422 	 0.510 	 Gatherade 	 gatherade mobile application local social networking organizational tool
# 438 	 0.506 	 Groopit 	 groopit collaboration platform collect data cross functional remote decentralized team accelerate collaboration
# 1937 	 0.501 	 BrewStubs 	 brewstubs™ enables craft brewery event organizer attract engage build ongoing relationship beer lover
# 2444 	 0.493 	 3rdDegree App 	 building connection one conversation time
# 734 	 0.477 	 Surefyre 	 bringing efficiency modern consumerstyle insuretech massive market insurer currently access
# 1537 	 0.476 	 Gitcoin 	 gitcoin platform enables open source developer monetize work used
# 251 	 0.471 	 Counterfeit.Technology 	 counterfeittechnology kill counterfeiter dead track
# 293 	 0.471 	 Coveware 	 coveware aggregate global ransomware cyber extortion data minimize related cost downtime
# 15 	 0.452 	 Acuity PPM 	 lightweight project portfolio management ppm software new pmos
# 1957 	 0.450 	 Candu 	 candu product experience platform software team want design refine personalize application’s user interface
# 1628 	 0.448 	 Elevar Technologies 	 developes software help client work productively
# 1351 	 0.447 	 Kognos 	 kognos cloudbased detection investigation platform detects investigates responds attack campaign
# 2409 	 0.444 	 Quantum Narrative 	 future interactive storytelling quantum narrative revolutionizing way world learns via fun smart interactive story

# %%
#considering each row as a query
for i in range(0,len(tokens)):
    corpus = []
    query_string = tokens[i]
    documents = tokens[0:i]+tokens[i+1:]
    

#     corpus = [document for document in documents]
    corpus = documents
    query = query_string
    
    dictionary = Dictionary(corpus+[query])
    tfidf = TfidfModel(dictionary=dictionary)
    similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)
    
    query_tf = tfidf[dictionary.doc2bow(query)]

    index = SoftCosineSimilarity(
            tfidf[[dictionary.doc2bow(document) for document in corpus]],
            similarity_matrix)
    doc_similarity_scores = index[query_tf]
    
    sorted_indexes = np.argsort(doc_similarity_scores)[::-1]
    print(f'Query: \t {0} \t {titles[i]} \t {desc[i]}')
    for idx in sorted_indexes[:15]:
        print(f'{idx} \t {doc_similarity_scores[idx]:0.3f} \t {titles[idx]} \t {desc[idx]}')
# Out:
# Query: 	 0 	 1 Accord Technologies 	 1 accord technology providing professional support business strive give client enterpriselevel service
# 2050 	 0.545 	 Double Loop Games 	 double loop game mobile studio dedicated making delightful relaxing experience biggest audience game
# 2334 	 0.518 	 ninecoves 	 strive help business get reliable timely insight make informationdriven decision develop datadriven culture
# 422 	 0.510 	 Gatherade 	 gatherade mobile application local social networking organizational tool
# 438 	 0.506 	 Groopit 	 groopit collaboration platform collect data cross functional remote decentralized team accelerate collaboration
# 1937 	 0.501 	 BrewStubs 	 brewstubs™ enables craft brewery event organizer attract engage build ongoing relationship beer lover
# 2444 	 0.493 	 3rdDegree App 	 building connection one conversation time
# 734 	 0.477 	 Surefyre 	 bringing efficiency modern consumerstyle insuretech massive market insurer currently access
# 1537 	 0.476 	 Gitcoin 	 gitcoin platform enables open source developer monetize work used
# 251 	 0.471 	 Counterfeit.Technology 	 counterfeittechnology kill counterfeiter dead track
# 293 	 0.471 	 Coveware 	 coveware aggregate global ransomware cyber extortion data minimize related cost downtime
# 15 	 0.452 	 Acuity PPM 	 lightweight project portfolio management ppm software new pmos
# 1957 	 0.450 	 Candu 	 candu product experience platform software team want design refine personalize application’s user interface
# 1628 	 0.448 	 Elevar Technologies 	 developes software help client work productively
# 1351 	 0.447 	 Kognos 	 kognos cloudbased detection investigation platform detects investigates responds attack campaign
# 2409 	 0.444 	 Quantum Narrative 	 future interactive storytelling quantum narrative revolutionizing way world learns via fun smart interactive story
# Query: 	 0 	 1005 Ventures 	 venture capital
# 1289 	 1.000 	 Lasting 	 lasting relationship counseling company part talkspace online therapy company
# 2524 	 1.000 	 Nytro.ai 	 pitch intelligence saas platform rep onboarding readiness
# 2275 	 0.979 	 Madiwor 	 madiwor cloud management information system specifically designed label manufacturer
# 1405 	 0.907 	 Hyperobjekt 	 hyperobjekt digital agency specializing data visualization web development nonprofit sector
# 132 	 0.900 	 BlockTelegraph 	 block telegraph leading source blockchain cryptocurrency news finance technology reader outside industry
# 448 	 0.900 	 Harvest Platform 	 harvest platform identifies negotiable bank fee get refund automatically
# 2014 	 0.880 	 Curated Planet 	 curated planet provides mobile solution keep tour operator traveler sync
# 569 	 0.828 	 Virtual Distance International 	 virtual distance international software solution company
# 1111 	 0.823 	 Noisy Trumpet 	 noisy trumpet specializes digital marketing advertising web development social medium management public relation
# 214 	 0.823 	 Clerkie 	 clerkie ai financial planner 123m underserved american looking answer
# 1226 	 0.820 	 LVL 	 lvl fdicinsured mobile banking app exchange cash  bitcoin free  invest easily autopilot
# 581 	 0.818 	 Vertispan 	 vertispan specializes software development ecosystem support gwt compiler
# 345 	 0.818 	 Digital Water Works 	 digital water work engineering technology solution provider dedicated innovating exclusively global water industry
# 1510 	 0.803 	 Funderdog™ 	 messaging fundraising automation mobile saas charity
# 133 	 0.771 	 Blocktown Capital 	 blocktown capital investment fund focused exclusively blockchain venture digital currency application token
# Query: 	 0 	  1533 Systems, Inc.  	 live data platform ingest process respond operate live data system scale
# 1259 	 0.580 	 Little Lion 	 little lion provides family activity nutrition yoga kickboxing art wellness via online interactive platform
# 132 	 0.533 	 BlockTelegraph 	 block telegraph leading source blockchain cryptocurrency news finance technology reader outside industry
# 1260 	 0.533 	 Live CGI 	 live cgi software platform enable make live branded content
# 76 	 0.533 	 Auxon 	 auxon software company enables ai  system engineer build safe resilient system
# 2264 	 0.531 	 Lionize 	 digital prezence advertising technology company focus influencer campaign email marketing market research
# 2233 	 0.525 	 Keydabra 	 artificial intelligence saas
# 1196 	 0.523 	 Muviware by Entertainment Cloud Solutions 	 enterprise cloudbased saas platform changing way cinema maximize business knowing targeting customer
# 1152 	 0.523 	 MVC Interactive 	 mvc interactive provides custom development service salesforce service app solution service web consulting service
# 381 	 0.522 	 EveryPig 	 everypig groundbreaking management app pig owner producer veterinarian
# 1184 	 0.512 	 Moxi Platform 	 moxi saas platform manages maintains house vehicle
# 1164 	 0.512 	 MSBAI 	 msbai developer platform creates solve expertisebarrier problem engineering
# 1098 	 0.506 	 Oakscale 	 scaling exciting brand franchising
# 2877 	 0.502 	 Stronghold Digital Mining 	 stronghold digital mining operates power generation facility convert waste coal used mine bitcoin cryptocurrencies
# 179 	 0.502 	 Cameyo 	 cameyo cloudnative window application transformation platform atp delivers window application device browser
# 1445 	 0.499 	 HERO Foundry 	 earlystage education technology event organization dedicated sharing hero journey tool world
# Query: 	 0 	 17 TeraWatts 	 17 terawatts clean energy software company
# 330 	 0.637 	 DemandStar Corporation 	 demandstar connects business local government contracting opportunity
# 2222 	 0.599 	 itiliti 	 itiliti provides human capital management solution buyer supplier staffing service
# 856 	 0.545 	 Seva 	 seva unified search platform help knowledge worker discover organize information need work
# 85 	 0.531 	 Axia CPQ 	 axia cpq salesforce partner help achieving greatest possible return salesforce investment
# 757 	 0.527 	 Stitchbridge 	 stitchbridge creator develop engaging interactive 360content mobile device
# 2972 	 0.525 	 ClothesLyne 	 clotheslyne develops online mobile marketplace connects customer variety laundry service provider
# 1804 	 0.517 	 Abridge News 	 abridge news developer news application designed provide quick fact argument side
# 1036 	 0.516 	 Pearl Street Technologies 	 pearl street technology develops nextgeneration software electric utility industry
# 1624 	 0.500 	 Elderosity 	 elderosity senior placement management software senior placement adviser
# 1870 	 0.490 	 Apte 	 data analytics saas platform 40bn donorrelations industry
# 765 	 0.489 	 SteadiPay 	 making sure small business dont run cash
# 2806 	 0.489 	 SmallTalk 	 smalltalk online language simulator improves english speaking skill prepare ielts toefl job interview
# 2614 	 0.489 	 Slap 	 let fun begin slap sound like plan new videobased social planning app supercharges social life
# 1786 	 0.484 	 ConferenceCast 	 conferencecasttv knowledge platform publish access conference video replay ondemand
# 1605 	 0.482 	 FactSquared 	 factsquared build product let know others don’t
# Query: 	 0 	 3DIQ 	 3diq make beyond easy recruiter edit format get realtime feedback candidate submittals
# 391 	 0.600 	 Far Technologies 	 far technology aibased cloud software platform company
# 1075 	 0.543 	 Openmind 	 openmind chatbased mentoring designed connect mentor develop skill
# 2071 	 0.525 	 Equip ID 	 equip id connects mechanical equipment digital world using nfc tag deliver equipmentspecific data supportive content
# 2241 	 0.521 	 LawDesk360 	 lawdesk360 artificial intelligence workflow efficiency platform help enterprise legal organization
# 2972 	 0.512 	 ClothesLyne 	 clotheslyne develops online mobile marketplace connects customer variety laundry service provider
# 611 	 0.496 	 uLumos 	 ulumos marketing automation solution run business
# 1407 	 0.449 	 I.T. Consulting St Petersburg 	 consulting st petersburg company specializes network infrastructure
# 1804 	 0.442 	 Abridge News 	 abridge news developer news application designed provide quick fact argument side
# 766 	 0.441 	 Status Fuel 	 status brings gas station mobile gas delivery ensuring safe clean convenient method fuel vehicle
# 2015 	 0.434 	 Cyberhill Partners 	 venture capital firm focused disruptive timely earlystage technology company utilize platform portfolio firm
# 698 	 0.432 	 Tech Argonauts 	 tech argonaut specialize aws cloud virtual cto service
# 1561 	 0.430 	 Flutter Social 	 flutter social virtual event planning marketplace using ai insight  virtual planner help user plan great event  hire vendor
# 1705 	 0.428 	 deepgreen 	 deepgreen develop artificial intelligence computer vision technology agriculture equipment
# 2488 	 0.428 	 LinqPal 	 linqpal payment financing platform construction industry
# 2317 	 0.424 	 MyTotem 	 mytotem artificial intelligence aipowered brand maker used create beautiful design
# Query: 	 0 	 3P Touch Media 	 3p touch medium mobile application development startup
# 2482 	 0.708 	 Launch House 	 launch house community medium company top entrepreneur
# 2699 	 0.672 	 Paydrop 	 payment infrastructure gigeconomy future work
# 1448 	 0.651 	 Hexabu 	 hexabu software company develops salesforce appexchange apps event monitoring
# 2607 	 0.634 	 Sillo 	 sillo mobile application help student build confidence initial anonymous conversation
# 2783 	 0.634 	 Ryan Paonessa Design 	 ryan paonessa design provides web brand identity design development consulting
# 105 	 0.627 	 Bema Creative 	 bema creative delivers branding website creation animation logo design trade show social medium campaign service
# 50 	 0.605 	 Archeads 	 archeads real estate property management firm dealing floorplans service
# 2513 	 0.604 	 Monumental 	 monumental specializes development mobile game
# 873 	 0.603 	 Scire Strategies 	 scire strategy consultancy specialzies project management strategic planning performance management service
# 1048 	 0.601 	 Partake. 	 partake make easy order purchase pay smartphone express pick ondemand delivery
# 688 	 0.596 	 Terciv 	 blockchain news platform
# 826 	 0.596 	 Sketchbox 	 sketchbox offer design interactive prototype vrar
# 2613 	 0.588 	 SkyX Group 	 skyx group inc focus design manufacture distribution consumer hardware medical device
# 2807 	 0.588 	 Slim.AI 	 slimai help application developer create build deploy run cloud native apps zero friction complexity waste
# 2087 	 0.581 	 Fast River Technologies 	 fast river technology provides healthcare data repository software  solution architecture design webbased application service
# Query: 	 0 	 4Di 	 4di data analytics platform architecture engineering construction industry
# 419 	 0.824 	 Fly with Breeze 	 fly breeze currently operating stealth mode
# 1799 	 0.817 	 8 Bit Development Inc. 	 8 bit development inc immersive technology development consulting firm located phoenix arizona
# 1077 	 0.808 	 Opas AI Inc 	 leveraging big data  neural net automate infrastructure
# 2782 	 0.786 	 Sa Wea Luxury 	 sa wea luxury operates technological luxury cannabis brand
# 2586 	 0.786 	 Ridepanda 	 ridepanda online eride shop offer electric vehicle maintenance support theft protection
# 1451 	 0.746 	 HEY MARY 	 hey mary patentpending intelligent athome cannabis dispensing platform
# 328 	 0.732 	 Denovium 	 denovium artificial intelligence company pioneering novel ai method accelerate innovation biopharma
# 354 	 0.723 	 DrDojo 	 healthcare saas
# 696 	 0.718 	 TechSpecs 	 ai driven search engine product technical specification
# 899 	 0.706 	 Roomnett 	 roomnett shared accommodation roommate finder website  app find likeminded roommate share home
# 414 	 0.703 	 Foxteria 	 foxteria interactive web development company bangalore provides fresh creative  interactive web solution business
# 2003 	 0.700 	 ConnectBooks 	 connectbooks amazon fba bookkeeping software provides integration profit dashboard amazon fba seller
# 2304 	 0.698 	 Mona 	 mona let anyone create webpage start selling skill online instantly
# 2790 	 0.678 	 Sensitive Home 	 sensitive home manufacturer seller plantbased cleaning solution designed customer sensitive skin
# 2600 	 0.678 	 Semiotic AI 	 semiotic ai provides encrypted computing service cloud based fully homomorphic encryption fhe
# Query: 	 0 	 ABYA 	 abya developer provider technological component creation graphic virtualization cloudgaming solution
# 1130 	 0.591 	 Neon Coat 	 neon coat groundbreaking io app taking model  brand next level
# through organic social marketing
# 1167 	 0.591 	 Move 37 	 move 37 provides applied artificial solution help navigate work desktop file application browser tab
# 1038 	 0.581 	 Peach Education 	 peach education provider student development platform
# 1432 	 0.575 	 Hatfactory 	 hat factory digital agency design mobile web application organization company
# 2973 	 0.550 	 Clay 	 clay help team create better 3d model letting artist upload 3d model share link provide view feedback realtime
# 1816 	 0.530 	 Ad Reform 	 ad reform intelligent assistant ad operation
# 475 	 0.501 	 ZoomSymbols.com 	 global financial market analytics mobile app
# 2177 	 0.498 	 Hellosaurus 	 hellosaurus elearning site child provides creative service engaging game video course
# 313 	 0.496 	 DataStreet 	 saas project management platform construction
# 1241 	 0.494 	 MarHub 	 marhub migration management platform
# 1655 	 0.493 	 Dispenserly 	 dispenserly provider online software platform intended manage monitor review identify new opportunity trend
# 1296 	 0.491 	 Lea (Live Event Assistant) 	 ai concierge help live event fan discover event purchase ticket via text messaging
# 1798 	 0.489 	 580 Strategies 	 580 strategy help establish digital structure organization need achieve success
# 1368 	 0.488 	 Integrātz 	 integrātz consulting training company specializes intelligent automation
# 2054 	 0.486 	 DriveMatch 	 drivematch provider job search platform used match commercial driver carrier operator
# Query: 	 0 	 Accelitude LLC 	 accelitude llc   company deal digital  cloud service solution
# 2340 	 0.635 	 Operation Labs 	 operation small vcbacked technology search lab started 2019
# 2950 	 0.575 	 Entrepreneurship Education Vietnam 	 10year universal education project activate inspire accelerate entrepreneurship vietnam
# 132 	 0.569 	 BlockTelegraph 	 block telegraph leading source blockchain cryptocurrency news finance technology reader outside industry
# 1651 	 0.561 	 DinDin Party 	 dindin party developer digital medium software
# 1293 	 0.557 	 LawPal 	 ai lawyer pocket
# 2191 	 0.555 	 Hypepilot 	 hypepilot open marketplace empowers business influencers connect business
# 448 	 0.548 	 Harvest Platform 	 harvest platform identifies negotiable bank fee get refund automatically
# 2974 	 0.535 	 Classpe 	 classpe elearning firm provides training neet personal transformation class 12th science course
# 1289 	 0.528 	 Lasting 	 lasting relationship counseling company part talkspace online therapy company
# 1 	 0.528 	 1005 Ventures 	 venture capital
# 2668 	 0.525 	 Tuna 	 open source software allows company easily integrate many different payment provider
# 2843 	 0.525 	 Terra.do 	 terrado operates online climate school
# 1861 	 0.522 	 Alula 	 alula develops digital platform designed cancer patient caregiver
# 1513 	 0.522 	 fusionlab.io 	 fusionlabio offer experimentation platform remove risk digital innovation transformation
# 2180 	 0.515 	 Hedron Vision 	 hedron vision software developer brings 3d experience 2d screen without extra hardware
# Query: 	 0 	 Accelor 	 accelor provides hardware solution intended blockchain ai business
# 97 	 0.516 	  BE Local, Inc.  	 travel curation platform
# 1595 	 0.497 	 Exsulcoin 	 blockchain technology platform
# 1039 	 0.489 	 PayVMS 	 payvms software development technology company providing information technology solution financial service company
# 1966 	 0.481 	 CarSnoop 	 carsnoop app allows user buy lease car phone computer
# 1579 	 0.480 	 EVAN360 	 instant personalized support platform improves productivity help organization thrive
# 575 	 0.475 	 Vicicit 	 vicicit cloud based candidate generation system cgs
# 1318 	 0.475 	 Life Snapshot 	 life snapshot digital storage vault protects personal asset final wish critical document
# 64 	 0.471 	 Atom Computing 	 atom computing build truly scalable quantum computer individual atom
# 2411 	 0.468 	 Qualtik 	 stop managing commercial real estate asset spreadsheet
# 1919 	 0.466 	 BLISSWAY 	 blissway developing new tolling technology give ability maintain free flow condition highway 247
# 851 	 0.466 	 Sherpas Cyber Security Group 	 sherpa cyber security group information technology cyber security develops comprehensive security solution
# 2369 	 0.466 	 Pilota 	 pilota leverage machine learning predict flight disruption automatically rebook traveler flight ahead time
# 455 	 0.465 	 Hammr 	 hammr network hardest working construction professional earth
# 2299 	 0.464 	 Montague Labs 	 full service digital product agency
# 2017 	 0.463 	 Daizy 	 b2bb2c interior design saas tool
# Query: 	 0 	 Accounting Panel 	 accounting panel cloudbased accounting tool designed help entrepreneur control business finance anytime anywhere
# 960 	 0.610 	 Quic 	 use one service explore broadcast social medium currently stealth mode launching soon
# 2419 	 0.609 	 Proteus Games 	 proteus game mobile development company working mobile game publisher
# 1701 	 0.591 	 DealValue 	 saas based service platform
# 1287 	 0.582 	 LandOne Takeoff 	 landone takeoff pdf annotation measurement software landscape irrigation contractor
# 1761 	 0.582 	 Codela 	 codela developing cloudbased solution coding interview
# 618 	 0.582 	 Twelve Seas Investment Company 	 blank check company
# 493 	 0.573 	 Zegura 	 ai ml dl iot face recognition consumer loyalty full stack sd cloud fog prem
# 2636 	 0.572 	 Sunny75 	 sunny75 mobile app provides outdoor camp planning application backpacking adventure
# 2936 	 0.572 	 HIgh Impact Sportwear 	 high impact sportwear company design manufacture marketing sportswear
# 2045 	 0.571 	 DNProtect 	 dnprotect internet’s leading risk management service internet domain name
# 910 	 0.564 	 Rip City Software 	 rip city software provides microservices architecture coaching  education service
# 2095 	 0.561 	 FINESSE 	 finesse fashion house leverage ai big data community feedback predict trend optimize distribution
# 2992 	 0.557 	 Arrive 	 arrive make investing vacation rental easy buying stock
# 181 	 0.557 	 Candl 	 mobile stock market application pattern recognition technology watchlist push notification
# 990 	 0.555 	 PredictMX 	 predictmx enables company make informed decision operational readiness maintenance need mobile equipment
# Query: 	 0 	 ACE IoT Solutions 	 ace iot solution offer secure managed platform collecting aggregating visualizing facility operation
# 1235 	 0.452 	 Magna Marketing 	 magna marketing digital transformation consulting firm specializes implementation advisory service managed service
# 788 	 0.444 	 Speakeasy AI 	 speakeasy ai make easier business understand respond customers’ need voice ai
# 2223 	 0.426 	 Iteright 	 iteright help software product team create solution customer need guided datadriven validation activity
# 829 	 0.415 	 SimpleForms 	 simpleforms demystifies mandatory employment document turning question making easier exchange store understand
# 1270 	 0.414 	 Logicluster 	 logicluster aiml currency pricing software remittance payment industry
# 435 	 0.413 	 Givingli 	 mobile gifting modern consumer send digital greeting designed independent artist along egifts favorite brand
# 880 	 0.413 	 Santa.com 	 santacom  official site santa oh yes im real
# 785 	 0.412 	 Spectiv 	 spectiv virtual reality streaming platform
# 2317 	 0.409 	 MyTotem 	 mytotem artificial intelligence aipowered brand maker used create beautiful design
# 1375 	 0.409 	 inviteme 	 inviteme application securely find schedule available time company
# 1752 	 0.406 	 Cloud Cover 	 cloud cover firm offer iaa daas cloud architecture network security realtime monitoring consultation service
# 2324 	 0.403 	 MuseDev 	 musedev innovative code analysis platform
# 2828 	 0.401 	 Symbo 	 sale engagement platform
# 2654 	 0.401 	 Symbo 	 sale engagement platform
# 2806 	 0.400 	 SmallTalk 	 smalltalk online language simulator improves english speaking skill prepare ielts toefl job interview
# Query: 	 0 	 Acsibi Studios 	 acsibi studio mobile game development company located acton
# 1798 	 0.431 	 580 Strategies 	 580 strategy help establish digital structure organization need achieve success
# 1453 	 0.419 	 Hi Five Web 	 hi five web render app development graphic design web design internet marketing branding strategy content writing service
# 2922 	 0.407 	 Latindi 	 latindi curated marketplace retailer connect best latin american brand stock shelf riskfree
# 1983 	 0.400 	 ClarityPark 	 mordern online organizer
# 1263 	 0.400 	 Livenpeace 	 fan club famous sportsman sport team show business star
# 761 	 0.394 	 Stephan and Stephan 	 stephan stephan provider payment processing cash flow management solution
# 2512 	 0.393 	 Momentum Consulting Group 	 momentum consulting group management consulting firm specializes product business process project software development
# 2049 	 0.392 	 Docuvision 	 docuvision aipowered personal data management platform company make privacy easy
# 2176 	 0.385 	 Hey Healthcare 	 hey healthcare provides healthcare software designed automate medical billing
# 998 	 0.376 	 Pozotron 	 pozotron develops software computer speech processing
# 801 	 0.366 	 Somewear Labs 	 somewear satellite communication solution designed increasingly digital world
# 1277 	 0.366 	 Lumatic 	 lumatic operator photography company aimed capture share individual story
# 1534 	 0.365 	 Ghost House Technology 	 ghost house ip technology startup focus application artificial intelligence computing technology
# 1551 	 0.363 	 Fitbe 	 next generation fitness app provides access classesgymsstudios near
# 2294 	 0.361 	 MemryX 	 memryx developing inmemory computing system aimed improve cpugpu computing architecture dataintensive task
# Query: 	 0 	 ACTIO 	 actio modular based software service analytics platform designed restaurant service
# 1002 	 0.557 	 PopUp Shops 	 connecting brand  space taking hassle finding retail space  popup brand work
# 104 	 0.537 	 Below the Fold 	 fold us machine learning provide automatic context news article
# 2586 	 0.528 	 Ridepanda 	 ridepanda online eride shop offer electric vehicle maintenance support theft protection
# 2782 	 0.528 	 Sa Wea Luxury 	 sa wea luxury operates technological luxury cannabis brand
# 1359 	 0.527 	 Inovium 	 inovium full erp service provider leveraging combination expertise innovation
# 1781 	 0.525 	 Compute Software 	 compute software cloud optimization platform maximizes cloud cost saving performance engineering productivity
# 112 	 0.511 	 Biocanic 	 biocanic first kind health program intelligence system designed streamline health program integrative practitioner
# 2573 	 0.508 	 Quipr 	 people culture communication
# 2740 	 0.508 	 Rangr 	 rangr new app help make outdoors exciting fun safe
# 1676 	 0.505 	 Duadle 	 duadle ai based relationship management app
# 2898 	 0.498 	 Pattycake Playhouse 	 pattycake playhouse daycare preschool maximum capacity 139 child ranging 8 week old 12 year old
# 1245 	 0.495 	 lifeID 	 lifeid opensource tokenized protocol selfsovereign identity
# 2961 	 0.495 	 Dendro 	 creative growth partner ambitious leader
# 2057 	 0.493 	 Edgevana 	 edgevana global marketplace automating data centre procurement process
# 738 	 0.484 	 Summerlight 	 summerlight operates stealth mode
# Query: 	 0 	 Activeconnect 	 activeconnect work type device operating system every transaction including io android window mac o
# 1554 	 0.585 	 FLEAT StreetLogic® 	 streetlogic patented selfdelivery platform provides retailer automation predictability control last mile logistics
# 1859 	 0.534 	 Alter 	 alter domain marketplace connects entrepreneur premium business name
# 83 	 0.529 	 Axel Technologies 	 axel technology software developer investing technology infrastructure
# 75 	 0.526 	 Autymate 	 autymate develops software solution like accounting hr healthcare automation apps help reduce time
# 1898 	 0.498 	 Autonomous Directive Ventures 	 autonomous application saas mobility research smart city human interface technology
# 68 	 0.495 	 Attunely 	 attunely produce machine learning model debt collection decreasing waste improving recovery yield
# 998 	 0.493 	 Pozotron 	 pozotron develops software computer speech processing
# 1502 	 0.493 	 FriendSpot 	 friendspot group messaging app help coordinate friend meet real world
# 1913 	 0.488 	 BizTech Plus 	 biztech plus offer network management software administration technology planning disaster recovery web presence assistance
# 483 	 0.481 	 Zippy.ai 	 zippy team fieldleaders engineering robotics computer vision machine learning design
# 2264 	 0.480 	 Lionize 	 digital prezence advertising technology company focus influencer campaign email marketing market research
# 1504 	 0.480 	 Frontdoor 	 frontdoor enterprise saas platform dedicated simplifying work real estate professional smb large enterprise company
# 2491 	 0.478 	 LIT 	 lit inputbased languageacquisition tool student teacher
# 762 	 0.478 	 Stem 	 online recording studio connects skilled musician open project
# 1680 	 0.473 	 Early Stage Podcast 	 early stage podcast devoted interviewing top entrepreneur seed series stage startup
# Query: 	 0 	 Acuity PPM 	 lightweight project portfolio management ppm software new pmos
# 977 	 0.573 	 PrologMobile 	 prologmobile mobile device analytics transaction company
# 811 	 0.534 	 SMC Squared 	  smc squared llc provides disruptive alternative service industry
# 1202 	 0.527 	 Menta AR 	 augmented reality marketing branding ecommerce viral
# 762 	 0.520 	 Stem 	 online recording studio connects skilled musician open project
# 1701 	 0.519 	 DealValue 	 saas based service platform
# 2924 	 0.513 	 KwikPick 	 online marketplace platform connect merchant customer pickup merchant product
# 2656 	 0.512 	 Swing Racquet + Paddle 	 swing racquet  paddle operator sport campus offer indoor covered court well fitness facility
# 2830 	 0.512 	 Swing Racquet + Paddle 	 swing racquet  paddle operator sport campus offer indoor covered court well fitness facility
# 2676 	 0.511 	 Viell 	 viell ai based digital membership club enables member network effectively audio video
# 1357 	 0.511 	 Innsena Communications 	 innsena communication serf company healthcare technology sector strategic marketing public relation counsel
# 2378 	 0.504 	 pH Networks 	 cyber security home  simplified
# 345 	 0.502 	 Digital Water Works 	 digital water work engineering technology solution provider dedicated innovating exclusively global water industry
# 1006 	 0.502 	 POOT 	 poot ridesharing mobile app public transportation industry
# 986 	 0.500 	 PREPUBLISH 	 app development mobile development aws io app development android app development backend development spring angular
# 1240 	 0.497 	 Margin 	 smart shopping email alias happier inbox
# Query: 	 0 	 ACW Analytics 	 deliver insight help asset manager plan react extreme weather event
# 1957 	 0.528 	 Candu 	 candu product experience platform software team want design refine personalize application’s user interface
# 2527 	 0.503 	 Oceana 	 oceana innovation process  technology platform support organization aspiring become innovative culture
# 2750 	 0.466 	 PWRFWD 	 pwrfwd online marketplace drive athlete consumer industry
# 581 	 0.464 	 Vertispan 	 vertispan specializes software development ecosystem support gwt compiler
# 575 	 0.461 	 Vicicit 	 vicicit cloud based candidate generation system cgs
# 1508 	 0.452 	 Functionaire 	 functionaire provides ux  ui design ux research ux strategy service
# 416 	 0.448 	 Foresite.ai 	 foresite saas platform providing predictive analytics geovisualization commercial real estate investor angelpad 12
# 1725 	 0.442 	 Conversive 	 conversive offer enterprise solution solving problem simulating facetoface conversation scale
# 1560 	 0.438 	  Fluentz, Inc.  	 silicon valley boutique software consultancy
# 871 	 0.429 	 ScoreMedia 	 scoremedia platform measure score thing done life
# 2099 	 0.424 	 FlareAgent 	 flareagent endtoend real estate transaction management software realtor
# 883 	 0.421 	 Salvo Software 	 salvo software offer software erp web development software consulting service
# 2215 	 0.417 	 Jetsy 	 jetsy travel technology platform change way consumer plan travel experience
# 2810 	 0.417 	 SkyFort 	 secure internetasaservice
# 1357 	 0.417 	 Innsena Communications 	 innsena communication serf company healthcare technology sector strategic marketing public relation counsel
# Query: 	 0 	 Ad Fontes Media 	 ad fontes medium public benefit corporation rate news founded vanessa otero creator medium bias chart®
# 1380 	 0.467 	 iSimu VR 	 isimu vr premier virtual reality entertainment arcade offering 40 unique virtual reality experience
# 1834 	 0.438 	 AccurKardia 	 cardiac ai healthcare iot
# 1254 	 0.425 	 LionX 	 lionx help company create customer trust  loyalty privacy experience transparency responsiveness
# 135 	 0.377 	 BlockVigil 	 blockvigil help build scale blockchain apps line code
# 1250 	 0.376 	 Lily.Health 	 lilyhealth building best reproductive health tool using latest technology research
# 1816 	 0.376 	 Ad Reform 	 ad reform intelligent assistant ad operation
# 1398 	 0.367 	 Humbleteam 	 humbleteam product design company
# 1042 	 0.362 	 PayCafe.com 	 endtoend payment solution
# 1895 	 0.360 	 Authentic Artists 	 aipowered virtual artist platform purposebuilt music gaming streaming application
# 41 	 0.358 	 Apoll01 	 apoll01 open platform surfacing need education institution collaborating reaching consensus establish standard
# 523 	 0.357 	 Woko Loco 	 serving kindness spreading positivity customizable delicious nutritious wok
# 2473 	 0.356 	 KEAZE 	 keaze future restaurant smart kitchen technology restaurant thrive new food economy
# 1931 	 0.351 	 Boutiq 	 smart datadriven luxury hospitality brand  techstars austin 2020
# 306 	 0.350 	 Cue Intelligence 	 cue intelligence provides sale service scripting software conversational intelligence
# 1486 	 0.348 	 GreenFig 	 greenfig micro education company providing digital skill training applied business science
# Query: 	 0 	 Ad Genius 	 ad genius provides marketing solution based exceptional technical talent creative power
# 2214 	 0.792 	 Jivoo 	 jivoo cloud consulting service company
# 1994 	 0.784 	 Code Vapor 	 code vapor consulting company delivers corporatelevel critical service emphasis affordability
# 1074 	 0.767 	 OppNLyfe 	 oppnlyfe website  mobile app help organize vacation different adventure user ab az
# 2303 	 0.763 	 Monday Night Mentorship 	 monday night mentorship creates mentoring leadership development program accelerate impact marketer
# 2033 	 0.752 	 Desert Lab Studio 	 desert lab studio provides web design  development internet marketing business consulting service
# 2615 	 0.747 	 Slim.AI 	 slimai help application developer create build deploy run cloud native apps zero friction complexity waste
# 2805 	 0.747 	 Smart Metrics 	 daily analytics marketing task
# 211 	 0.747 	 ClearAT 	 clearat technology startup provides automated sale process allows u save time
# 1043 	 0.739 	 Paybird 	 paybird enables business accept payment via social medium
# 154 	 0.728 	 Bounce 	 short term hourly  daily storage around urban area hosted local business
# 2631 	 0.728 	 STYNGR 	 styngr online store offering ingame music experience latest popular track player
# 2062 	 0.728 	 Ello 	 world’s first ai reading coach work real book
# 2622 	 0.685 	 splashmob 	 splashmob computer software company specializes live event
# 2686 	 0.665 	 Wingmen 	 wingman offer demand personalized driver service corporate event business owner individual mobile app
# 2036 	 0.664 	 Dex 	 dex personal crm give relationship superpower
# Query: 	 0 	 Aersys Inc. 	 automated microfulfillment center drone rover delivery
# 181 	 0.424 	 Candl 	 mobile stock market application pattern recognition technology watchlist push notification
# 2009 	 0.411 	 Counterpart 	 counterpart insurtech startup company work management liability insurance market
# 1672 	 0.401 	  DRiVR AI, Inc.  	 drivrai score vehicle driving performance analyzes data ass risk provides tool protect driver improve performance
# 2421 	 0.401 	 Prompt 	 supercharged contact app busy professional
# 521 	 0.401 	 Woofpage 	 woofpage online pet community pet owner every pet star
# 583 	 0.400 	 VeriCite 	 vericite provides originality checking tool provide tight integration lm workflow smooth customer experience
# 2318 	 0.395 	 Myntor 	 myntor build online course help student outperform traditional classroom providing realtime feedback using conversational ai
# 2942 	 0.383 	 Foodvine 	 foodvine new way order discover authentic food home chef local farmer food truck operator
# 1719 	 0.380 	 Contabulo 	 contabulo general purpose board suitable knowledge management project planning team collaboration
# 1771 	 0.369 	 Columbia Blockchain Alliance 	 columbia blockchain alliance internet firm educates student alumnus  employee aspect blockchain  cryptocurrencies
# 2766 	 0.368 	 Seaplane IO 	 seaplane io serverless cloud modern enterprise allowing customer deploy function everywhere
# 1864 	 0.358 	 Amplifinn 	 amplifinn digital transformation innovation solution company
# 2335 	 0.346 	 Next Alpha 	 next alpha quantitative longshort strategy designed deliver superior return limited risk
# 38 	 0.338 	 Apaly Health 	 apaly health enables employer provider direct contract scale
# 2200 	 0.336 	 Home Service AI 	 guest engagement hospitality automation platform
# Query: 	 0 	 Agamon 	 agamon aipowered healthcare platform convert clinical text structured data
# 1085 	 0.521 	 OneClick.ai 	 oneclickai provides automated platform enables business developer access ai
# 1878 	 0.517 	 Ardira 	 ardira known salesforce isv partner offer tailored apps salesforce appexchange
# 395 	 0.475 	 FakeNet AI 	 fakenet ai offer web app api scan video detect variety alteration technique machine learning model
# 1527 	 0.424 	 Geeks In The Woods 	 angel investor  software engineer working remote  connected build global startup diverse team alaska
# 639 	 0.416 	 TrayAway 	 trayaway room service tray trolley tracking retrieval app
# 2256 	 0.407 	 Loft 	 get benefit internal kubernetes platform without spending year build
# 29 	 0.377 	 Aligned Carbon 	 aligned carbon supplier aligned carbon nanotube enabling 1000x improvement computing
# 2048 	 0.377 	 DOCUMENT CRUNCH 	 document crunch ai platform reviewing contract document
# 1528 	 0.375 	 Genie Squad 	 genie squad develops advanced naturallanguage understanding technology answering question structured data
# 1588 	 0.372 	 EveryTeam 	 everyteam modern repository connects organizes team’s shared information
# 929 	 0.369 	 Remeet 	 remote meeting reinvented
# 799 	 0.364 	 Songlink 	 songlink fully customizable demand smart link solution music podcasts
# 1569 	 0.364 	 Fortella 	 revenue driven marketing b2b enterprise
# 1609 	 0.363 	 Fanalytical 	 fanalytical provides tool revenue growth collegiate athletic department
# 2552 	 0.363 	 Phoetech Group 	 phoetech group los angelesbased company operating stealth mode
# Query: 	 0 	 Agape 	 agape platform scientifically designed strengthen romantic relationship personalized daily question
# 449 	 0.496 	 Harpoon 	 harpoon earlystage venture capital specializes finance investment management
# 245 	 0.482 	 Cora 	 datadriven saas platform  marketplace 77b b2b furnishing industry
# 758 	 0.481 	 Stir 	 stir set create product goal transforming way people go
# 346 	 0.475 	 Digital Capital Management 	 digital capital management fund management firm offering portfolio management digital asset fund plan different investor
# 681 	 0.435 	 Textile 	 textile building new digital experience focusing user privacy transparency decentralization
# 2970 	 0.433 	 Cofactr 	 cofactr using data new way link engineering assembly part supply chain circuit board manufacturing industry
# 2003 	 0.429 	 ConnectBooks 	 connectbooks amazon fba bookkeeping software provides integration profit dashboard amazon fba seller
# 1494 	 0.423 	 Guesst 	 guesst technology company power new retail
# 1316 	 0.419 	 LienIQ 	 lieniq decentralizes residential nonperforming second lien analyticsbased investing
# 1278 	 0.413 	 Lumico Digital 	 lumico digital software development studio specializing mobile web apps io android supporting cloud service
# 1784 	 0.413 	 ConciergeBot 	 conciergebot artificially intelligent virtual concierge vacation rental guest owner
# 1349 	 0.413 	 Knowbility 	 ai cfo founder investor
# 2140 	 0.401 	 FunnelFiller 	 b2b business intelligence prospecting lead gen  sale 1
# 70 	 0.396 	 Augmented Radar Imaging 	 augmented radar imaging delivers radar advanced machine learning algorithm power autonomous vehicle warehouse robot
# 978 	 0.395 	 Projectric 	 projectric combine resource management  project management single project portfolio management software solution
# Query: 	 0 	 Agave 	 agave free hiring platform offer job posting
# 2484 	 0.581 	 Lead Belay 	 lead belay professional training  coaching platform
# 988 	 0.579 	 Prelude 	 prelude autonomous red team tool packaged desktop application
# 514 	 0.569 	 WP Repairman 	 onestop resource worryfree wordpress
# 1994 	 0.569 	 Code Vapor 	 code vapor consulting company delivers corporatelevel critical service emphasis affordability
# 2615 	 0.563 	 Slim.AI 	 slimai help application developer create build deploy run cloud native apps zero friction complexity waste
# 2805 	 0.563 	 Smart Metrics 	 daily analytics marketing task
# 1698 	 0.556 	 DataScava 	 unstructured data miner
# 2785 	 0.545 	 Sillo 	 sillo mobile application help student build confidence initial anonymous conversation
# 2605 	 0.545 	 Sign Hill Consulting 	 sign hill consulting management firm offer product strategy data inventory implementation technology solution
# 2053 	 0.538 	 Dripos 	 dripos offer point sale solution quick service restaurant
# 174 	 0.533 	 BuzzDate 	 get buzzing
# 1514 	 0.533 	 FutureGrasp 	 focus futuregrasp llc identify track forecast ass emerging disruptive technology
# 956 	 0.497 	 Racepass 	 one pas 5000 race worldwide
# 573 	 0.476 	 Videosyne 	 rethink retail applying programmatic big data ai 92 sale online
# 774 	 0.476 	 Stability Health 	 stability health us proprietary tool technology support service help people diabetes
# Query: 	 0 	 Agita Labs 	 agita lab develops privacyenhanced computing architecture facilitate creation new data market
# 1629 	 0.589 	 Elevate + Forget The Funnel 	 elevate help fastgrowing saas company identify  act growth opportunity
# 1038 	 0.564 	 Peach Education 	 peach education provider student development platform
# 1804 	 0.562 	 Abridge News 	 abridge news developer news application designed provide quick fact argument side
# 2511 	 0.536 	 ModernLoop 	 modernloop creates software organizes manages business interview
# 2293 	 0.535 	 Menergi 	 menergi ecosystem provides institutional donor access diverse pool nonprofit community
# 1797 	 0.531 	 4Tier Software 	 4tier software build amazing software satisfies consumer need offer safe engaging place worker learn skill
# 583 	 0.527 	 VeriCite 	 vericite provides originality checking tool provide tight integration lm workflow smooth customer experience
# 823 	 0.516 	 Skillz Israel 	 skillz israel new marketplace brings together nonprofessionals service provider client need service
# 2331 	 0.514 	 Notivize 	 notivize provides product manager product marketer solution need continuously optimize product experience
# 496 	 0.505 	 ZapERP 	 zaperp provider ecommerce software help scale business achieve goal
# 1781 	 0.503 	 Compute Software 	 compute software cloud optimization platform maximizes cloud cost saving performance engineering productivity
# 475 	 0.496 	 ZoomSymbols.com 	 global financial market analytics mobile app
# 112 	 0.494 	 Biocanic 	 biocanic first kind health program intelligence system designed streamline health program integrative practitioner
# 1600 	 0.493 	 F3TCH 	 f3tch mobile app provides hotel service amenity smartphones related device
# 200 	 0.491 	 Centanni Park 	 fullservice strategic consultancy mobile web technology architecture focus humancentered design
# Query: 	 0 	 Agnes Intelligence 	 artificial intelligence
# 1703 	 1.000 	 Deep Ocean Insights 	 deep ocean insight aim become world’s leading subject matter expert practitioner spectrum tool process
# 1106 	 1.000 	 Nubix.io 	 nubixio computer software company specializes field information technology internet thing
# 1219 	 1.000 	 MIMIR Blockchain Solutions 	 world’s first decentralized blockchain service provider dbsp bringing blockchain offchain
# 1209 	 1.000 	 Metalenz 	 metalenz design sell metaoptics including consumer electronics mobile phone automotive
# 1204 	 1.000 	 Menu3 	 menu3 software company develops 3d enabled product platform
# 1174 	 1.000 	 Neural Magic 	 neural magic stealth stage machine learning company based somerville
# 1533 	 1.000 	 Getloo 	 getloo mobile application help people finding restroom go
# 2141 	 1.000 	 FunCraft 	 funcraft make mobile game daily ritual players’ life  ​
# 1778 	 1.000 	 Comprindeo 	 comprindeo computer software company
# 2240 	 1.000 	 Lawnbot.biz 	 saas salesbot whitelabel platform payment instant quote
# 869 	 1.000 	 ScrappyCito 	 scrappycito job search tool veteran looking transition civilian workforce
# 2232 	 1.000 	 KEYZY 	 simple cloud based licensing platform software
# 1896 	 1.000 	 Authenticity.AI 	 authenticityai founded provide highly accurate artificial intelligence surveillance solution legal compliance industry
# 1591 	 1.000 	 ExchangeSavvy 	 exchangesavvy provides backup microsoft 365  exchange analysis mailbox migration service
# 1123 	 1.000 	 Neuraswitch 	 neuraswitch aipowered communication platform
# Query: 	 0 	 Agoric 	 agoric provides framework programming smart contract securely ease beyond anything available today
# 387 	 0.595 	 eTailPet 	 etailpet  facilitates online sale creating custom online store independent pet retailer
# 1091 	 0.565 	 Ographr 	 ographr mobile app provides service search hire photographer well videographers
# 1374 	 0.545 	 Interview School 	 interview school mockinterview software designed developed interview question feedback latest update
# 1803 	 0.541 	 Abalogix 	 abalogix software developing firm
# 2494 	 0.508 	 LoadBetter 	 loadbetter advanced digital freight platform market focus specialized shipment
# 391 	 0.503 	 Far Technologies 	 far technology aibased cloud software platform company
# 4 	 0.490 	 3DIQ 	 3diq make beyond easy recruiter edit format get realtime feedback candidate submittals
# 2488 	 0.490 	 LinqPal 	 linqpal payment financing platform construction industry
# 2474 	 0.478 	 Keyory 	 keyory computer software offer periodic email increase automate checkins productivity
# 548 	 0.477 	 VujaDay Creative Digital Agency 	 vujaday creative digital agency digital agency specializes marketing  advertising web design
# 2125 	 0.472 	 Gisual 	 gisual provides outage intelligence telecom service provider
# 2170 	 0.472 	 Gitential 	 software development analytics saas
# 2957 	 0.472 	 EJ Reilly & Associates 	 ej reilly associate specialize public relation brand consultation video production social  digital marketing support service
# 2015 	 0.472 	 Cyberhill Partners 	 venture capital firm focused disruptive timely earlystage technology company utilize platform portfolio firm
# 956 	 0.466 	 Racepass 	 one pas 5000 race worldwide
# Query: 	 0 	 Agreemint 	 search faster close end
# 1793 	 0.861 	 3D Hybrid Solutions 	 3d hybrid solution develops metal 3d printing laser hardening tool cnc machine
# 2368 	 0.838 	 Pivot Market 	 marketplace allows brand book space inside store
# 1146 	 0.823 	 mymedicalimages.com 	 mymedicalimagescom place view share manage medical image
# 1902 	 0.777 	 Axle 	 axle help freight broker grow faster automating backoffice providing fast  affordable working capital
# 1490 	 0.777 	 GridRank 	 gridrank first platform enables fast intuitive group decision making turn every decision game colleague
# 2758 	 0.771 	 ReviewNPrep 	 reviewnprep edtech company help user prepare next certification practice exam marketplace
# 1243 	 0.771 	 Market Vulture 	 market vulture monitor dramatic event around world spot opportunity lie beneath
# 2581 	 0.771 	 ResumeZest 	 resume writing service
# 1563 	 0.768 	 Flux TXT 	 text marketing platform accelerate business
# 1411 	 0.727 	 iFieldSmart 	 ifieldsmart cloud based project management software service provider
# 2060 	 0.718 	 eForce Esports 	 project help people  date latest event world esports achievement favorite team player
# 2970 	 0.715 	 Cofactr 	 cofactr using data new way link engineering assembly part supply chain circuit board manufacturing industry
# 1236 	 0.705 	  Mahalo Technologies, Inc.  	 providing secure user driven digital banking analytical solution
# 387 	 0.702 	 eTailPet 	 etailpet  facilitates online sale creating custom online store independent pet retailer
# 557 	 0.697 	 Voicebot.ai 	 voicebotai provides news market analysis interview related voice assistant artificial intelligence
# Query: 	 0 	 Akava 	 akava specializes software engineering devops design product project management service client
# 932 	 0.659 	 Relex 	 relex world first cryptocurrency based real estate developer opportunity
# 598 	 0.647 	 V-Armed 	 varmed creates custom 3d vr simulation largescale training
# 615 	 0.647 	 Twyne 	 twyne provides ridesharing coriding carpooling facility helping people
# 1507 	 0.628 	 FullStac LLC 	 fullstac creates develops cloud based saas solution ecommerce business management targeted towards small business
# 1780 	 0.627 	 Compute North 	 compute north delivers highperformance cryptocurrency mining infrastructure solution customer
# 1169 	 0.625 	 Neon Coat 	 neon coat groundbreaking io app taking model  brand next level
# through organic social marketing
# 1128 	 0.625 	 Netifi 	 nextgeneration microservices platform
# 2782 	 0.623 	 Sa Wea Luxury 	 sa wea luxury operates technological luxury cannabis brand
# 2586 	 0.623 	 Ridepanda 	 ridepanda online eride shop offer electric vehicle maintenance support theft protection
# 2032 	 0.620 	 DenScore 	 denscore software solution leverage dental claim data along patient provider feedback
# 707 	 0.620 	 Taxbender 	 taxbender help residence lower property tax
# 2273 	 0.613 	 MamaLingua 	 mamalingua community focused group looking create tool enhance languagelearning child
# 514 	 0.608 	 WP Repairman 	 onestop resource worryfree wordpress
# 1185 	 0.608 	 MOZAIK MEDIA 	 mozaik live streaming technology company build innovative product cloud based multicamera video production
# 1163 	 0.608 	 Mt. Cleverest 	 mt cleverest online textbook improves used
# Query: 	 0 	 Akita Software 	 akita build dynamic application programming interface model software programming integration
# 2186 	 0.732 	 Happy Cabbage Analytics 	 happy cabbage analytics provides data analytics insight platform cannabis industry
# 2543 	 0.700 	 Pandaflow 	 lowcode nocode automation integration platform
# 2707 	 0.700 	 PaparazzMe 	 saas paas mobile app photography
# 1917 	 0.700 	 Blendots 	 customer feedback inspires decision
# 2522 	 0.693 	 Nurture Pods 	 nurture pod elearning platform provides class pod making setting teacher student learning pod
# 1677 	 0.680 	 DYLGO 	 dylgo provides website design management service
# 1690 	 0.639 	 CYTK 	 virtual assistant software technician auto mechanic
# 2406 	 0.635 	 Quolum 	 quolum building industry’s first platform
# 2103 	 0.615 	 Floodlight Software 	 floodlight software provides software service endtoend industrial inspection management
# 2156 	 0.615 	 flowbot.com 	 flowbot automates everyday apps device dropdead simple pointandclick workflow
# 944 	 0.615 	 RecordFixer 	 web application
# 25 	 0.611 	 Agoric 	 agoric provides framework programming smart contract securely ease beyond anything available today
# ...
# 2507 	 0.615 	 Mayple 	 marketplace next generation consumer product
# 305 	 0.599 	 Culdesac 	 culdesac offer quick easy way discover new outdoor game within peer group
# 1896 	 0.581 	 Authenticity.AI 	 authenticityai founded provide highly accurate artificial intelligence surveillance solution legal compliance industry
# 981 	 0.581 	 Process Server Technology 	 process server technology powerful webbased platform mobile app instantly connects law firm
# 922 	 0.581 	 Reveal Why 	 reveal us ai advanced natural language processing advanced analytics address threat brand reputation
# 1590 	 0.581 	 EvoEndo 	 evoendo develops system enable unsedated endoscopic procedure combination sterile singleuse
# 1264 	 0.572 	 Livepeer 	 livepeer develops operates platform decentralized live video broadcast internet
# Query: 	 0 	 Ansatz AI 	 ansatz ai develops machine learning tool design optimization chemical material technology
# 907 	 0.685 	 Rivet Labs 	 rivet lab automation software develops recurring revenue cash forecasting application
# 744 	 0.623 	 Structure 	 instant automated cloud deployment
# 2329 	 0.597 	 Numero 	 numero campaign financial software manages payment processing accounting compliance campaign
# 223 	 0.586 	 Cognida 	 cognida network open source platform enable enterprise securely manage connected device
# 67 	 0.564 	 Attila 	 attila ai platform offering solution retail financial institution automate sale financial service
# 2033 	 0.545 	 Desert Lab Studio 	 desert lab studio provides web design  development internet marketing business consulting service
# 1536 	 0.543 	 Gigabit 	 gigabit event technology startup transforms physical event seamless virtual experience
# 1561 	 0.542 	 Flutter Social 	 flutter social virtual event planning marketplace using ai insight  virtual planner help user plan great event  hire vendor
# 2180 	 0.536 	 Hedron Vision 	 hedron vision software developer brings 3d experience 2d screen without extra hardware
# 2053 	 0.533 	 Dripos 	 dripos offer point sale solution quick service restaurant
# 2597 	 0.530 	 Sardine 	 sardine provides fraud prevention service solution digital economy
# 2771 	 0.530 	 Savvy 	 savvy allows landlord offer cashback rent well discount local internet business tenant
# 1903 	 0.528 	 Basement App 	 social network close friend
# 237 	 0.517 	 ConnectOR 	 connector secure mobilefirst  webbased platform allows surgical team easily communicate  manage patient’s surgical lifecycle
# 268 	 0.517 	 Constellation Kidney Group 	 constellation kidney group offer software solution healthcare industry
# Query: 	 0 	 AnyLog 	 anylog building next generation decentralized iot platform data owner capture full value data blockchain
# 1228 	 0.541 	 Maatic IT Consulting 	 maatic consulting offer web application development staffing mobile application development ecommerce solution service
# 1011 	 0.530 	 Pointful Education 	 pointful education creates publishes online high school curriculum emerging technology futurefocused career
# 2334 	 0.513 	 ninecoves 	 strive help business get reliable timely insight make informationdriven decision develop datadriven culture
# 311 	 0.502 	 Dealer Credit Resources 	 saas platform enabling equipment dealer conveniently offer financing customer
# 1795 	 0.501 	 3Victors 	 3victors provides airline revenue manager travel marketer financial analyst new insight consumer demand airfare pricing
# 356 	 0.499 	 Down to Shop 	 shop mobile shopping network showcase product original hilarious characterdriven content
# 2380 	 0.489 	 PERSPECTIVES 	 perspective provides diversity inclusion training vr technology
# 2436 	 0.484 	 YUR 	 yur fitness health platform designed make fitness game using virtual reality
# 1664 	 0.483 	 Dough Pay 	 dough mealplan group guarantee higher volume customer local restaurant
# 2162 	 0.478 	 Gomapi 	 saas asset management healthcare
# 2133 	 0.478 	 Golden Hearts Gaming 	 golden heart gaming offer digital promotional game support charitable cause
# 2131 	 0.477 	 GoFable 	 gofablecom one place content need headachefree solution new  existing marketing team
# 2164 	 0.477 	 Golden Hearts Gaming 	 golden heart gaming offer digital promotional game support charitable cause
# 1778 	 0.470 	 Comprindeo 	 comprindeo computer software company
# 2521 	 0.466 	 Nuhom 	 nuhom reward modern home buyer
# Query: 	 0 	 Aori 	 set tool help conquer google bing facebook ad
# 1699 	 0.710 	 De Novo 	 job matching app combine ai human wisdom help professional find best job fit interactive streamlined  delightful way
# 1652 	 0.660 	 Diode Ventures 	  diode venture provides turnkey endtoend solution industrial commercial technology interest
# 2852 	 0.660 	 ZoeZoe 	 fashion ecommerce
# 263 	 0.660 	 Coosta 	 coosta mortgage collateral transform platform secondary market
# 242 	 0.660 	 Conundrum Software 	 conundrum software company develops social networking apps software iphone
# 2696 	 0.660 	 ZoeZoe 	 fashion ecommerce
# 2914 	 0.651 	 Mountains 	 mountain online marketplace allows artist creator get feedback work form experienced professional
# 2283 	 0.613 	 Logistics For Hire 	 logistics hire developer distribution management software
# 2546 	 0.613 	 Papercups 	 papercups specializes offering reliable efficient software allows company connect user directly realtime chat
# 2051 	 0.574 	 DoubleGDP 	 doublegdp application software connect resident accelerate growth deliver responsive public service
# 2253 	 0.566 	 KosmoTime 	 kosmotime focus field calendar management todo list batching sprint task distraction blocking
# 533 	 0.564 	 Whisper Mob 	 humancentered datadriven approach driving conversion
# 105 	 0.559 	 Bema Creative 	 bema creative delivers branding website creation animation logo design trade show social medium campaign service
# 2001 	 0.556 	 Company Six 	 company six developer technology advance awareness protection put harm’s way
# 1080 	 0.556 	 Onion River Consulting 	 onion river consulting primarily focus offering complete range product development service build custom software
# Query: 	 0 	 Apaly Health 	 apaly health enables employer provider direct contract scale
# 2667 	 0.649 	 Turquoise Health 	 turquoise health health care company simplifies administration reduce expense complexity healthcare
# 2196 	 0.625 	 Hopstack 	 enterprise software saas warehouse automation logistics supply chain
# 155 	 0.590 	 Bounce 	 giving people experience want want starting dating
# 2785 	 0.580 	 Sillo 	 sillo mobile application help student build confidence initial anonymous conversation
# 2605 	 0.580 	 Sign Hill Consulting 	 sign hill consulting management firm offer product strategy data inventory implementation technology solution
# 543 	 0.559 	 Warehouse Exchange 	 warehouse exchange flexible ondemand warehouse platform
# 203 	 0.546 	 Chatgroup.io 	 easiest way create paid chat group
# 723 	 0.543 	 System Chief 	 system chief specializes cloud computing ecommerce development database management consulting managed service
# 760 	 0.536 	 Sticker Control 	 sticker control company provides tracking automation process digitization software
# 2784 	 0.533 	 Simply 	 simply techdriven real estate investment platform enables homeowner sell property need little tlc
# 2606 	 0.533 	 Siimee™ 	 missiondriven startup providing equitable unbiased connection experience job seeker employer weaving compassion community access accountability respect every fiber recruiting process
# 2486 	 0.528 	 LeadZen 	 art buying via trusted personal network
# 2230 	 0.525 	 Kintaba 	 kintaba modern incident management platform help company recover major outage incident team
# 1906 	 0.520 	 Beamdata 	 change driven beamdata promotes civic engagement issue advocacy development digital community
# 1418 	 0.516 	 Impartial.AI 	 impartialai analyze perspective help see article compare
# Query: 	 0 	 APEX 	 apex app enables user select driver choice favorite uberlyft driver advance rideshare  delivery
# 1537 	 0.535 	 Gitcoin 	 gitcoin platform enables open source developer monetize work used
# 2974 	 0.523 	 Classpe 	 classpe elearning firm provides training neet personal transformation class 12th science course
# 2752 	 0.515 	 robin cafe 	 casual luxury cafe serving organic juice food smoothy juice  shake serving underserved minority community
# 2738 	 0.506 	 Ration 	 ration provides innovative sessionable cannabis product
# 2540 	 0.501 	 OutReachFrog 	 outreachfrog take data driven appraoch enable growing company succeed seo
# 914 	 0.441 	 Rifft Media LLC 	 medium based review site
# 2682 	 0.438 	 Vectice 	 vectice cloudbased platform power data ai initiative
# 2071 	 0.430 	 Equip ID 	 equip id connects mechanical equipment digital world using nfc tag deliver equipmentspecific data supportive content
# 1429 	 0.427 	 InnoTech 	 innotech software development company supply chain logistics telecom healthcare smart city industry
# 2035 	 0.427 	 Developen 	 developen creates personalized convenient efficient engineering tool
# 352 	 0.425 	 Drivetime 	 drivetime provides online platform designed help user play game drive
# 194 	 0.420 	 Cawlo 	 cawlo startup currently stealth
# 2048 	 0.420 	 DOCUMENT CRUNCH 	 document crunch ai platform reviewing contract document
# 839 	 0.420 	 SideKick.Tools 	 powerful teamrun tool dramatically boost customer growth rescue lost revenue leverage declining resource
#
# 2337 	 0.417 	 Oracle Health 	 oracle health heart failure monitoring system specialized heart failure cardiac arrhythmia
# Query: 	 0 	 apiphani 	 apiphani offer strategic  operational consulting database management managed service
# 301 	 0.654 	 Curie 	 curie develops artificial intelligencebased respiratory health monitoring technology
# 2282 	 0.580 	 LoudCrowd 	 loudcrowd saas company redefining way brand invest interact customer tool growth
# 884 	 0.571 	 SaltyCloud 	 saltycloud provides access workflow automation tool help maximize impact security risk team
# 473 	 0.569 	 Zunta Technologies 	 zunta technology provides service like cloud disaster recovery consulting backup software hardware service
# 1547 	 0.566 	 Financial Strides 	 financial stride specializes providing financial service banking technology software data security service
# 199 	 0.552 	 Celitech 	 celitech enables online business app offer cellular data esim using mobile connectivity analytics
# 97 	 0.547 	  BE Local, Inc.  	 travel curation platform
# 1583 	 0.544 	 Evercoin 	 evercoin mobile application provides cryptocurrency exchange service
# 989 	 0.534 	 Preferhired 	 online referral marketplace world go hire refer friend find job
# 2309 	 0.531 	 Mistro 	 mistro offer platform provides unique benefit plan remote employee
# 722 	 0.529 	 Tacboard.com 	 tacboardcom developer mobile application managing wedding photo
# 1713 	 0.523 	 DeskViz 	 deskviz tech startup specializing blockchain rd software application development
# 2810 	 0.518 	 SkyFort 	 secure internetasaservice
# 2610 	 0.518 	 Skan Technologies 	 skan technology engineering analytics‎ app help tracking engineer behavior output increase productivity
# 405 	 0.517 	 Fission Consulting 	 service software development
# Query: 	 0 	 Apoll01 	 apoll01 open platform surfacing need education institution collaborating reaching consensus establish standard
# 387 	 0.600 	 eTailPet 	 etailpet  facilitates online sale creating custom online store independent pet retailer
# 1380 	 0.564 	 iSimu VR 	 isimu vr premier virtual reality entertainment arcade offering 40 unique virtual reality experience
# 2380 	 0.564 	 PERSPECTIVES 	 perspective provides diversity inclusion training vr technology
# 139 	 0.559 	 bluDOT 	 bludot customer loyalty program us advanced facial recognition technology
# 2905 	 0.558 	 NFJ 	 global brand ownership group
# 2264 	 0.551 	 Lionize 	 digital prezence advertising technology company focus influencer campaign email marketing market research
# 1832 	 0.516 	 ABUSINESS 	 sap®cloud onpremise hybrid sap intelligent enterprise custom integration solution
# 2933 	 0.501 	 i-80 Gold 	 i80 gold nevadabased mining company focus gold production development
# 278 	 0.498 	 Composio 	 innovative writing platform available designed make selfpublishing easy accessible shareable across device
# 227 	 0.498 	 CompanionMx 	 companionmx digital health technology company
# 495 	 0.495 	 Zaphne 	 zaphne developer content accelerator plugin designed facilitate wordpress content automation
# 2854 	 0.487 	 YourDataConnect 	 yourdataconnect data monetization platform provides data valuation  data marketplace well regulatory compliance solution
# 557 	 0.480 	 Voicebot.ai 	 voicebotai provides news market analysis interview related voice assistant artificial intelligence
# 1353 	 0.479 	 Kolu 	 kolu mobile application brings tourist together local tour guide based three interest
# 1427 	 0.476 	 Innago - Property Management Software 	 easy use property management software smalltomidsized landlord
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-41a9517da32a> in <module>
#      12     dictionary = Dictionary(corpus+[query])
#      13     tfidf = TfidfModel(dictionary=dictionary)
# ---> 14     similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)
#      15
#      16     query_tf = tfidf[dictionary.doc2bow(query)]
#
# D:\anaconda\lib\site-packages\gensim\similarities\termsim.py in __init__(self, source, dictionary, tfidf, symmetric, positive_definite, nonzero_limit, dtype)
#     230             num_nonzero = column_nonzero[t1_index]
#     231             num_rows = nonzero_limit - num_nonzero
# --> 232             most_similar = [
#     233                 (dictionary.token2id[term], similarity)
#     234                 for term, similarity in index.most_similar(t1, topn=num_rows)
#
# D:\anaconda\lib\site-packages\gensim\similarities\termsim.py in <listcomp>(.0)
#     230             num_nonzero = column_nonzero[t1_index]
#     231             num_rows = nonzero_limit - num_nonzero
# --> 232             most_similar = [
#     233                 (dictionary.token2id[term], similarity)
#     234                 for term, similarity in index.most_similar(t1, topn=num_rows)
#
# D:\anaconda\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, t1, topn)
#    1472             logger.debug('an out-of-dictionary term "%s"', t1)
#    1473         else:
# -> 1474             most_similar = self.keyedvectors.most_similar(positive=[t1], topn=topn, **self.kwargs)
#    1475             for t2, similarity in most_similar:
#    1476                 if similarity > self.threshold:
#
# D:\anaconda\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     565         if not topn:
#     566             return dists
# --> 567         best = matutils.argsort(dists, topn=topn + len(all_words), reverse=True)
#     568         # ignore (don't return) words from the input
#     569         result = [(self.index2word[sim], float(dists[sim])) for sim in best if sim not in all_words]
#
# D:\anaconda\lib\site-packages\gensim\matutils.py in argsort(x, topn, reverse)
#      81         return np.argsort(x)[:topn]
#      82     # np >= 1.8 has a fast partial argsort, use that!
# ---> 83     most_extreme = np.argpartition(x, topn)[:topn]
#      84     return most_extreme.take(np.argsort(x.take(most_extreme)))  # resort topn into order
#      85
#
# <__array_function__ internals> in argpartition(*args, **kwargs)
#
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     830
#     831     """
# --> 832     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#     833
#     834
#
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
print(documents)
# Out:
# [['accord', 'technology', 'providing', 'professional', 'support', 'business', 'strive', 'give', 'client', 'enterpriselevel', 'service'], ['venture', 'capital'], ['live', 'data', 'platform', 'ingest', 'process', 'respond', 'operate', 'live', 'data', 'system', 'scale'], ['terawatts', 'clean', 'energy', 'software', 'company'], ['diq', 'make', 'beyond', 'easy', 'recruiter', 'edit', 'format', 'get', 'realtime', 'feedback', 'candidate', 'submittals'], ['p', 'touch', 'medium', 'mobile', 'application', 'development', 'startup'], ['di', 'data', 'analytics', 'platform', 'architecture', 'engineering', 'construction', 'industry'], ['abya', 'developer', 'provider', 'technological', 'component', 'creation', 'graphic', 'virtualization', 'cloudgaming', 'solution'], ['accelitude', 'llc', 'company', 'deal', 'digital', 'cloud', 'service', 'solution'], ['accelor', 'provides', 'hardware', 'solution', 'intended', 'blockchain', 'ai', 'business'], ['accounting', 'panel', 'cloudbased', 'accounting', 'tool', 'designed', 'help', 'entrepreneur', 'control', 'business', 'finance', 'anytime', 'anywhere'], ['ace', 'iot', 'solution', 'offer', 'secure', 'managed', 'platform', 'collecting', 'aggregating', 'visualizing', 'facility', 'operation'], ['acsibi', 'studio', 'mobile', 'game', 'development', 'company', 'located', 'acton'], ['actio', 'modular', 'based', 'software', 'service', 'analytics', 'platform', 'designed', 'restaurant', 'service'], ['activeconnect', 'work', 'type', 'device', 'operating', 'system', 'every', 'transaction', 'including', 'io', 'android', 'window', 'mac'], ['lightweight', 'project', 'portfolio', 'management', 'ppm', 'software', 'new', 'pmos'], ['deliver', 'insight', 'help', 'asset', 'manager', 'plan', 'react', 'extreme', 'weather', 'event'], ['ad', 'fontes', 'medium', 'public', 'benefit', 'corporation', 'rate', 'news', 'founded', 'vanessa', 'otero', 'creator', 'medium', 'bias', 'chart'], ['ad', 'genius', 'provides', 'marketing', 'solution', 'based', 'exceptional', 'technical', 'talent', 'creative', 'power'], ['automated', 'microfulfillment', 'center', 'drone', 'rover', 'delivery'], ['agamon', 'aipowered', 'healthcare', 'platform', 'convert', 'clinical', 'text', 'structured', 'data'], ['agape', 'platform', 'scientifically', 'designed', 'strengthen', 'romantic', 'relationship', 'personalized', 'daily', 'question'], ['agave', 'free', 'hiring', 'platform', 'offer', 'job', 'posting'], ['agita', 'lab', 'develops', 'privacyenhanced', 'computing', 'architecture', 'facilitate', 'creation', 'new', 'data', 'market'], ['artificial', 'intelligence'], ['agoric', 'provides', 'framework', 'programming', 'smart', 'contract', 'securely', 'ease', 'beyond', 'anything', 'available', 'today'], ['search', 'faster', 'close', 'end'], ['akava', 'specializes', 'software', 'engineering', 'devops', 'design', 'product', 'project', 'management', 'service', 'client'], ['akita', 'build', 'dynamic', 'application', 'programming', 'interface', 'model', 'software', 'programming', 'integration'], ['aligned', 'carbon', 'supplier', 'aligned', 'carbon', 'nanotube', 'enabling', 'x', 'improvement', 'computing'], ['allelica', 'genomics', 'software', 'company', 'driving', 'transition', 'polygenic', 'risk', 'score', 'genomic', 'research', 'clinical', 'application'], ['ampcontrolio', 'aibased', 'optimization', 'software', 'electric', 'vehicle', 'charging', 'build', 'charging', 'station', 'low', 'cost'], ['anna', 'first', 'aipowered', 'selfcheckout', 'solution', 'designed', 'meet', 'specific', 'need', 'cannabis', 'retailer'], ['annotex', 'pdf', 'annotator', 'software', 'allows', 'user', 'write', 'math', 'equation', 'chemical', 'structure'], ['u', 'intelligence', 'agencygrade', 'forensic', 'analysis', 'critical', 'intel'], ['ansatz', 'ai', 'develops', 'machine', 'learning', 'tool', 'design', 'optimization', 'chemical', 'material', 'technology'], ['anylog', 'building', 'next', 'generation', 'decentralized', 'iot', 'platform', 'data', 'owner', 'capture', 'full', 'value', 'data', 'blockch ...

# %%
corpus
# Out:
# [[['venture', 'capital'],
#   ['live',
#    'data',
#    'platform',
#    'ingest',
#    'process',
#    'respond',
#    'operate',
#    'live',
#    'data',
#    'system',
#    'scale'],
#   ['terawatts', 'clean', 'energy', 'software', 'company'],
#   ['diq',
#    'make',
#    'beyond',
#    'easy',
#    'recruiter',
#    'edit',
#    'format',
#    'get',
#    'realtime',
#    'feedback',
#    'candidate',
#    'submittals'],
#   ['p', 'touch', 'medium', 'mobile', 'application', 'development', 'startup'],
#   ['di',
#    'data',
#    'analytics',
#    'platform',
#    'architecture',
#    'engineering',
#    'construction',
#    'industry'],
#   ['abya',
#    'developer',
#    'provider',
#    'technological',
#    'component',
#    'creation',
#    'graphic',
#    'virtualization',
#    'cloudgaming',
#    'solution'],
#   ['accelitude',
#    'llc',
#    'company',
#    'deal',
#    'digital',
#    'cloud',
#    'service',
#    'solution'],
#   ['accelor',
#    'provides',
#    'hardware',
#    'solution',
#    'intended',
#    'blockchain',
#    'ai',
#    'business'],
#   ['accounting',
#    'panel',
#    'cloudbased',
#    'accounting',
#    'tool',
#    'designed',
#    'help',
#    'entrepreneur',
#    'control',
#    'business',
#    'finance',
#    'anytime',
#    'anywhere'],
#   ['ace',
#    'iot',
#    'solution',
#    'offer',
#    'secure',
#    'managed',
#    'platform',
#    'collecting',
#    'aggregating',
#    'visualizing',
#    'facility',
#    'operation'],
#   ['acsibi',
#    'studio',
#    'mobile',
#    'game',
#    'development',
#    'company',
#    'located',
#    'acton'],
#   ['actio',
#    'modular',
#    'based',
#    'software',
#    'service',
#    'analytics',
#    'platform',
#    'designed',
#    'restaurant',
#    'service'],
#   ['activeconnect',
#    'work',
#    'type',
#    'device',
#    'operating',
#    'system',
#    'every',
#    'transaction',
#    'including',
#    'io',
#    'android',
#    'window',
#    'mac'],
#   ['lightweight',
#    'project',
#    'portfolio',
#    'management',
#    'ppm',
#    'software',
#    'new',
#    'pmos'],
#   ['deliver',
#    'insight',
#    'help',
#    'asset',
#    'manager',
#    'plan',
#    'react',
#    'extreme',
#    'weather',
#    'event'],
#   ['ad',
#    'fontes',
#    'medium',
#    'public',
#    'benefit',
#    'corporation',
#    'rate',
#    'news',
#    'founded',
#    'vanessa',
#    'otero',
#    'creator',
#    'medium',
#    'bias',
#    'chart'],
#   ['ad',
#    'genius',
#    'provides',
#    'marketing',
#    'solution',
#    'based',
#    'exceptional',
#    'technical',
#    'talent',
#    'creative',
#    'power'],
#   ['automated', 'microfulfillment', 'center', 'drone', 'rover', 'delivery'],
#   ['agamon',
#    'aipowered',
#    'healthcare',
#    'platform',
#    'convert',
#    'clinical',
#    'text',
#    'structured',
#    'data'],
#   ['agape',
#    'platform',
#    'scientifically',
#    'designed',
#    'strengthen',
#    'romantic',
#    'relationship',
#    'personalized',
#    'daily',
#    'question'],
#   ['agave', 'free', 'hiring', 'platform', 'offer', 'job', 'posting'],
#   ['agita',
#    'lab',
#    'develops',
#    'privacyenhanced',
#    'computing',
#    'architecture',
#    'facilitate',
#    'creation',
#    'new',
#    'data',
#    'market'],
#   ['artificial', 'intelligence'],
#   ['agoric',
#    'provides',
#    'framework',
#    'programming',
#    'smart',
#    'contract',
#    'securely',
#    'ease',
#    'beyond',
#    'anything',
#    'available',
#    'today'],
#   ['search', 'faster', 'close', 'end'],
#   ['akava',
#    'specializes',
#    'software',
#    'engineering',
#    'devops',
#    'design',
#    'product',
#    'project',
#    'management',
#    'service',
#    'client'],
#   ['akita',
#    'build',
#    'dynamic',
#    'application',
#    'programming',
#    'interface',
#    'model',
#    'software',
#    'programming',
#    'integration'],
#   ['aligned',
#    'carbon',
#    'supplier',
#    'aligned',
#    'carbon',
#    'nanotube',
#    'enabling',
#    'x',
#    'improvement',
#    'computing'],
#   ['allelica',
#    'genomics',
#    'software',
#    'company',
#    'driving',
#    'transition',
#    'polygenic',
#    'risk',
#    'score',
#    'genomic',
#    'research',
#    'clinical',
#    'application'],
#   ['ampcontrolio',
#    'aibased',
#    'optimization',
#    'software',
#    'electric',
#    'vehicle',
#    'charging',
#    'build',
#    'charging',
#    'station',
#    'low',
#    'cost'],
#   ['anna',
#    'first',
#    'aipowered',
#    'selfcheckout',
#    'solution',
#    'designed',
#    'meet',
#    'specific',
#    'need',
#    'cannabis',
#    'retailer'],
#   ['annotex',
#    'pdf',
#    'annotator',
#    'software',
#    'allows',
#    'user',
#    'write',
#    'math',
#    'equation',
#    'chemical',
#    'structure'],
#   ['u',
#    'intelligence',
#    'agencygrade',
#    'forensic',
#    'analysis',
#    'critical',
#    'intel'],
#   ['ansatz',
#    'ai',
#    'develops',
#    'machine',
#    'learning',
#    'tool',
#    'design',
#    'optimization',
#    'chemical',
#    'material',
#    'technology'],
#   ['anylog',
#    'building',
#    'next',
#    'generation',
#    'decentralized',
#    'iot',
#    'platform',
#    'data',
#    'owner',
#    'capture',
#    'full',
#    'value',
#    'data',
#    'blockchain'],
#   ['set', 'tool', 'help', 'conquer', 'google', 'bing', 'facebook', 'ad'],
#   ['apaly',
#    'health',
#    'enables',
#    'employer',
#    'provider',
#    'direct',
#    'contract',
#    'scale'],
#   ['apex',
#    'app',
#    'enables',
#    'user',
#    'select',
#    'driver',
#    'choice',
#    'favorite',
#    'uberlyft',
#    'driver',
#    'advance',
#    'rideshare',
#    'delivery'],
#   ['apiphani',
#    'offer',
#    'strategic',
#    'operational',
#    'consulting',
#    'database',
#    'management',
#    'managed',
#    'service'],
#   ['apoll',
#    'open',
#    'platform',
#    'surfacing',
#    'need',
#    'education',
#    'institution',
#    'collaborating',
#    'reaching',
#    'consensus',
#    'establish',
#    'standard'],
#   ['app',
#    'growth',
#    'expert',
#    'help',
#    'mobile',
#    'app',
#    'publisher',
#    'developer',
#    'discover',
#    'increase',
#    'app',
#    'performance',
#    'sustainability'],
#   ['apprentiscope', 'computer', 'software', 'company'],
#   ['appyhour', 'smart', 'marketing', 'business', 'management', 'platform'],
#   ['apres',
#    'analytics',
#    'platform',
#    'built',
#    'scale',
#    'explain',
#    'ai',
#    'decision',
#    'making'],
#   ['aquifer',
#    'motion',
#    'saas',
#    'platform',
#    'enables',
#    'creator',
#    'team',
#    'create',
#    'studiolevel',
#    'animated',
#    'video',
#    'without',
#    'studio'],
#   ['ara',
#    'sound',
#    'lab',
#    'develops',
#    'audio',
#    'technology',
#    'various',
#    'application'],
#   ['arbilex',
#    'leverage',
#    'predictive',
#    'analytics',
#    'empower',
#    'lawyer',
#    'litigation',
#    'funders',
#    'make',
#    'datadriven',
#    'decision',
#    'crossborder',
#    'dispute'],
#   ['arch',
#    'digitally',
#    'manages',
#    'private',
#    'investment',
#    'operation',
#    'investor',
#    'investment',
#    'advisor'],
#   ['archeads',
#    'real',
#    'estate',
#    'property',
#    'management',
#    'firm',
#    'dealing',
#    'floorplans',
#    'service'],
#   ['ari',
#    'coach',
#    'mission',
#    'make',
#    'healthy',
#    'eating',
#    'simple',
#    'accessible',
#    'everyone'],
#   ['ari',
#    'recruiting',
#    'intelligent',
#    'recruiting',
#    'software',
#    'track',
#    'athlete',
#    'provides',
#    'feedback',
#    'enhanced',
#    'decision',
#    'making'],
#   ['aria',
#    'intel',
#    'operates',
#    'digital',
#    'medium',
#    'platform',
#    'tech',
#    'medium',
#    'gaming'],
#   ['armarius',
#    'software',
#    'provides',
#    'robotic',
#    'process',
#    'automation',
#    'data',
#    'loss',
#    'prevention',
#    'enhanced',
#    'capability',
#    'website',
#    'filtering',
#    'service'],
#   ['arpio',
#    'protects',
#    'eliminates',
#    'downtime',
#    'aws',
#    'application',
#    'making',
#    'easy',
#    'recover',
#    'outage',
#    'minute'],
#   ['delivering',
#    'peace',
#    'mind',
#    'replacing',
#    'traditional',
#    'networking',
#    'software',
#    'defined',
#    'security',
#    'solution'],
#   ['asizer', 'app', 'measure', 'body'],
#   ['assembler',
#    'lab',
#    'detroit',
#    'startup',
#    'studio',
#    'working',
#    'local',
#    'talent',
#    'build',
#    'venturescale',
#    'business'],
#   ['astellent',
#    'consulting',
#    'company',
#    'improves',
#    'software',
#    'designed',
#    'developed',
#    'delivered',
#    'help',
#    'organization',
#    'achieve'],
#   ['ethereum', 'smart', 'contract', 'wallet', 'dapp', 'browser'],
#   ['development',
#    'stage',
#    'startup',
#    'enabling',
#    'next',
#    'generation',
#    'precision',
#    'medicine',
#    'fusing',
#    'biochip',
#    'ai',
#    'technology'],
#   ['atelier', 'home', 'design', 'mobile', 'app'],
#   ['atlerts',
#    'stateoftheart',
#    'communication',
#    'platform',
#    'manages',
#    'incident',
#    'report',
#    'injury',
#    'documentation',
#    'athletic',
#    'department'],
#   ['atom',
#    'computing',
#    'build',
#    'truly',
#    'scalable',
#    'quantum',
#    'computer',
#    'individual',
#    'atom'],
#   ['atomata',
#    'provides',
#    'iot',
#    'hardware',
#    'software',
#    'solution',
#    'grower',
#    'scale'],
#   ['atticus',
#    'simplifying',
#    'probate',
#    'estate',
#    'settlement',
#    'individual',
#    'institutional',
#    'advisor'],
#   ['attila',
#    'ai',
#    'platform',
#    'offering',
#    'solution',
#    'retail',
#    'financial',
#    'institution',
#    'automate',
#    'sale',
#    'financial',
#    'service'],
#   ['attunely',
#    'produce',
#    'machine',
#    'learning',
#    'model',
#    'debt',
#    'collection',
#    'decreasing',
#    'waste',
#    'improving',
#    'recovery',
#    'yield'],
#   ['leading',
#    'free',
#    'opensource',
#    'io',
#    'mac',
#    'based',
#    'audiomusic',
#    'developer',
#    'tool',
#    'proudly',
#    'power',
#    'million',
#    'app',
#    'installs'],
#   ['augmented',
#    'radar',
#    'imaging',
#    'delivers',
#    'radar',
#    'advanced',
#    'machine',
#    'learning',
#    'algorithm',
#    'power',
#    'autonomous',
#    'vehicle',
#    'warehouse',
#    'robot'],
#   ['augmented',
#    'review',
#    'help',
#    'review',
#    'validate',
#    'design',
#    'realtime',
#    'augmented',
#    'reality'],
#   ['aura',
#    'salonware',
#    'provider',
#    'salon',
#    'management',
#    'software',
#    'elevate',
#    'salon',
#    'experience'],
#   ['aurelius',
#    'data',
#    'provide',
#    'patient',
#    'consumer',
#    'healthcare',
#    'provider',
#    'best',
#    'cannabinoid',
#    'treatment'],
#   ['autopartsz', 'best', 'auto', 'part', 'finder', 'app'],
#   ['autymate',
#    'develops',
#    'software',
#    'solution',
#    'like',
#    'accounting',
#    'hr',
#    'healthcare',
#    'automation',
#    'apps',
#    'help',
#    'reduce',
#    'time'],
#   ['auxon',
#    'software',
#    'company',
#    'enables',
#    'ai',
#    'system',
#    'engineer',
#    'build',
#    'safe',
#    'resilient',
#    'system'],
#   ['auxxit',
#    'nextgeneration',
#    'digital',
#    'marketplace',
#    'platform',
#    'leverage',
#    'engaging',
#    'experience',
#    'realtime',
#    'group',
#    'chat',
#    'live',
#    'streaming'],
#   ['avail',
#    'boutique',
#    'firm',
#    'manages',
#    'telecom',
#    'technology',
#    'asset',
#    'delivers',
#    'expense',
#    'success'],
#   ['avansa',
#    'computer',
#    'software',
#    'company',
#    'specializes',
#    'blockchain',
#    'cryptocurrency',
#    'software'],
#   ['avlaki',
#    'information',
#    'technology',
#    'firm',
#    'specializes',
#    'advisory',
#    'consulting',
#    'solution',
#    'technology',
#    'business'],
#   ['avo', 'insight', 'augmented', 'reality', 'based', 'marketing', 'company'],
#   ['awecom', 'aipowered', 'streaming', 'optimizer'],
#   ['axel',
#    'technology',
#    'software',
#    'developer',
#    'investing',
#    'technology',
#    'infrastructure'],
#   ['axellero',
#    'software',
#    'development',
#    'company',
#    'provides',
#    'product',
#    'design',
#    'web',
#    'development',
#    'io',
#    'machine',
#    'learning',
#    'service'],
#   ['axia',
#    'cpq',
#    'salesforce',
#    'partner',
#    'help',
#    'achieving',
#    'greatest',
#    'possible',
#    'return',
#    'salesforce',
#    'investment'],
#   ['babsorbed',
#    'technology',
#    'enables',
#    'business',
#    'create',
#    'immersive',
#    'experience',
#    'interacting',
#    'physical',
#    'object',
#    'world'],
#   ['badge',
#    'u',
#    'company',
#    'develops',
#    'biometric',
#    'cryptocurrency',
#    'based',
#    'unique',
#    'identification',
#    'software',
#    'store',
#    'one',
#    'cryptographic',
#    'key'],
#   ['bankd',
#    'app',
#    'make',
#    'tracking',
#    'managing',
#    'digital',
#    'asset',
#    'effortless'],
#   ['mobile',
#    'solution',
#    'increasing',
#    'efficiency',
#    'sale',
#    'bar',
#    'club',
#    'nightlife',
#    'venue'],
#   ['barshift', 'firstever', 'point', 'promotion', 'software'],
#   ['bartrack',
#    'offer',
#    'digital',
#    'platform',
#    'tracking',
#    'inventory',
#    'optimizing',
#    'quality',
#    'draft',
#    'product'],
#   ['base',
#    'firstever',
#    'software',
#    'platform',
#    'built',
#    'specifically',
#    'executive',
#    'assistant'],
#   ['baseai',
#    'offer',
#    'business',
#    'process',
#    'automation',
#    'software',
#    'several',
#    'industry'],
#   ['basenube',
#    'company',
#    'specializes',
#    'development',
#    'healthcare',
#    'software',
#    'product'],
#   ['basil',
#    'security',
#    'develops',
#    'enterprise',
#    'software',
#    'product',
#    'enable',
#    'security',
#    'policy',
#    'management'],
#   ['bayou',
#    'midstream',
#    'fullservice',
#    'midstream',
#    'company',
#    'providing',
#    'customized',
#    'solution',
#    'oil',
#    'gas',
#    'producer'],
#   ['travel', 'curation', 'platform'],
#   ['beagle',
#    'learning',
#    'provides',
#    'software',
#    'accelerates',
#    'learning',
#    'strategic',
#    'decision',
#    'making',
#    'using',
#    'custom',
#    'built',
#    'ai'],
#   ['beanstalk',
#    'network',
#    'research',
#    'development',
#    'company',
#    'privacy',
#    'preserving',
#    'financial',
#    'transaction'],
#   ['passive', 'income', 'market'],
#   ['help',
#    'early',
#    'growth',
#    'stage',
#    'startup',
#    'hire',
#    'right',
#    'senior',
#    'talent',
#    'help',
#    'easily',
#    'cross',
#    'chasm',
#    'arr'],
#   ['bedrock', 'private', 'personal', 'super', 'computer', 'company'],
#   ['bein',
#    'carib',
#    'software',
#    'solution',
#    'company',
#    'carribean',
#    'product',
#    'food',
#    'entertainment',
#    'travel',
#    'lifestyle'],
#   ['fold',
#    'us',
#    'machine',
#    'learning',
#    'provide',
#    'automatic',
#    'context',
#    'news',
#    'article'],
#   ['bema',
#    'creative',
#    'delivers',
#    'branding',
#    'website',
#    'creation',
#    'animation',
#    'logo',
#    'design',
#    'trade',
#    'show',
#    'social',
#    'medium',
#    'campaign',
#    'service'],
#   ['bensen',
#    'build',
#    'software',
#    'help',
#    'restaurant',
#    'brand',
#    'sell',
#    'stuff',
#    'voice',
#    'platform',
#    'like',
#    'alexa',
#    'google',
#    'assistant'],
#   ['machine',
#    'learning',
#    'model',
#    'serving',
#    'platform',
#    'creator',
#    'opensource',
#    'bentoml'],
#   ['bid',
#    'event',
#    'provider',
#    'mobile',
#    'event',
#    'coordination',
#    'application'],
#   ['billseye',
#    'realtime',
#    'mobile',
#    'billing',
#    'solution',
#    'application',
#    'professional',
#    'bill',
#    'client',
#    'call'],
#   ['something', 'wicked', 'way', 'come'],
#   ['binit',
#    'develops',
#    'aibased',
#    'tech',
#    'revolutionize',
#    'waste',
#    'segregation'],
#   ['biocanic',
#    'first',
#    'kind',
#    'health',
#    'program',
#    'intelligence',
#    'system',
#    'designed',
#    'streamline',
#    'health',
#    'program',
#    'integrative',
#    'practitioner'],
#   ['bionica',
#    'lab',
#    'digital',
#    'health',
#    'hardware',
#    'development',
#    'company',
#    'build',
#    'wearable',
#    'monitoring',
#    'system',
#    'solve',
#    'problem',
#    'doctor'],
#   ['bird',
#    'brain',
#    'developer',
#    'enterprise',
#    'platform',
#    'intended',
#    'serve',
#    'pest',
#    'control',
#    'industry'],
#   ['bitcoin',
#    'energy',
#    'ultimate',
#    'health',
#    'energy',
#    'drink',
#    'made',
#    'hustler',
#    'grinder',
#    'entrepreneur'],
#   ['bitcoindb',
#    'database',
#    'designed',
#    'store',
#    'data',
#    'bitcoin',
#    'cash',
#    'blockchain'],
#   ['developer',
#    'enterprise',
#    'software',
#    'designed',
#    'aggregate',
#    'access',
#    'information',
#    'across',
#    'multiple',
#    'source'],
#   ['bit', 'hash', 'digital', 'marketing', 'agency'],
#   ['bit',
#    'disk',
#    'data',
#    'engineering',
#    'consultancy',
#    'dedicated',
#    'building',
#    'robust',
#    'performant',
#    'data',
#    'system'],
#   ['bizdeviq',
#    'platform',
#    'connect',
#    'student',
#    'paid',
#    'artificial',
#    'intelligence',
#    'machine',
#    'learning',
#    'data',
#    'science',
#    'project'],
#   ['privacy',
#    'preserving',
#    'face',
#    'recognition',
#    'technology',
#    'personalized',
#    'customer',
#    'experience',
#    'increased',
#    'venue',
#    'safety'],
#   ['blinkup',
#    'geolocation',
#    'app',
#    'enables',
#    'user',
#    'connect',
#    'network',
#    'easily',
#    'locate',
#    'proximity'],
#   ['blitziq',
#    'develops',
#    'insight',
#    'platform',
#    'allows',
#    'user',
#    'assist',
#    'sale',
#    'team',
#    'run',
#    'consistent',
#    'sale',
#    'process'],
#   ['block',
#    'party',
#    'studio',
#    'technology',
#    'manages',
#    'spam',
#    'troll',
#    'social',
#    'medium',
#    'network'],
#   ['blockchain',
#    'art',
#    'collective',
#    'provides',
#    'unparalleled',
#    'provenance',
#    'tracking',
#    'artist',
#    'collector',
#    'dealer',
#    'institution'],
#   ['industrial', 'blockchain', 'network', 'infrastructure'],
#   ['blockchain',
#    'buffalo',
#    'conduct',
#    'group',
#    'discussion',
#    'meeting',
#    'conference',
#    'blockchain',
#    'technology',
#    'service'],
#   ['blockchan',
#    'online',
#    'social',
#    'medium',
#    'platform',
#    'enables',
#    'user',
#    'publish',
#    'monetize',
#    'content',
#    'connect',
#    'others'],
#   ['blockinterop',
#    'information',
#    'technology',
#    'solution',
#    'company',
#    'specializing',
#    'analysis',
#    'implementation',
#    'healthcare',
#    'resource'],
#   ['bloomberg', 'crypto', 'asset'],
#   ['blockpad', 'online', 'platform', 'document', 'spreadsheet'],
#   ['block',
#    'telegraph',
#    'leading',
#    'source',
#    'blockchain',
#    'cryptocurrency',
#    'news',
#    'finance',
#    'technology',
#    'reader',
#    'outside',
#    'industry'],
#   ['blocktown',
#    'capital',
#    'investment',
#    'fund',
#    'focused',
#    'exclusively',
#    'blockchain',
#    'venture',
#    'digital',
#    'currency',
#    'application',
#    'token'],
#   ['blocktricity',
#    'capital',
#    'investment',
#    'firm',
#    'specializes',
#    'cryptocurrencies',
#    'digital',
#    'asset'],
#   ['blockvigil',
#    'help',
#    'build',
#    'scale',
#    'blockchain',
#    'apps',
#    'line',
#    'code'],
#   ['blocky',
#    'help',
#    'people',
#    'trust',
#    'data',
#    'technology',
#    'zipperchain',
#    'scale',
#    'million',
#    'txssecond',
#    'extremely',
#    'low',
#    'predictable',
#    'cost'],
#   ['blocnets', 'privately', 'funded', 'software', 'technology', 'company'],
#   ['bloom',
#    'artificial',
#    'intelligence',
#    'company',
#    'guide',
#    'user',
#    'towards',
#    'happier',
#    'healthier',
#    'fulfilling',
#    'life'],
#   ['bludot',
#    'customer',
#    'loyalty',
#    'program',
#    'us',
#    'advanced',
#    'facial',
#    'recognition',
#    'technology'],
#   ['boardroom',
#    'alpha',
#    'develops',
#    'analytics',
#    'set',
#    'standard',
#    'assessment',
#    'public',
#    'company',
#    'director',
#    'officer',
#    'corporate',
#    'governance'],
#   ['bola',
#    'ai',
#    'voice',
#    'assistant',
#    'company',
#    'develops',
#    'solution',
#    'reduce',
#    'documentation',
#    'burden',
#    'dental',
#    'medical',
#    'provider'],
#   ['boldcode', 'web', 'software', 'development', 'company'],
#   ['boldvue', 'provides', 'elearning', 'service', 'solution'],
#   ['bolt',
#    'lab',
#    'provides',
#    'instant',
#    'private',
#    'payment',
#    'everyday',
#    'purchase'],
#   ['bolton',
#    'secure',
#    'provider',
#    'soc',
#    'noc',
#    'staffing',
#    'coverage',
#    'cybersecurity',
#    'service',
#    'tool',
#    'analysis'],
#   ['authenticating', 'supply', 'chain', 'using', 'blockchain', 'technology'],
#   ['bonbloc',
#    'blockchain',
#    'software',
#    'company',
#    'focus',
#    'corporate',
#    'government',
#    'solution'],
#   ['childhood', 'literacy', 'platform', 'reading', 'log', 'reward', 'system'],
#   ['bookelicious',
#    'promotes',
#    'literacy',
#    'helping',
#    'child',
#    'find',
#    'great',
#    'book',
#    'topic',
#    'passionate'],
#   ['borgo',
#    'cloudbased',
#    'hris',
#    'payroll',
#    'management',
#    'solution',
#    'small',
#    'midsized',
#    'business'],
#   ['bot',
#    'image',
#    'medical',
#    'software',
#    'company',
#    'utilizes',
#    'artificial',
#    'intelligence',
#    'imaging',
#    'interpretation'],
#   ['botanisol',
#    'analytics',
#    'improves',
#    'measurement',
#    'analytics',
#    'engineering',
#    'science'],
#   ['botisimo',
#    'crossplatform',
#    'chatbot',
#    'viewer',
#    'engagement',
#    'tool',
#    'suite',
#    'available',
#    'twitch',
#    'mixer',
#    'youtube',
#    'discord'],
#   ['short',
#    'term',
#    'hourly',
#    'daily',
#    'storage',
#    'around',
#    'urban',
#    'area',
#    'hosted',
#    'local',
#    'business'],
#   ['giving', 'people', 'experience', 'want', 'want', 'starting', 'dating'],
#   ['bound',
#    'enables',
#    'insurance',
#    'company',
#    'brokerage',
#    'agency',
#    'offer',
#    'insurance',
#    'product'],
#   ['boxlet',
#    'storage',
#    'develops',
#    'peertopeer',
#    'network',
#    'software',
#    'offer',
#    'customizable',
#    'short',
#    'term',
#    'storage',
#    'solution'],
#   ['helping',
#    'world',
#    'best',
#    'consumer',
#    'brand',
#    'build',
#    'deeper',
#    'customer',
#    'relationship',
#    'scale'],
#   ['saas',
#    'marketing',
#    'platform',
#    'enables',
#    'brand',
#    'setup',
#    'manage',
#    'measure',
#    'chat',
#    'conversation',
#    'best',
#    'customer'],
#   ['breaking',
#    'normal',
#    'social',
#    'networking',
#    'party',
#    'game',
#    'app',
#    'capitalizes',
#    'real',
#    'human',
#    'connection'],
#   ['techenabled',
#    'consulting',
#    'platform',
#    'connecting',
#    'business',
#    'industry',
#    'professional',
#    'share',
#    'knowledge',
#    'ondemand'],
#   ['bringing',
#    'transformative',
#    'power',
#    'map',
#    'internet',
#    'make',
#    'entire',
#    'web',
#    'collaborative',
#    'learning',
#    'experience'],
#   ['brightback',
#    'offer',
#    'entreprenurial',
#    'advice',
#    'subscriptionbased',
#    'business',
#    'customer',
#    'lifetime',
#    'value'],
#   ['brilliant',
#    'hire',
#    'recruiting',
#    'solution',
#    'efficient',
#    'unbiased',
#    'candidate',
#    'screening'],
#   ['brokerassist',
#    'mobilefirst',
#    'saas',
#    'marketplace',
#    'product',
#    'connecting',
#    'realtors',
#    'fractional',
#    'assistance',
#    'referral',
#    'networking',
#    'gig'],
#   ['provides', 'technical', 'financial', 'service', 'nationwide'],
#   ['budgetshred',
#    'expertise',
#    'paper',
#    'document',
#    'shredding',
#    'computer',
#    'destruction',
#    'electronics',
#    'recycling',
#    'service'],
#   ['behind',
#    'buildee',
#    'work',
#    'greatest',
#    'mind',
#    'building',
#    'science',
#    'partnership',
#    'market',
#    'driver',
#    'company'],
#   ['buildr',
#    'provides',
#    'solution',
#    'bridging',
#    'job',
#    'site',
#    'cloud',
#    'task',
#    'automation',
#    'faster',
#    'project',
#    'closeout',
#    'datadriven',
#    'contractor'],
#   ['easily', 'invest', 'spare', 'change', 'cryptocurrency'],
#   ['buttonwood',
#    'software',
#    'platform',
#    'help',
#    'elite',
#    'latestage',
#    'startup',
#    'efficiently',
#    'raise',
#    'growth',
#    'capital'],
#   ['buyjour',
#    'new',
#    'type',
#    'marketing',
#    'platform',
#    'dramatically',
#    'increase',
#    'effectiveness',
#    'abm',
#    'strategy'],
#   ['buywith',
#    'online',
#    'shopping',
#    'livestream',
#    'platform',
#    'brand',
#    'retailer',
#    'influencers',
#    'expert',
#    'host',
#    'live',
#    'shopping',
#    'event'],
#   ['get', 'buzzing'],
#   ['byteboard',
#    'redesigns',
#    'technical',
#    'interview',
#    'reflective',
#    'engineer',
#    'job',
#    'projectbased',
#    'approach'],
#   ['calendarer',
#    'offer',
#    'calendar',
#    'synchronization',
#    'professional',
#    'contact',
#    'management',
#    'contact',
#    'scaling',
#    'contact',
#    'organization'],
#   ['california',
#    'cannabis',
#    'market',
#    'information',
#    'technology',
#    'service',
#    'company'],
#   ['camberline',
#    'technology',
#    'sensordriven',
#    'platform',
#    'help',
#    'community',
#    'read',
#    'electricity',
#    'usage',
#    'support',
#    'energy',
#    'conservation'],
#   ['cameyo',
#    'cloudnative',
#    'window',
#    'application',
#    'transformation',
#    'platform',
#    'atp',
#    'delivers',
#    'window',
#    'application',
#    'device',
#    'browser'],
#   ['take', 'chat', 'live'],
#   ['mobile',
#    'stock',
#    'market',
#    'application',
#    'pattern',
#    'recognition',
#    'technology',
#    'watchlist',
#    'push',
#    'notification'],
#   ['candoo', 'workflow', 'management', 'software', 'drone', 'business'],
#   ['financial', 'solution', 'cannabis', 'cbd', 'company'],
#   ['canncurrent',
#    'provides',
#    'softwareasaservice',
#    'solution',
#    'cannabis',
#    'industry'],
#   ['canopy',
#    'software',
#    'company',
#    'specializing',
#    'making',
#    'data',
#    'breach',
#    'impact',
#    'assessment'],
#   ['carbon',
#    'cash',
#    'behavioral',
#    'energy',
#    'efficiency',
#    'app',
#    'reward',
#    'student',
#    'conserving',
#    'electricity',
#    'reducing',
#    'carbon',
#    'footprint'],
#   ['carbonado',
#    'connects',
#    'verified',
#    'talent',
#    'new',
#    'opportunity',
#    'guided',
#    'skill',
#    'fit',
#    'use',
#    'advanced',
#    'tool',
#    'technology',
#    'leveraging',
#    'ai'],
#   ['secure', 'blockchain', 'clinical', 'network'],
#   ['carbyn',
#    'platform',
#    'service',
#    'tech',
#    'environment',
#    'assembled',
#    'installed',
#    'corporation',
#    'fund',
#    'real',
#    'estate',
#    'workspace'],
#   ['bringing', 'ondemand', 'inhome', 'nursing', 'care'],
#   ['castamash',
#    'mobile',
#    'app',
#    'allows',
#    'create',
#    'collaborative',
#    'video',
#    'friend',
#    'around',
#    'world'],
#   ['catalyst',
#    'education',
#    'elearning',
#    'platform',
#    'provides',
#    'education',
#    'stem',
#    'course',
#    'lab'],
#   ['cattle', 'management', 'mobile', 'application'],
#   ['cawlo', 'startup', 'currently', 'stealth'],
#   ['cblocks',
#    'creates',
#    'product',
#    'make',
#    'easy',
#    'save',
#    'spend',
#    'earn',
#    'cryptocurrency'],
#   ['cbm',
#    'marketing',
#    'solution',
#    'provides',
#    'advertising',
#    'seo',
#    'digital',
#    'marketing',
#    'service'],
#   ['reservationless', 'hotel'],
#   ['data',
#    'science',
#    'analytics',
#    'enterprise',
#    'software',
#    'ai',
#    'machine',
#    'learning',
#    'data',
#    'platform',
#    'ml',
#    'operationalization',
#    'etl',
#    'data',
#    'warehousing'],
#   ['celitech',
#    'enables',
#    'online',
#    'business',
#    'app',
#    'offer',
#    'cellular',
#    'data',
#    'esim',
#    'using',
#    'mobile',
#    'connectivity',
#    'analytics'],
#   ['fullservice',
#    'strategic',
#    'consultancy',
#    'mobile',
#    'web',
#    'technology',
#    'architecture',
#    'focus',
#    'humancentered',
#    'design'],
#   ['cerca',
#    'mobile',
#    'technology',
#    'enables',
#    'user',
#    'find',
#    'connect',
#    'people',
#    'move',
#    'forward'],
#   ['chat',
#    'goose',
#    'help',
#    'company',
#    'responsive',
#    'community',
#    'managing',
#    'chat',
#    'channel',
#    'first',
#    'product',
#    'bot',
#    'manager'],
#   ['easiest', 'way', 'create', 'paid', 'chat', 'group'],
#   ['chattr',
#    'retail',
#    'chatbot',
#    'platform',
#    'reinventing',
#    'way',
#    'candidate',
#    'employer',
#    'create',
#    'meaningful',
#    'connection',
#    'scale'],
#   ['checkplis', 'develops', 'software', 'restaurant', 'industry'],
#   ['mint', 'photo', 'blockchain'],
#   ['cherry', 'office', 'perk', 'solution', 'modern', 'startup'],
#   ['allinone', 'platform'],
#   ['cide',
#    'kic',
#    'provides',
#    'solution',
#    'serious',
#    'pain',
#    'point',
#    'within',
#    'hospitality',
#    'industry'],
#   ['clean',
#    'water',
#    'ai',
#    'ai',
#    'detects',
#    'dangerous',
#    'bacteria',
#    'ecoli',
#    'cholera',
#    'well',
#    'harmful',
#    'particle'],
#   ['clearat',
#    'technology',
#    'startup',
#    'provides',
#    'automated',
#    'sale',
#    'process',
#    'allows',
#    'u',
#    'save',
#    'time'],
#   ['clearcam',
#    'provides',
#    'clinician',
#    'innovative',
#    'tool',
#    'technology',
#    'improve',
#    'vision',
#    'skill',
#    'operating',
#    'room'],
#   ['clearlaw',
#    'provides',
#    'seamless',
#    'design',
#    'artificial',
#    'intelligence',
#    'innovative',
#    'natural',
#    'language',
#    'processing',
#    'tool'],
#   ['clerkie',
#    'ai',
#    'financial',
#    'planner',
#    'underserved',
#    'american',
#    'looking',
#    'answer'],
#   ['clerksy',
#    'new',
#    'outlook',
#    'human',
#    'capital',
#    'service',
#    'modern',
#    'company',
#    'inclusivehr'],
#   ['mobile', 'app', 'digital', 'medium', 'fashion', 'beauty', 'style'],
#   ['digital', 'health', 'clinic', 'workflow', 'solution'],
#   ['cloud',
#    'cien',
#    'firm',
#    'delivering',
#    'cloud',
#    'technology',
#    'customized',
#    'service'],
#   ['productiongrade', 'development', 'environment', 'coding', 'analytics'],
#   ['coderecipe',
#    'marketplace',
#    'developer',
#    'grab',
#    'ready',
#    'use',
#    'cloud',
#    'solution'],
#   ['coegil',
#    'help',
#    'anyone',
#    'load',
#    'visualize',
#    'predict',
#    'data',
#    'second',
#    'made',
#    'path',
#    'spreadsheet',
#    'big',
#    'data'],
#   ['cognaisent',
#    'specializes',
#    'field',
#    'machine',
#    'learning',
#    'deep',
#    'learning',
#    'artificial',
#    'intelligence',
#    'drug',
#    'discovery',
#    'molecular',
#    'analysis'],
#   ['cognida',
#    'network',
#    'open',
#    'source',
#    'platform',
#    'enable',
#    'enterprise',
#    'securely',
#    'manage',
#    'connected',
#    'device'],
#   ['command',
#    'e',
#    'develops',
#    'unified',
#    'desktop',
#    'search',
#    'tool',
#    'help',
#    'us',
#    'quickly',
#    'scour',
#    'file',
#    'data',
#    'source',
#    'across',
#    'nearly',
#    'every',
#    'app',
#    'use'],
#   ['blockchain',
#    'decentralized',
#    'organization',
#    'crypto',
#    'cryptocurrencies'],
#   ['commonwealth',
#    'lab',
#    'governance',
#    'startup',
#    'offering',
#    'new',
#    'twist',
#    'token',
#    'airdrop'],
#   ['companionmx', 'digital', 'health', 'technology', 'company'],
#   ['comprehensive',
#    'solution',
#    'business',
#    'size',
#    'complete',
#    'tech',
#    'solution',
#    'actively',
#    'manage',
#    'endtoend',
#    'need'],
#   ['innovative',
#    'writing',
#    'platform',
#    'available',
#    'designed',
#    'make',
#    'selfpublishing',
#    'easy',
#    'accessible',
#    'shareable',
#    'across',
#    'device'],
#   ['compt',
#    'perk',
#    'management',
#    'software',
#    'help',
#    'company',
#    'create',
#    'manage',
#    'streamline',
#    'perk',
#    'stipend',
#    'delight',
#    'employee'],
#   ['conalogix',
#    'llc',
#    'specializes',
#    'biotech',
#    'pharmaceutical',
#    'lifescience',
#    'focused',
#    'consulting',
#    'solution'],
#   ['concreit', 'provides', 'real', 'estate', 'software'],
#   ['condeto',
#    'nimble',
#    'property',
#    'management',
#    'tool',
#    'built',
#    'modern',
#    'age'],
#   ['confetti', 'collective', 'retailing', 'company'],
#   ['conflict',
#    'coach',
#    'receive',
#    'indepth',
#    'coaching',
#    'personalized',
#    'quick',
#    'reference',
#    'guide',
#    'constructive',
#    'conflict',
#    'conversation'],
#   ['software',
#    'mobile',
#    'app',
#    'development',
#    'web',
#    'design',
#    'digital',
#    'marketing'],
#   ['connector',
#    'secure',
#    'mobilefirst',
#    'webbased',
#    'platform',
#    'allows',
#    'surgical',
#    'team',
#    'easily',
#    'communicate',
#    'manage',
#    'patient',
#    'surgical',
#    'lifecycle'],
#   ['consentual',
#    'provides',
#    'videobased',
#    'esignature',
#    'platform',
#    'used',
#    'peertopeer',
#    'consent',
#    'agreement',
#    'contract'],
#   ['constellation',
#    'kidney',
#    'group',
#    'offer',
#    'software',
#    'solution',
#    'healthcare',
#    'industry'],
#   ['consumeroptix',
#    'front',
#    'office',
#    'insurtech',
#    'company',
#    'brings',
#    'intelligent',
#    'automation',
#    'personalization',
#    'consumer',
#    'insurance',
#    'distribution'],
#   ['contracthub',
#    'legal',
#    'operation',
#    'platform',
#    'streamlines',
#    'process',
#    'managing',
#    'document'],
#   ['conundrum',
#    'software',
#    'company',
#    'develops',
#    'social',
#    'networking',
#    'apps',
#    'software',
#    'iphone'],
#   ['convuent',
#    'software',
#    'development',
#    'company',
#    'provides',
#    'review',
#    'feedback',
#    'online',
#    'reputation',
#    'management',
#    'service'],
#   ['coosta',
#    'mortgage',
#    'collateral',
#    'transform',
#    'platform',
#    'secondary',
#    'market'],
#   ['datadriven',
#    'saas',
#    'platform',
#    'marketplace',
#    'b',
#    'b',
#    'b',
#    'furnishing',
#    'industry'],
#   ['coral',
#    'app',
#    'designed',
#    'help',
#    'cultivate',
#    'sexuality',
#    'transform',
#    'relationship',
#    'sex'],
#   ['coral',
#    'humancentric',
#    'robotics',
#    'company',
#    'designing',
#    'robot',
#    'people',
#    'enhance',
#    'everyday',
#    'life'],
#   ['corsha',
#    'api',
#    'security',
#    'platform',
#    'prevents',
#    'network',
#    'attack',
#    'dynamic',
#    'fully',
#    'automated',
#    'multifactor',
#    'authentication',
#    'apis'],
#   ['cortez',
#    'lab',
#    'software',
#    'company',
#    'engaged',
#    'development',
#    'salesforce',
#    'application'],
#   ['cost'],
#   ['counterfeittechnology', 'kill', 'counterfeiter', 'dead', 'track'],
#   ['coup',
#    'mobile',
#    'messaging',
#    'service',
#    'allows',
#    'consumer',
#    'send',
#    'text',
#    'discover',
#    'thousand',
#    'local',
#    'deal',
#    'nearby'],
#   ['coveware',
#    'aggregate',
#    'global',
#    'ransomware',
#    'cyber',
#    'extortion',
#    'data',
#    'minimize',
#    'related',
#    'cost',
#    'downtime'],
#   ['cowan',
#    'agency',
#    'made',
#    'expert',
#    'team',
#    'artist',
#    'player',
#    'work',
#    'turn',
#    'face',
#    'firm',
#    'creating',
#    'worldclass',
#    'service'],
#   ['cpnetio',
#    'brings',
#    'industry',
#    'technology',
#    'traditional',
#    'manufacturing',
#    'vertical'],
#   ['cr', 'score', 'college', 'admission', 'coach', 'pocket'],
#   ['digital', 'marketing', 'made', 'simple'],
#   ['developing', 'tool', 'service', 'solution', 'business', 'customer'],
#   ['cream',
#    'analytics',
#    'gotomarket',
#    'analytics',
#    'tool',
#    'provides',
#    'automated',
#    'answer',
#    'improve',
#    'financial',
#    'health'],
#   ['credit',
#    'washington',
#    'specializes',
#    'deep',
#    'application',
#    'research',
#    'precise',
#    'implementation',
#    'ai',
#    'machine',
#    'learning',
#    'data',
#    'science'],
#   ['cresance',
#    'us',
#    'ai',
#    'cut',
#    'cloud',
#    'operating',
#    'cost',
#    'using',
#    'algorithm',
#    'detect',
#    'wastage'],
#   ['datadriven',
#    'saas',
#    'platform',
#    'marketplace',
#    'b',
#    'b',
#    'b',
#    'furnishing',
#    'industry'],
#   ['coosta',
#    'mortgage',
#    'collateral',
#    'transform',
#    'platform',
#    'secondary',
#    'market'],
#   ['convuent',
#    'software',
#    'development',
#    'company',
#    'provides',
#    'review',
#    'feedback',
#    'online',
#    'reputation',
#    'management',
#    'service'],
#   ['conundrum',
#    'software',
#    'company',
#    'develops',
#    'social',
#    'networking',
#    'apps',
#    'software',
#    'iphone'],
#   ['contracthub',
#    'legal',
#    'operation',
#    'platform',
#    'streamlines',
#    'process',
#    'managing',
#    'document'],
#   ['consumeroptix',
#    'front',
#    'office',
#    'insurtech',
#    'company',
#    'brings',
#    'intelligent',
#    'automation',
#    'personalization',
#    'consumer',
#    'insurance',
#    'distribution'],
#   ['constellation',
#    'kidney',
#    'group',
#    'offer',
#    'software',
#    'solution',
#    'healthcare',
#    'industry'],
#   ['consentual',
#    'provides',
#    'videobased',
#    'esignature',
#    'platform',
#    'used',
#    'peertopeer',
#    'consent',
#    'agreement',
#    'contract'],
#   ['connector',
#    'secure',
#    'mobilefirst',
#    'webbased',
#    'platform',
#    'allows',
#    'surgical',
#    'team',
#    'easily',
#    'communicate',
#    'manage',
#    'patient',
#    'surgical',
#    'lifecycle'],
#   ['software',
#    'mobile',
#    'app',
#    'development',
#    'web',
#    'design',
#    'digital',
#    'marketing'],
#   ['conflict',
#    'coach',
#    'receive',
#    'indepth',
#    'coaching',
#    'personalized',
#    'quick',
#    'reference',
#    'guide',
#    'constructive',
#    'conflict',
#    'conversation'],
#   ['confetti', 'collective', 'retailing', 'company'],
#   ['condeto',
#    'nimble',
#    'property',
#    'management',
#    'tool',
#    'built',
#    'modern',
#    'age'],
#   ['concreit', 'provides', 'real', 'estate', 'software'],
#   ['conalogix',
#    'llc',
#    'specializes',
#    'biotech',
#    'pharmaceutical',
#    'lifescience',
#    'focused',
#    'consulting',
#    'solution'],
#   ['compt',
#    'perk',
#    'management',
#    'software',
#    'help',
#    'company',
#    'create',
#    'manage',
#    'streamline',
#    'perk',
#    'stipend',
#    'delight',
#    'employee'],
#   ['innovative',
#    'writing',
#    'platform',
#    'available',
#    'designed',
#    'make',
#    'selfpublishing',
#    'easy',
#    'accessible',
#    'shareable',
#    'across',
#    'device'],
#   ['comprehensive',
#    'solution',
#    'business',
#    'size',
#    'complete',
#    'tech',
#    'solution',
#    'actively',
#    'manage',
#    'endtoend',
#    'need'],
#   ['companionmx', 'digital', 'health', 'technology', 'company'],
#   ['commonwealth',
#    'lab',
#    'governance',
#    'startup',
#    'offering',
#    'new',
#    'twist',
#    'token',
#    'airdrop'],
#   ['blockchain',
#    'decentralized',
#    'organization',
#    'crypto',
#    'cryptocurrencies'],
#   ['crossliner', 'healthcare', 'firm', 'operating', 'stealth', 'mode'],
#   ['crimpd',
#    'climbingspecific',
#    'training',
#    'application',
#    'us',
#    'training',
#    'knowledge',
#    'data',
#    'analytics',
#    'lattice',
#    'training'],
#   ['cresance',
#    'us',
#    'ai',
#    'cut',
#    'cloud',
#    'operating',
#    'cost',
#    'using',
#    'algorithm',
#    'detect',
#    'wastage'],
#   ['credit',
#    'washington',
#    'specializes',
#    'deep',
#    'application',
#    'research',
#    'precise',
#    'implementation',
#    'ai',
#    'machine',
#    'learning',
#    'data',
#    'science'],
#   ['cream',
#    'analytics',
#    'gotomarket',
#    'analytics',
#    'tool',
#    'provides',
#    'automated',
#    'answer',
#    'improve',
#    'financial',
#    'health'],
#   ['developing', 'tool', 'service', 'solution', 'business', 'customer'],
#   ['digital', 'marketing', 'made', 'simple'],
#   ['cr', 'score', 'college', 'admission', 'coach', 'pocket'],
#   ['cpnetio',
#    'brings',
#    'industry',
#    'technology',
#    'traditional',
#    'manufacturing',
#    'vertical'],
#   ['cowan',
#    'agency',
#    'made',
#    'expert',
#    'team',
#    'artist',
#    'player',
#    'work',
#    'turn',
#    'face',
#    'firm',
#    'creating',
#    'worldclass',
#    'service'],
#   ['coveware',
#    'aggregate',
#    'global',
#    'ransomware',
#    'cyber',
#    'extortion',
#    'data',
#    'minimize',
#    'related',
#    'cost',
#    'downtime'],
#   ['coup',
#    'mobile',
#    'messaging',
#    'service',
#    'allows',
#    'consumer',
#    'send',
#    'text',
#    'discover',
#    'thousand',
#    'local',
#    'deal',
#    'nearby'],
#   ['counterfeittechnology', 'kill', 'counterfeiter', 'dead', 'track'],
#   ['cost'],
#   ['cortez',
#    'lab',
#    'software',
#    'company',
#    'engaged',
#    'development',
#    'salesforce',
#    'application'],
#   ['corsha',
#    'api',
#    'security',
#    'platform',
#    'prevents',
#    'network',
#    'attack',
#    'dynamic',
#    'fully',
#    'automated',
#    'multifactor',
#    'authentication',
#    'apis'],
#   ['cyber',
#    'list',
#    'offer',
#    'company',
#    'cybersecurity',
#    'protection',
#    'education',
#    'training',
#    'phishing',
#    'exercise'],
#   ['customerdb',
#    'software',
#    'firm',
#    'offer',
#    'saas',
#    'analytics',
#    'tool',
#    'productmarket',
#    'fit',
#    'optimizing',
#    'growth',
#    'market'],
#   ['curie',
#    'develops',
#    'artificial',
#    'intelligencebased',
#    'respiratory',
#    'health',
#    'monitoring',
#    'technology'],
#   ['cuore',
#    'platform',
#    'created',
#    'empower',
#    'financial',
#    'agent',
#    'providing',
#    'complete',
#    'digital',
#    'operational',
#    'hub',
#    'based',
#    'worldclass',
#    'technology'],
#   ['culture',
#    'genesis',
#    'digital',
#    'studio',
#    'focused',
#    'remixing',
#    'digital',
#    'technology',
#    'urban',
#    'multicultural',
#    'audience'],
#   ['culturalyst',
#    'software',
#    'company',
#    'build',
#    'digital',
#    'infrastructure',
#    'local',
#    'cultural',
#    'ecosystem'],
#   ['culdesac',
#    'offer',
#    'quick',
#    'easy',
#    'way',
#    'discover',
#    'new',
#    'outdoor',
#    'game',
#    'within',
#    'peer',
#    'group'],
#   ['cue',
#    'intelligence',
#    'provides',
#    'sale',
#    'service',
#    'scripting',
#    'software',
#    'conversational',
#    'intelligence'],
#   ['cuanto',
#    'allows',
#    'latin',
#    'american',
#    'creator',
#    'monetize',
#    'audience',
#    'sell',
#    'social',
#    'medium'],
#   ['cryptonet',
#    'service',
#    'global',
#    'leader',
#    'providing',
#    'innovative',
#    'web',
#    'hosting',
#    'solution',
#    'personal',
#    'commercial',
#    'businessrelated',
#    'need'],
#   ['crypto',
#    'key',
#    'stack',
#    'software',
#    'based',
#    'hardware',
#    'wallet',
#    'help',
#    'protect',
#    'key',
#    'transacting'],
#   ['crypto',
#    'disrupted',
#    'cryptocurrency',
#    'blockchain',
#    'youtube',
#    'channel',
#    'podcast',
#    'greg',
#    'kerr',
#    'trent',
#    'lapinski'],
#   ['saas',
#    'platform',
#    'enabling',
#    'equipment',
#    'dealer',
#    'conveniently',
#    'offer',
#    'financing',
#    'customer'],
#   ['daytoday',
#    'guide',
#    'patient',
#    'medical',
#    'procedure',
#    'help',
#    'recover',
#    'return',
#    'normal',
#    'life'],
#   ['saas', 'project', 'management', 'platform', 'construction'],
#   ['realtime',
#    'unstructured',
#    'data',
#    'transformation',
#    'inference',
#    'edge',
#    'cloud',
#    'saas',
#    'platform',
#    'providing',
#    'data',
#    'management',
#    'service'],
#   ['datanchor',
#    'develops',
#    'novel',
#    'cryptotechnology',
#    'anchor',
#    'data',
#    'consumption',
#    'within',
#    'network',
#    'boundary'],
#   ['datamode', 'data', 'pipeline', 'visibility', 'tool', 'data', 'engineer'],
#   ['databased',
#    'software',
#    'company',
#    'provides',
#    'automation',
#    'analytics',
#    'crm',
#    'solution',
#    'sale',
#    'team',
#    'understand',
#    'evaluate',
#    'develop'],
#   ['dashing',
#    'home',
#    'service',
#    'platform',
#    'us',
#    'blockchain',
#    'technology',
#    'create',
#    'ecosystem',
#    'homeowner',
#    'service',
#    'provider'],
#   ['dashcma',
#    'provides',
#    'interactive',
#    'dashboard',
#    'allows',
#    'give',
#    'meaningful',
#    'pricing',
#    'conversation',
#    'agent',
#    'client'],
#   ['dash',
#    'app',
#    'provides',
#    'mobile',
#    'payment',
#    'customer',
#    'engagement',
#    'platform',
#    'restaurant'],
#   ['dagda',
#    'partner',
#    'impact',
#    'investing',
#    'information',
#    'technology',
#    'company'],
#   ['dagan',
#    'provides',
#    'agricultural',
#    'environmental',
#    'data',
#    'service',
#    'support',
#    'expansion',
#    'regenerative',
#    'agriculture'],
#   ['data',
#    'vendor',
#    'reference',
#    'data',
#    'dacin',
#    'digital',
#    'asset',
#    'class',
#    'dlt',
#    'blockchain',
#    'capital',
#    'market',
#    'software',
#    'solution',
#    'data',
#    'management',
#    'b',
#    'b',
#    'service'],
#   ['devflight', 'business', 'model', 'opensource', 'software'],
#   ['destiny', 'debt', 'management', 'platform'],
#   ['deployhub',
#    'offer',
#    'hosted',
#    'next',
#    'generation',
#    'software',
#    'deployment',
#    'kubernetes',
#    'agile',
#    'devops',
#    'team'],
#   ['dentistai',
#    'software',
#    'automatically',
#    'detects',
#    'pathology',
#    'dental',
#    'imaging'],
#   ['denovium',
#    'artificial',
#    'intelligence',
#    'company',
#    'pioneering',
#    'novel',
#    'ai',
#    'method',
#    'accelerate',
#    'innovation',
#    'biopharma'],
#   ['denovers',
#    'company',
#    'specialized',
#    'uiux',
#    'design',
#    'b',
#    'b',
#    'design',
#    'development'],
#   ['demandstar',
#    'connects',
#    'business',
#    'local',
#    'government',
#    'contracting',
#    'opportunity'],
#   ['demand',
#    'iq',
#    'provides',
#    'software',
#    'managed',
#    'service',
#    'clean',
#    'energy',
#    'industry'],
#   ['delic',
#    'psychedelics',
#    'corporation',
#    'specializes',
#    'education',
#    'content',
#    'event',
#    'psychoactive',
#    'compound'],
#   ['delfin', 'virtual', 'advisor', 'energy', 'industry'],
#   ['deepwalk',
#    'research',
#    'develops',
#    'mobile',
#    'application',
#    'supplement',
#    'construction',
#    'survey',
#    'precision',
#    'model'],
#   ['deephow',
#    'develops',
#    'aipowered',
#    'learning',
#    'platform',
#    'manufacturing',
#    'service',
#    'repair'],
#   ['intelligent', 'instrumentation', 'synthetic', 'biology'],
#   ['deepcuris', 'build', 'ai', 'engine', 'smallmolecule', 'drug', 'discovery'],
#   ['photorealistic', 'avatar', 'scale'],
#   ['displayride',
#    'innovator',
#    'focused',
#    'enhancing',
#    'rideshare',
#    'experience'],
#   ['discreetai',
#    'build',
#    'service',
#    'privacypreserving',
#    'machine',
#    'learning',
#    'mobile',
#    'web',
#    'server'],
#   ['dirt',
#    'protocol',
#    'decentralized',
#    'information',
#    'curation',
#    'us',
#    'token',
#    'staking',
#    'incentivize',
#    'honesty'],
#   ['suggestion', 'box', 'reimagined'],
#   ['software',
#    'help',
#    'direct',
#    'seller',
#    'save',
#    'time',
#    'managing',
#    'growing',
#    'business'],
#   ['saas', 'law', 'enforcement', 'public', 'safety', 'mobile', 'apps'],
#   ['digital',
#    'water',
#    'work',
#    'engineering',
#    'technology',
#    'solution',
#    'provider',
#    'dedicated',
#    'innovating',
#    'exclusively',
#    'global',
#    'water',
#    'industry'],
#   ['digital',
#    'capital',
#    'management',
#    'fund',
#    'management',
#    'firm',
#    'offering',
#    'portfolio',
#    'management',
#    'digital',
#    'asset',
#    'fund',
#    'plan',
#    'different',
#    'investor'],
#   ['drum',
#    'new',
#    'gig',
#    'economy',
#    'platform',
#    'aim',
#    'improve',
#    'life',
#    'million'],
#   ['drslinq',
#    'developing',
#    'mobile',
#    'ekg',
#    'device',
#    'platform',
#    'appropriately',
#    'triage',
#    'chest',
#    'pain',
#    'patient',
#    'er'],
#   ['dropshot',
#    'capital',
#    'management',
#    'investment',
#    'firm',
#    'offer',
#    'ai',
#    'machine',
#    'learning',
#    'solution',
#    'systematic',
#    'trading',
#    'investment'],
#   ['drop',
#    'cowboy',
#    'direct',
#    'voicemail',
#    'worldwide',
#    'mass',
#    'messaging',
#    'system'],
#   ['drivewayz', 'mobile', 'app', 'show', 'parking', 'option', 'city'],
#   ['drivetime',
#    'provides',
#    'online',
#    'platform',
#    'designed',
#    'help',
#    'user',
#    'play',
#    'game',
#    'drive'],
#   ['driver',
#    'hardwarefree',
#    'mobile',
#    'app',
#    'allows',
#    'user',
#    'video',
#    'record',
#    'trip',
#    'receiving',
#    'safety',
#    'alert'],
#   ['healthcare', 'saas'],
#   ['dragonglass',
#    'hardware',
#    'design',
#    'manufacturing',
#    'company',
#    'blockchain',
#    'cloud',
#    'computing',
#    'space'],
#   ['shop',
#    'mobile',
#    'shopping',
#    'network',
#    'showcase',
#    'product',
#    'original',
#    'hilarious',
#    'characterdriven',
#    'content'],
#   ['dowallet',
#    'rapidly',
#    'growing',
#    'decentralized',
#    'financial',
#    'service',
#    'hub',
#    'hold',
#    'manage',
#    'crypto',
#    'fiat',
#    'asset'],
#   ['purveyor', 'friendly', 'competition'],
#   ['dottid',
#    'commercial',
#    'real',
#    'estate',
#    'softwareasaservice',
#    'technology',
#    'platform'],
#   ['doppler',
#    'provides',
#    'application',
#    'management',
#    'platform',
#    'used',
#    'help',
#    'developer',
#    'manage',
#    'api',
#    'key',
#    'across',
#    'project'],
#   ['team', 'health', 'platform'],
#   ['donut', 'mobile', 'app', 'save', 'earn', 'high', 'yield', 'defi'],
#   ['donorup',
#    'first',
#    'giving',
#    'platform',
#    'focus',
#    'individual',
#    'donor',
#    'help',
#    'refine',
#    'imprint',
#    'world'],
#   ['eiffel',
#    'group',
#    'team',
#    'consultant',
#    'developer',
#    'specialized',
#    'odoo',
#    'integration',
#    'erp',
#    'software'],
#   ['diy',
#    'online',
#    'supply',
#    'chain',
#    'platform',
#    'diy',
#    'custom',
#    'clearance',
#    'process'],
#   ['edupixel',
#    'online',
#    'education',
#    'platform',
#    'dedicated',
#    'empowering',
#    'creative',
#    'workforce',
#    'teaching',
#    'new',
#    'skill',
#    'tool'],
#   ['eddii',
#    'virtual',
#    'app',
#    'character',
#    'designed',
#    'engage',
#    'people',
#    'living',
#    'diabetes',
#    'track',
#    'record',
#    'health'],
#   ['founded',
#    'passion',
#    'education',
#    'whether',
#    'academic',
#    'student',
#    'lifelong',
#    'learner',
#    'help',
#    'create',
#    'next',
#    'learning',
#    'moment'],
#   ['echoar',
#    'delivers',
#    'augmented',
#    'reality',
#    'training',
#    'experience',
#    'mental',
# ...
#    'strategic',
#    'planning',
#    'performance',
#    'management',
#    'service'],
#   ['schoolrio',
#    'creating',
#    'new',
#    'market',
#    'online',
#    'education',
#    'student',
#    'simple',
#    'affordable',
#    'way',
#    'get',
#    'personalized',
#    'solution'],
#   ['schaller',
#    'garvin',
#    'associate',
#    'provides',
#    'billing',
#    'service',
#    'business',
#    'decision',
#    'support',
#    'medical',
#    'industry'],
#   ['scenethink',
#    'connects',
#    'event',
#    'creator',
#    'directly',
#    'local',
#    'influencers',
#    'drive',
#    'attendance',
#    'event'],
#   ['satisfactor',
#    'tool',
#    'spanish',
#    'measure',
#    'loyalty',
#    'customer',
#    'company',
#    'offer',
#    'survey',
#    'via',
#    'web',
#    'email'],
#   ['satira', 'provider', 'professional', 'comedy', 'coaching', 'service'],
#   ['transparent',
#    'riskmanaged',
#    'cryptocurrency',
#    'investment',
#    'fund',
#    'plus',
#    'digital',
#    'asset',
#    'education',
#    'investor',
#    'financial',
#    'advisor'],
#   ['santacom', 'official', 'site', 'santa', 'oh', 'yes', 'im', 'real'],
#   ['sander',
#    'consulting',
#    'provides',
#    'managed',
#    'service',
#    'cybersecurity',
#    'training',
#    'consulting',
#    'service',
#    'small',
#    'business'],
#   ['sandbox',
#    'system',
#    'software',
#    'company',
#    'created',
#    'collaborative',
#    'online',
#    'ide',
#    'called',
#    'makai'],
#   ['salvo',
#    'software',
#    'offer',
#    'software',
#    'erp',
#    'web',
#    'development',
#    'software',
#    'consulting',
#    'service'],
#   ['saltycloud',
#    'provides',
#    'access',
#    'workflow',
#    'automation',
#    'tool',
#    'help',
#    'maximize',
#    'impact',
#    'security',
#    'risk',
#    'team'],
#   ['salt',
#    'city',
#    'tech',
#    'offer',
#    'wide',
#    'range',
#    'consulting',
#    'information',
#    'technology',
#    'management',
#    'managed',
#    'service'],
#   ['salespype',
#    'software',
#    'solution',
#    'combine',
#    'crm',
#    'builtin',
#    'automation',
#    'solution'],
#   ['business', 'development', 'training', 'education', 'saas'],
#   ['premier',
#    'resource',
#    'peer',
#    'community',
#    'salesrevenue',
#    'leader',
#    'chicago',
#    'top',
#    'highgrowth',
#    'tech',
#    'company'],
#   ['local', 'data', 'science', 'firm'],
#   ['every', 'patient', 'deserves', 'safe', 'effective', 'medication'],
#   ['rxbridge',
#    'information',
#    'technology',
#    'health',
#    'care',
#    'service',
#    'industry',
#    'specialized',
#    'transparency',
#    'white',
#    'glove',
#    'customer',
#    'service'],
#   ['royce',
#    'technical',
#    'consulting',
#    'firm',
#    'specializes',
#    'search',
#    'recruiting'],
#   ['royal',
#    'specializes',
#    'document',
#    'management',
#    'printing',
#    'infrastructure',
#    'service'],
#   ['routefire',
#    'provider',
#    'trade',
#    'execution',
#    'infrastructure',
#    'digital',
#    'asset',
#    'space'],
#   ['route',
#    'dynamic',
#    'develops',
#    'platform',
#    'intended',
#    'automate',
#    'aviation',
#    'routing'],
#   ['rosint', 'lab', 'solves', 'problem', 'software', 'technology'],
#   ['rosebud',
#    'woman',
#    'make',
#    'exquisite',
#    'intimate',
#    'skin',
#    'body',
#    'care',
#    'formulation'],
#   ['root',
#    'banking',
#    'mobile',
#    'application',
#    'provides',
#    'digital',
#    'banking',
#    'financial',
#    'service'],
#   ['roomnett',
#    'shared',
#    'accommodation',
#    'roommate',
#    'finder',
#    'website',
#    'app',
#    'find',
#    'likeminded',
#    'roommate',
#    'share',
#    'home'],
#   ['rocketmomo', 'web', 'design', 'development', 'company'],
#   ['company', 'use', 'rocket', 'solve', 'recruiting', 'need'],
#   ['ondemand', 'mobile', 'store'],
#   ['roboamp', 'application', 'web', 'lightning', 'fast'],
#   ['robhat',
#    'lab',
#    'developer',
#    'online',
#    'web',
#    'browsing',
#    'tool',
#    'intended',
#    'tackle',
#    'spread',
#    'fake',
#    'news',
#    'misinformation'],
#   ['roastertools',
#    'keep',
#    'roastery',
#    'running',
#    'smoothly',
#    'business',
#    'profitable',
#    'focus',
#    'roasting',
#    'great',
#    'coffee'],
#   ['roam',
#    'research',
#    'tool',
#    'offer',
#    'service',
#    'notetaking',
#    'graph',
#    'database'],
#   ['rivet',
#    'lab',
#    'automation',
#    'software',
#    'develops',
#    'recurring',
#    'revenue',
#    'cash',
#    'forecasting',
#    'application'],
#   ['riskcast',
#    'solution',
#    'productivity',
#    'forecasting',
#    'tool',
#    'provides',
#    'way',
#    'project',
#    'manager',
#    'track',
#    'labor',
#    'material',
#    'equipment'],
#   ['risk',
#    'lab',
#    'open',
#    'source',
#    'protocol',
#    'synthetic',
#    'risk',
#    'transfer'],
#   ['rip',
#    'city',
#    'software',
#    'provides',
#    'microservices',
#    'architecture',
#    'coaching',
#    'education',
#    'service'],
#   ['accounting',
#    'firm',
#    'provider',
#    'cloud',
#    'accounting',
#    'software',
#    'growing',
#    'organization',
#    'florida',
#    'southeastern',
#    'u'],
#   ['rightair', 'developing', 'noninvasive', 'ventilator', 'copd', 'patient'],
#   ['rig',
#    'callout',
#    'cloudbased',
#    'communication',
#    'platform',
#    'provides',
#    'shipping',
#    'logistics',
#    'service'],
#   ['medium', 'based', 'review', 'site'],
#   ['ridealong',
#    'software',
#    'tool',
#    'give',
#    'patrol',
#    'officer',
#    'key',
#    'information',
#    'people',
#    'mental',
#    'illness'],
#   ['rhabits',
#    'lightweight',
#    'easytouse',
#    'platform',
#    'transforms',
#    'feedback',
#    'powerful',
#    'performance',
#    'insight',
#    'employee',
#    'manager',
#    'leadership'],
#   ['streamlined',
#    'procurement',
#    'distribution',
#    'used',
#    'supply',
#    'structure',
#    'access',
#    'egress',
#    'industrial',
#    'company'],
#   ['rewardzzz', 'blockchain', 'app'],
#   ['revokind',
#    'provides',
#    'blockchain',
#    'network',
#    'solution',
#    'developing',
#    'artificially',
#    'intelligent',
#    'autonomous',
#    'communication',
#    'system'],
#   ['review',
#    'maiden',
#    'creative',
#    'tool',
#    'review',
#    'management',
#    'allows',
#    'local',
#    'company',
#    'receive',
#    'feedback',
#    'automatically',
#    'current',
#    'customer'],
#   ['reverie', 'lab', 'machine', 'learningdriven', 'pharma', 'company'],
#   ['reveal',
#    'us',
#    'ai',
#    'advanced',
#    'natural',
#    'language',
#    'processing',
#    'advanced',
#    'analytics',
#    'address',
#    'threat',
#    'brand',
#    'reputation'],
#   ['retinaai',
#    'develop',
#    'artificial',
#    'intelligence',
#    'software',
#    'diagnosing',
#    'retinal',
#    'disease',
#    'image',
#    'retina'],
#   ['respirogen',
#    'feature',
#    'device',
#    'technology',
#    'provides',
#    'oxygen',
#    'independent',
#    'damaged',
#    'lung',
#    'like',
#    'acute',
#    'respiratory',
#    'distress',
#    'syndrome'],
#   ['scale',
#    'quality',
#    'customer',
#    'support',
#    'affordable',
#    'flexible',
#    'service',
#    'available'],
#   ['resermine', 'aienabled', 'platform', 'decision', 'making', 'surveillance'],
#   ['repetere',
#    'generates',
#    'automated',
#    'sale',
#    'product',
#    'mix',
#    'forecast',
#    'machine',
#    'learning',
#    'artificial',
#    'intelligence'],
#   ['rengen',
#    'lab',
#    'easiest',
#    'trusted',
#    'place',
#    'connect',
#    'company',
#    'issuing',
#    'private',
#    'equity',
#    'security',
#    'token',
#    'offering'],
#   ['remote', 'meeting', 'reinvented'],
#   ['remedia', 'advanced', 'medical', 'data', 'analytics', 'company'],
#   ['reliable',
#    'web',
#    'solution',
#    'platform',
#    'providing',
#    'wide',
#    'spectrum',
#    'service',
#    'related',
#    'creation',
#    'mobile',
#    'responsive',
#    'design',
#    'seo'],
#   ['relex',
#    'world',
#    'first',
#    'cryptocurrency',
#    'based',
#    'real',
#    'estate',
#    'developer',
#    'opportunity'],
#   ['related',
#    'work',
#    'research',
#    'product',
#    'strategy',
#    'firm',
#    'provides',
#    'data',
#    'research',
#    'product',
#    'strategy',
#    'company'],
#   ['refirm',
#    'lab',
#    'group',
#    'iot',
#    'security',
#    'expert',
#    'develops',
#    'new',
#    'method',
#    'vetting',
#    'validating',
#    'firmware'],
#   ['earn', 'cash', 'back', 'commission', 'thousand', 'store', 'brand'],
#   ['social', 'platform', 'bringing', 'wine', 'appreciation', 'everyone'],
#   ['redemption',
#    'technology',
#    'source',
#    'ecommerce',
#    'marketplace',
#    'platform',
#    'anonymously',
#    'allows',
#    'subscriber',
#    'pay',
#    'cryptocurrency',
#    'anywhere'],
#   ['red',
#    'sunflower',
#    'specializes',
#    'website',
#    'ecommerce',
#    'mobile',
#    'apps',
#    'ux',
#    'design',
#    'cybersecurity',
#    'help',
#    'business',
#    'improve',
#    'web',
#    'presence'],
#   ['red',
#    'mountain',
#    'scientific',
#    'provides',
#    'data',
#    'needed',
#    'effectively',
#    'manage',
#    'wind',
#    'turbine',
#    'cell',
#    'tower',
#    'asset'],
#   ['ai',
#    'based',
#    'application',
#    'personalizes',
#    'gift',
#    'purchasing',
#    'experience',
#    'special',
#    'life',
#    'event',
#    'like',
#    'birthday',
#    'anniversary'],
#   ['professional', 'networking', 'saas'],
#   ['recruitchute', 'recruiting', 'platform', 'college', 'soccer'],
#   ['recruitbot',
#    'provides',
#    'recruitment',
#    'service',
#    'using',
#    'big',
#    'data',
#    'machine',
#    'learning',
#    'technology'],
#   ['web', 'application'],
#   ['realty',
#    'shine',
#    'software',
#    'real',
#    'estate',
#    'integrated',
#    'website',
#    'property',
#    'management',
#    'marketing'],
#   ['realtime', 'digital', 'innovation', 'software', 'company'],
#   ['realitynext',
#    'education',
#    'technology',
#    'teen',
#    'make',
#    'share',
#    'vr',
#    'storygames'],
#   ['read',
#    'doc',
#    'focus',
#    'writing',
#    'high',
#    'quality',
#    'documentation',
#    'restructuredtext',
#    'markdown',
#    'specification'],
#   ['rare',
#    'bit',
#    'zerofee',
#    'peertopeer',
#    'marketplace',
#    'buy',
#    'sell',
#    'discover',
#    'crypto',
#    'good'],
#   ['rapid',
#    'imaging',
#    'provides',
#    'innovative',
#    'imaging',
#    'solution',
#    'significant',
#    'problem'],
#   ['real', 'estate', 'admin', 'made', 'simple'],
#   ['rannko',
#    'offer',
#    'full',
#    'stack',
#    'software',
#    'review',
#    'reputation',
#    'management',
#    'digital',
#    'presence',
#    'social',
#    'medium'],
#   ['help', 'nonprofit', 'acquire', 'retain', 'donor'],
#   ['raise',
#    'barr',
#    'technology',
#    'company',
#    'creates',
#    'corporate',
#    'diversity',
#    'inclusion',
#    'training'],
#   ['radix', 'lab', 'aim', 'operating', 'system', 'laboratory'],
#   ['one', 'pas', 'race', 'worldwide'],
#   ['r',
#    'score',
#    'mobile',
#    'responsive',
#    'collaborative',
#    'application',
#    'enables',
#    'government',
#    'efficiently',
#    'enforce',
#    'fair',
#    'hiring',
#    'legislation'],
#   ['data', 'orchestration', 'platform', 'consumer', 'fintech'],
#   ['quickze', 'restaurant', 'app'],
#   ['use',
#    'one',
#    'service',
#    'explore',
#    'broadcast',
#    'social',
#    'medium',
#    'currently',
#    'stealth',
#    'mode',
#    'launching',
#    'soon'],
#   ['quantum',
#    'softech',
#    'group',
#    'focus',
#    'development',
#    'erp',
#    'system',
#    'accounting',
#    'software',
#    'solution'],
#   ['complete', 'iot', 'platform', 'electronic', 'hobby', 'enthusiast'],
#   ['quantum',
#    'insight',
#    'find',
#    'hidden',
#    'meaning',
#    'complex',
#    'data',
#    'using',
#    'physic',
#    'quantum',
#    'mechanic'],
#   ['quantiport',
#    'innovative',
#    'technology',
#    'quickly',
#    'easily',
#    'accurately',
#    'measure',
#    'blood',
#    'volume'],
#   ['utilizing', 'new', 'technology', 'advance', 'medical', 'research'],
#   ['qlogix',
#    'entertainment',
#    'edtech',
#    'engages',
#    'child',
#    'background',
#    'learn',
#    'stem',
#    'fun',
#    'interactive',
#    'innovative',
#    'play'],
#   ['qknow',
#    'get',
#    'employee',
#    'engaged',
#    'learning',
#    'help',
#    'employee',
#    'remember',
#    'training',
#    'automates',
#    'process',
#    'save',
#    'time'],
#   ['q',
#    'empowers',
#    'healthcare',
#    'team',
#    'insightful',
#    'actionable',
#    'data',
#    'drive',
#    'improvement',
#    'patient',
#    'engagement',
#    'treatment',
#    'plan',
#    'adherence'],
#   ['pyrus',
#    'consulting',
#    'group',
#    'offer',
#    'enterprise',
#    'resource',
#    'planning',
#    'solution',
#    'service'],
#   ['modern', 'sale', 'operation', 'platform', 'retail'],
#   ['purepost',
#    'publicbenefit',
#    'corporation',
#    'veteran',
#    'veteran',
#    'champion'],
#   ['civic',
#    'engagement',
#    'platform',
#    'connecting',
#    'citizen',
#    'elected',
#    'representative'],
#   ['protosure',
#    'cloudbased',
#    'programmingfree',
#    'submit',
#    'underwrite',
#    'rate',
#    'quote',
#    'policy',
#    'issuance',
#    'system'],
#   ['propfuel', 'voice', 'member', 'platform', 'built', 'association'],
#   ['one', 'shortterm', 'rental', 'compliance'],
#   ['promanage',
#    'technology',
#    'company',
#    'working',
#    'iiot',
#    'ar',
#    'ai',
#    'technology',
#    'area',
#    'manufacturing',
#    'operation',
#    'management'],
#   ['prologmobile', 'mobile', 'device', 'analytics', 'transaction', 'company'],
#   ['projectric',
#    'combine',
#    'resource',
#    'management',
#    'project',
#    'management',
#    'single',
#    'project',
#    'portfolio',
#    'management',
#    'software',
#    'solution'],
#   ['build', 'meaningful', 'relationship'],
#   ['project',
#    'phoenix',
#    'software',
#    'company',
#    'develops',
#    'universal',
#    'business',
#    'web',
#    'service',
#    'toolset',
#    'every',
#    'developer',
#    'use'],
#   ['process',
#    'server',
#    'technology',
#    'powerful',
#    'webbased',
#    'platform',
#    'mobile',
#    'app',
#    'instantly',
#    'connects',
#    'law',
#    'firm'],
#   ['probability',
#    'statistic',
#    'provides',
#    'blockchain',
#    'development',
#    'artificial',
#    'intelligence',
#    'software',
#    'development',
#    'service'],
#   ['privops',
#    'offer',
#    'digital',
#    'transformation',
#    'platform',
#    'control',
#    'data'],
#   ['prime',
#    'foray',
#    'offer',
#    'cloud',
#    'computing',
#    'consulting',
#    'information',
#    'technology',
#    'marketing',
#    'service'],
#   ['prescribe', 'fit', 'promotes', 'adaptation', 'healthy', 'lifestyle'],
#   ['app',
#    'development',
#    'mobile',
#    'development',
#    'aws',
#    'io',
#    'app',
#    'development',
#    'android',
#    'app',
#    'development',
#    'backend',
#    'development',
#    'spring',
#    'angular'],
#   ['prepaid',
#    'program',
#    'management',
#    'prepaid',
#    'card',
#    'program',
#    'management',
#    'firm',
#    'develops',
#    'manages',
#    'payment',
#    'processing',
#    'solution'],
#   ['prelude',
#    'autonomous',
#    'red',
#    'team',
#    'tool',
#    'packaged',
#    'desktop',
#    'application'],
#   ['online',
#    'referral',
#    'marketplace',
#    'world',
#    'go',
#    'hire',
#    'refer',
#    'friend',
#    'find',
#    'job'],
#   ['predictmx',
#    'enables',
#    'company',
#    'make',
#    'informed',
#    'decision',
#    'operational',
#    'readiness',
#    'maintenance',
#    'need',
#    'mobile',
#    'equipment'],
#   ['predictive',
#    'trading',
#    'system',
#    'aipowered',
#    'datadriven',
#    'cloudbased',
#    'decision',
#    'making',
#    'investment',
#    'management'],
#   ['predictionhealth',
#    'automates',
#    'documentation',
#    'bringing',
#    'machine',
#    'learning',
#    'daily',
#    'clinical',
#    'practice'],
#   ['predictim',
#    'provides',
#    'new',
#    'innovative',
#    'way',
#    'vet',
#    'people',
#    'instantly',
#    'using',
#    'artificial',
#    'intelligence',
#    'alternative',
#    'data'],
#   ['precizion',
#    'solution',
#    'provides',
#    'data',
#    'science',
#    'analytics',
#    'service'],
#   ['virtual', 'socializing', 'recognition', 'platform', 'business', 'team'],
#   ['preceptor',
#    'security',
#    'group',
#    'developing',
#    'class',
#    'physical',
#    'security',
#    'program',
#    'system',
#    'technology',
#    'solution'],
#   ['prana',
#    'software',
#    'software',
#    'development',
#    'company',
#    'offer',
#    'custom',
#    'software',
#    'solution',
#    'enterprise'],
#   ['pozotron', 'develops', 'software', 'computer', 'speech', 'processing'],
#   ['potent',
#    'system',
#    'game',
#    'software',
#    'industry',
#    'provides',
#    'gambling',
#    'app',
#    'development',
#    'video',
#    'game'],
#   ['postalytics',
#    'selfserve',
#    'direct',
#    'mail',
#    'automation',
#    'tool',
#    'look',
#    'act',
#    'feel',
#    'like',
#    'digital',
#    'channel'],
#   ...]]
