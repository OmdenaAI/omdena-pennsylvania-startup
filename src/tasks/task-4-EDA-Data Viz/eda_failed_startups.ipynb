# %%
import pandas as pd
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv(r'D:\Omdena\cleaned_failed_startup.csv')

# %%
df
# Out:
#                             Company Description             Category  \
# 0       Anonymous location-based social network         Social Media
# 1   Platform to share short looping video clips         Social Media
# 2        Platform for mobile interaction design               Design
# 3                 Short-form streaming platform        Entertainment
# 4      Finance and accounting software for SMEs             Finances
# ..                                          ...                  ...
# 79  Launching rockets into space from airplanes       Transportation
# 80            Augmented driving device for cars       Transportation
# 81      Building emotionally intelligent robots  Software & Hardware
# 82               Gourmet meals at your doorstep      Food & Beverage
# 83                Short-form streaming platform        Entertainment
#
#        Outcome             Cause  Total Funding Amount  Number of Investors  \
# ...

# %%
df.shape
# Out:
# (84, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Description   84 non-null     object
#  1   Category              84 non-null     object
#  2   Outcome               84 non-null     object
#  3   Cause                 84 non-null     object
#  4   Total Funding Amount  84 non-null     int64
#  5   Number of Investors   84 non-null     int64
#  6   Min Employees         84 non-null     int64
#  7   Max Employees         84 non-null     int64
#  8   Average Employees     84 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        Total Funding Amount  Number of Investors  Min Employees  \
# count          8.400000e+01            84.000000      84.000000
# mean           9.004145e+07           -14.345238     355.880952
# std            3.117062e+08           154.935548    1612.029735
# min           -9.990000e+02          -999.000000       1.000000
# 25%            2.225000e+06             3.000000      10.000000
# 50%            1.120000e+07             7.500000      10.000000
# 75%            4.272500e+07            13.250000      50.000000
# max            1.800000e+09            39.000000   10000.000000
#
#        Max Employees  Average Employees
# count      84.000000          84.000000
# mean      611.190476         483.452381
# std      2513.093138        2059.932736
# min        10.000000           5.000000
# 25%        50.000000          30.000000
# 50%        50.000000          30.000000
# 75%       100.000000          75.000000
# max     15000.000000       12500.000000

# %%
df.count()
# Out:
# Company Description     84
# Category                84
# Outcome                 84
# Cause                   84
# Total Funding Amount    84
# Number of Investors     84
# Min Employees           84
# Max Employees           84
# Average Employees       84
# dtype: int64

# %%
#check for outliers
sns.boxplot(x=df["Total Funding Amount"])
# Out:
# <AxesSubplot:xlabel='Total Funding Amount'>

# %%
sns.boxplot(x=df['Number of Investors'])
# Out:
# <AxesSubplot:xlabel='Number of Investors'>

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3-q1
print(IQR)
# Out:
# Total Funding Amount    40500000.00
# Number of Investors           10.25
# Min Employees                 40.00
# Max Employees                 50.00
# Average Employees             45.00
# dtype: float64

# %%
# Correlation between funding amt and avg no. of employees
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Total Funding Amount'], df['Average Employees'])
ax.set_xlabel('Total Funding Amount')
ax.set_ylabel('Average Employees')
plt.show()

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_notebook_iframe()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-09 21:09:38.658134&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
