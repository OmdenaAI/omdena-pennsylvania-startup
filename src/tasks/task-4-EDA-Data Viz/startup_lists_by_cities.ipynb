# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt  #for data visualization
# Out:
# C:\Users\a\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv("startup_list_by_cities.csv")
data
# Out:
#                 city                           name  \
# 0            Atlanta      SaferCodes Vovid QR codes
# 1            Atlanta                      EarthLink
# 2            Atlanta                 Ionic Security
# 3            Atlanta                      TripLingo
# 4            Atlanta  invitation codes app referral
# ...              ...                            ...
# 25416  Washington DC                          Crumz
# 25417  Washington DC            MicroTeachings Inc.
# 25418  Washington DC                 Avenger Mobile
# 25419  Washington DC                      LogicNets
# 25420  Washington DC                    Vilvas Inc.
#
#                                 link  \
# 0                 https://parser.run
# 1          http://www.earthlink.net/
# 2          http://ionicsecurity.com/
# 3           http://www.triplingo.com
# 4           https://invitation.codes
# ...                              ...
# 25416         http://Domain Avaiable
# ...

# %%
# understaning the data

# %%
data.head()
# Out:
#       city                           name                       link  \
# 0  Atlanta      SaferCodes Vovid QR codes         https://parser.run
# 1  Atlanta                      EarthLink  http://www.earthlink.net/
# 2  Atlanta                 Ionic Security  http://ionicsecurity.com/
# 3  Atlanta                      TripLingo   http://www.triplingo.com
# 4  Atlanta  invitation codes app referral   https://invitation.codes
#
#                                          description
# 0  \nData as a service.\nSimple, custom web scrap...
# 1                                              \n \n
# 2  \n The Unified Data and Mobility Security Plat...
# 3  \n Customized language and culture learning fo...
# 4  \nThe referral community\nInvitation App is a ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                 city                           name  \
# 0            Atlanta      SaferCodes Vovid QR codes
# 1            Atlanta                      EarthLink
# 2            Atlanta                 Ionic Security
# 3            Atlanta                      TripLingo
# 4            Atlanta  invitation codes app referral
# ...              ...                            ...
# 25416  Washington DC                          Crumz
# 25417  Washington DC            MicroTeachings Inc.
# 25418  Washington DC                 Avenger Mobile
# 25419  Washington DC                      LogicNets
# 25420  Washington DC                    Vilvas Inc.
#
#                                 link  \
# 0                 https://parser.run
# 1          http://www.earthlink.net/
# 2          http://ionicsecurity.com/
# 3           http://www.triplingo.com
# 4           https://invitation.codes
# ...                              ...
# 25416         http://Domain Avaiable
# ...

# %%
data.describe()
# Out:
#             city              name                   link description
# count      25421             25420                  25023       25421
# unique        11             24938                  24544       22420
# top     New York  nowboarding.club  http://www.google.com       \n \n
# freq        8150                11                     15        2894

# %%
data.columns
# Out:
# Index(['city', 'name', 'link', 'description'], dtype='object')

# %%
data.nunique()
# Out:
# city              11
# name           24938
# link           24544
# description    22420
# dtype: int64

# %%
data['city'].unique()
# Out:
# array(['Atlanta', 'Austin', 'Boston', 'Boulder', 'Chicago', 'Houston',
#        'Los Angeles', 'New York', 'San Francisco', 'Seattle',
#        'Washington DC'], dtype=object)

# %%
data.shape
# Out:
# (25421, 4)

# %%
#cleaning  the data

# %%
data.isnull().sum()
# Out:
# city             0
# name             1
# link           398
# description      0
# dtype: int64

# %%
 data.drop(['link'],axis=1,inplace=True)
 data.head()
# Out:
#       city                           name  \
# 0  Atlanta      SaferCodes Vovid QR codes
# 1  Atlanta                      EarthLink
# 2  Atlanta                 Ionic Security
# 3  Atlanta                      TripLingo
# 4  Atlanta  invitation codes app referral
#
#                                          description
# 0  \nData as a service.\nSimple, custom web scrap...
# 1                                              \n \n
# 2  \n The Unified Data and Mobility Security Plat...
# 3  \n Customized language and culture learning fo...
# 4  \nThe referral community\nInvitation App is a ...

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = STOPWORDS
wordcloud = WordCloud(width=800,height=400,stopwords=stopwords, min_font_size=10,max_words=150).generate(' '.join
                                                                                           (data['description']))

# %%
plt.figure(figsize=(20,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.title("Wordcloud of description", fontsize=25)
plt.savefig('1.jpeg')
plt.show()

# %%
wordcloud1 = WordCloud(width=800,height=400,stopwords=stopwords, min_font_size=10,max_words=150).generate(' '.join
                                                                                           (data['city']))

# %%
plt.figure(figsize=(20,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.title("Wordcloud of state", fontsize=25)
plt.savefig('2.jpeg')
plt.show()
