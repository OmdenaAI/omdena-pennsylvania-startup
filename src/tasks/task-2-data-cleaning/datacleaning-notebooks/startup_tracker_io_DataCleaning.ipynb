# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path = "/content/drive/MyDrive/Omdena/startup_tracker_io.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                                          description  ... Unnamed: 19
# 0  '#1 Social Justice Network: Civil Rights Tools...  ...         NaN
# 1  'A Better Business Dashboard For Founders And ...  ...         NaN
# 2  'Story-driven online courses in game format fo...  ...         NaN
# 3                'Net Worth and Investments Tracker'  ...         NaN
# 4                             'Finance for Founders'  ...         NaN
#
# [5 rows x 20 columns]

# %%
del df['Unnamed: 19']

# %%
df
# Out:
#                                            description  ... Alexa Ranking
# 0    '#1 Social Justice Network: Civil Rights Tools...  ...          4.7m
# 1    'A Better Business Dashboard For Founders And ...  ...          2.3m
# 2    'Story-driven online courses in game format fo...  ...          3.5m
# 3                  'Net Worth and Investments Tracker'  ...        705.9k
# 4                               'Finance for Founders'  ...        297.3k
# ..                                                 ...  ...           ...
# 308  'Libris teaches children to read by reading bo...  ...             0
# 309  'Chisel Analytics provides an on demand analyt...  ...            3m
# 310  'Largest community-curated collection of natur...  ...             0
# 311  'Web and mobile app development using latest t...  ...        705.7k
# 312  'KOYA pairs kindness and connection to create ...  ...        247.4k
#
# [313 rows x 19 columns]

# %%
df.shape
# Out:
# (313, 19)

# %%
df.columns.values
# Out:
# array(['description', 'website', 'crunchbase_link', 'name',
#        'activity_level', 'market', 'products', 'revenue_through',
#        'founded_by', 'founded', 'place', 'team_members', 'launch_stage',
#        'revenue_stage', 'amount_raised', 'twitter_followers',
#        'percentile', 'pageviews', 'Alexa Ranking'], dtype=object)

# %%
df.dtypes
# Out:
# description          object
# website              object
# crunchbase_link      object
# name                 object
# activity_level       object
# market               object
# products             object
# revenue_through      object
# founded_by           object
# founded              object
# place                object
# team_members         object
# launch_stage         object
# revenue_stage        object
# amount_raised        object
# twitter_followers    object
# percentile           object
# pageviews            object
# Alexa Ranking        object
# dtype: object

# %%
import numpy as np

# select numeric columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

# select non numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# []
# ['description' 'website' 'crunchbase_link' 'name' 'activity_level'
#  'market' 'products' 'revenue_through' 'founded_by' 'founded' 'place'
#  'team_members' 'launch_stage' 'revenue_stage' 'amount_raised'
#  'twitter_followers' 'percentile' 'pageviews' 'Alexa Ranking']

# %%
#percentage of null values in each column
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# description - 0%
# website - 0%
# crunchbase_link - 0%
# name - 0%
# activity_level - 0%
# market - 0%
# products - 0%
# revenue_through - 0%
# founded_by - 19%
# founded - 0%
# place - 0%
# team_members - 0%
# launch_stage - 0%
# revenue_stage - 0%
# amount_raised - 0%
# twitter_followers - 0%
# percentile - 0%
# pageviews - 0%
# Alexa Ranking - 0%

# %%
df['revenue_stage'].unique()
# Out:
# array(['Pre', 'Post', 'Publicly'], dtype=object)

# %%
#changing the string values in 'revenue_stage' to numeric value
df['revenue_stage'].replace({"Pre": "1", "Post": "2", "Publicly": "3"}, inplace=True)

# %%
df['launch_stage'].replace({"51-100": "Publicly", "1": "Publicly"}, inplace=True)

# %%
df
# Out:
#                                            description  ... Alexa Ranking
# 0    '#1 Social Justice Network: Civil Rights Tools...  ...          4.7m
# 1    'A Better Business Dashboard For Founders And ...  ...          2.3m
# 2    'Story-driven online courses in game format fo...  ...          3.5m
# 3                  'Net Worth and Investments Tracker'  ...        705.9k
# 4                               'Finance for Founders'  ...        297.3k
# ..                                                 ...  ...           ...
# 308  'Libris teaches children to read by reading bo...  ...             0
# 309  'Chisel Analytics provides an on demand analyt...  ...            3m
# 310  'Largest community-curated collection of natur...  ...             0
# 311  'Web and mobile app development using latest t...  ...        705.7k
# 312  'KOYA pairs kindness and connection to create ...  ...        247.4k
#
# [313 rows x 19 columns]

# %%
df['launch_stage'].unique()
# Out:
# array(['Publicly', 'Pre', 'Privately'], dtype=object)

# %%
#changing the string values in 'launch_stage' to numeric value
df['launch_stage'].replace({"Pre": "1", "Privately": "2", "Publicly": "3"}, inplace=True)
df
# Out:
#                                            description  ... Alexa Ranking
# 0    '#1 Social Justice Network: Civil Rights Tools...  ...          4.7m
# 1    'A Better Business Dashboard For Founders And ...  ...          2.3m
# 2    'Story-driven online courses in game format fo...  ...          3.5m
# 3                  'Net Worth and Investments Tracker'  ...        705.9k
# 4                               'Finance for Founders'  ...        297.3k
# ..                                                 ...  ...           ...
# 308  'Libris teaches children to read by reading bo...  ...             0
# 309  'Chisel Analytics provides an on demand analyt...  ...            3m
# 310  'Largest community-curated collection of natur...  ...             0
# 311  'Web and mobile app development using latest t...  ...        705.7k
# 312  'KOYA pairs kindness and connection to create ...  ...        247.4k
#
# [313 rows x 19 columns]

# %%
df['products'].unique()
# Out:
# array(["'mobile app', 'service', 'web app'", "'web app'",
#        "'service', 'web app'", "'mobile app', 'service'", "'other'",
#        "'desktop app'", "'mobile app', 'web app'",
#        "'desktop app', 'mobile app', 'service', 'web app'",
#        "'mobile app'", "'other', 'desktop app', 'mobile app', 'web app'",
#        "'desktop app', 'web app'",
#        "'desktop app', 'mobile app', 'web app'", "'other', 'service'",
#        "'service'", "'other', 'service', 'web app'",
#        "'desktop app', 'service', 'web app'",
#        "'desktop app', 'mobile app'", "'physical goods', 'service'",
#        "'other', 'mobile app', 'service'", "'hardware'",
#        "'desktop app', 'service'",
#        "'desktop app', 'hardware', 'mobile app', 'service', 'web app'",
#        "'desktop app', 'hardware', 'service', 'web app'",
#        "'physical goods'", "'gaming', 'startups', 'software dev'",
#        "'other', 'mobile app', 'web app'",
#        "'desktop app', 'mobile app', 'service'",
#        "'other', 'desktop app', 'mobile app', 'service', 'web app'",
#        "'other', 'web app'", "'advertising'",
#        "'desktop app', 'hardware', 'mobile app', 'physical goods', 'service', 'web app'"],
#       dtype=object)

# %%
#This is the only column with NaN values, as these are real data values, didn't deal with NaN value.
df['founded_by'].unique()
# Out:
# array(['"Wa\'il Ashshowwaf", \'Justin A. Moore, ESQ.\', \'Rooam\'',
#        "'Daren@hey.com \\U0001f9ed'", "'Umnazia'",
#        "'Hussein Yahfoufi 🌟', 'Jessica (Jones) Yahfoufi'",
#        "'Tiffany Wong'", "'Chai Meet Biscuit'", nan, "'Oliver Grand'",
#        "'Global Fun'", "'Lean Power'", "'True Reply', 'oneQube'",
#        "'SocialMeep'", "'DesignerUp'", "'strategynode', 'Tyler J. Fox'",
#        "'Rad Padre', 'Freedom TV+ (Streaming on Roku & Amazon Fire TV)'",
#        "'VyrocApp'", "'Chris Beaman'", "'Snipply'", "'Angshuman Guha'",
#        "'agreemint'", "'Shake SDK'", "'Deskle'",
#        "'Shannon S', 'PayLoadz'", "'Mooditude App'", "'WatchTowerHQ'",
#        "'nullbox'", "'Email2Go'", "'Nishant', 'DigsFact', 'DigsFact LLC'",
#        "'Smartbate'", "'Ryan Hitchler'", "'tribe'", "'Malcolm Woods'",
#        "'Bryan Grey'", "'GoCRM'", "'David Wilmot'", "'Fahim Karim'",
#        "'poolmarketing'", "'Alex Edmonds🎙️'", "'Memorize'",
#        "'Cenports Commerce'", "'Fortunesoft'", "'Keeper Tax'",
#        '"Wa\'il Ashshowwaf", \'Stuck in the Sand\', \'Rooam\'',
#        "'Kirill Rebrov', 'Natalia Tsvetkova'", "'Basam Alasaly'",
#        "'Trevor Lohrbeer'", "'Mark Milbourne', 'Tallie'", "'Time Doctor'",
#        "'mHospital'", "'Postal.io', 'TextRecruit'", "'Kirill'",
#        "'MediFind'", "'Sportlo'", "'RestCase'", "'Starkflow'",
#        "'Martin Welker', 'Peter Oehler', 'Lookeen Desktop Search'",
#        "'Waitwhile'", "'Namesnack', 'Namesnack'", "'Sonraí Security'",
#        "'KeepSolid Goals', 'KeepSolid Inc.', 'Vasiliy Ivanov'",
#        "'Namesnack', 'PlanSnack'", "'Chaine'", "'Polygon.io'",
#        "'Brandly'", "'Gignav', 'Om Soni'",
#        "'Inleven App', 'Alberto Sustiel,'", "'DailyRemote'",
#        "'Russell Smith 🚀\\U0001f9d0', 'Fred Stevens-Smith'",
#        "'James Peel'", "'Kristen Ruby', 'RubyMediaGroup®'", "'Bookshlf'",
#        "'PostPanda'", "'Vladimir Lugovsky', 'Konstantin Danovsky'",
#        "'HomeFlow'", "'CloudLead.co'", "'Avvnue Inc'", "'WorcLab'",
#        "'Pigly'", "'Cereo'", "'Blueground'", "'Peoplebox'",
#        "'Rebeliance'", "'Michael Leigeber'", "'Apipheny'",
#        "'Mark Thomas'", "'SlideTeam'", "'Cloud Aress'", "'Christian V'",
#        "'MangoCRM'", "'Jason Chen', 'Richard Lam', 'Dwink'",
#        "'Rohan Hall'", "'Bizooy.com'", "'Product School'", "'evntures'",
#        "'Christopher Jakeson'", "'Majd M', 'Korash'", "'Joshua Waller'",
#        "'Tom Medema', 'Bloomon'", "'Alexander Richey'", "'AnyLog'",
#        "'Gaetan Ekoondo Helsen'", "'Lofty AI'",
#        "'Kamil Rudnicki', 'HeySpace'", "'𝑨𝒏𝒅𝒓𝒆𝒘 𝑱𝒆𝒓𝒏𝒊𝒈𝒂𝒏'",
#        "'Modalyst - Dropshipping Software'", "'Narrow Security'",
#        "'OneGold', 'APMEX', 'Sprott Asset Management'",
#        "'Sib Mahapatra', 'Greg Hayes', 'Verity Sylvester', 'Redfin', 'Breather', 'redfin'",
#        "'Sebastian Hovv'", "'Funnelfly'", "'Lyndsey Harper MD FACOG'",
#        "'Bryan Starbuck'", "'UserGuiding 🌊'", "'Algovest'",
#        "'Alexey Khitrov'", "'Palm'", "'Axel DeAngelis'",
#        "'Pastryy_design'", "'Rania Reda'", "'Shoanak Mallapurkar'",
#        "'Santo 🏡', 'MailMyPrescriptions.com'", "'wappier'",
#        "'EugeneMachine'", "'Saketa'",
#        "'Thibaud CLEMENT', 'Noémie Clément'", "'Bankey'", "'BasicAI'",
#        "'CloudApp'", "'Splash Q2C (Quote To Cash) Cloud'", "'James Nunn'",
#        "'Zenus Bank'",
#        "'Eran Eyal', 'lance', 'Springleap', 'Forbes Technology Council'",
#        "'Intro30'", "'Passbase'", "'Cetalingua Project'", "'Qanairy'",
#        "'Kugadi'", "'G Riar'", "'Gjergj Camaj'", "'Abord'", "'bokksu'",
#        "'Neil Hoyne'", '"Michael A\'Burzynski"',
#        "'Shahar Chaskelevitch', 'Tomer Barnea', 'Dima Grossman', 'Aviram Kadosh'",
#        "'Lean On Me'", "'Sunglass Innovation®'", "'ZIRTUE'", "'Ziggeo'",
#        "'Tapyness®'", "'Supercode | QR Code Generator'",
#        "'b2b', 'subscription'", "'Dan B. Lee'", "'Dvorah Graeser'",
#        "'Uulala'", "'Entriwise'", "'UniBit'",
#        "'👋 Arjun Rai | 👉$49+/year at HelloWoofy.com'", "'Lazarus'",
#        "'Wrangle'",
#        "'SaaS Startup Kit', 'Keeni Procedures', 'Aurora Forecast', 'Keeni Space Operating Procedures'",
#        "'Kaleb Jordan Wilson', 'Paroma Indilo'", "'Lead Geeks'", "'Piio'",
#        "'Daniel Levi'", "'Danilka'", "'breachbits', 'John L.'",
#        "'PlaybookUX', 'Personal Zen'", "'Genau Junior'", "'Nynedge'",
#        "'Lillian 🏗♻️', 'Yooney 🏗', 'Block Notary', 'Microwork', 'POA Network'",
#        "'ColdCrowd'", "'MyCali Designs'", "'Testsigma'",
#        "'Andriy Bas', 'Dima Kovalenko'",
#        "'Henry Yoshida, CFP®', 'Thomas Young', 'Richard Dude Jr.'",
#        "'Darshan Patil'", "'ScopeStack', 'Jon Scott'", "'Peter Bailis'",
#        "'Josh Maurer', 'Todd'", "'Bogdan Glushko'", "'Alex'",
#        "'Keeni', 'SpotTune', 'TUNE', 'Eat Tune', 'a-tune', 'Aurora Forecast'",
#        "'Margaret'", "'Lolli 🍭', '§Alex Adelman 🍭', '§matt 🍭'",
#        "'zigpoll', 'JQBX'", "'Colorful Dots, LLC', 'Eric David Smith'",
#        "'Try Storied'", "'Zach Dunn', 'Sam Dunn'",
#        "'Maria E. Marzo, DDS'", "'MKTR.AI'", "'Applewild School'",
#        "'Jerry Franklin'", "'Rohit | rgoyal.eth 🦇🔊', 'PaxPlay'",
#        "'Carlo Tapia'", "'Shane Evans'", "'Brabazon Law Office'",
#        "'David Gasparyan'", "'StreamerCloud.com', 'Gamer Ninja'",
#        "'Parker Amos'", "'Asad', 'Jay Singh'", "'Alamo Insurance'",
#        "'b2b', 'other'",
#        "'Soufian Idriss', 'Dana Panzer', 'Clarity', 'Clarity Money'",
#        "'Paul Muret'", "'Steve Moberley'", "'Coinediction'",
#        "'Vistar Singh'", "'Statful'",
#        "'Emily Brackett, President of Visible Logic', 'Emily Brackett'",
#        "'deposit Bitcoin'", "'Deposit PayPal'", "'Zlatko', 'Tako Agency'",
#        "'getdmarcly'", "'BizTT'", "'Gentreo'", "'Joe cordes'",
#        "'Elliot Kirstein'", "'Infinity'", "'BTB Construction'",
#        "'Young Chung'", "'Kounsel'", "'DeWitt and DeWitt'", "'UniPapers'",
#        "'Riley Moore'", "'PhishFeed'", "'Joshua A. Davis, Esq. ⚖️⚗️'",
#        "'JournalFlow'", "'Kurosh Hashemi'", "'Jiggles TV'",
#        "'The Social Cafe'", "'Chris Tung', 'Huttle'", "'Jon Strom'",
#        "'Justin Hunter'", "'Alex Jae Mitchell'", "'Dennis Warfield'",
#        "'SVGator'", "'Tunniverse', 'Mark Suarkeo'", "'Suddan S S'",
#        "'Epixel MLM Software'", "'Alex Bouaziz', 'Shuooo'",
#        "'PromSocial'", "'Summit Mindfulness'", "'librisapp'",
#        "'Chisel Analytics'", "'Masha'",
#        "'Stefan Smiljkovic', 'Jelena Jovanovic'", "'u✪ſ', 'Adidas'"],
#       dtype=object)

# %%
df['activity_level'].unique()
# Out:
# array(['High company activity detected', 'Low company activity detected',
#        'Sourced by Startup Tracker',
#        'No recent company activity detected', "'Instabug'",
#        "'Simple Quarters - We Buy Houses Indianapolis'"], dtype=object)

# %%
df['activity_level'].replace({"High company activity detected": "1", "Low company activity detected": "2", "Sourced by Startup Tracker": "3", "No recent company activity detected": "4", "Instabug": "5", "Simple Quarters - We Buy Houses Indianapolis": "6"}, inplace=True)

# %%
df
# Out:
#                                            description  ... Alexa Ranking
# 0    '#1 Social Justice Network: Civil Rights Tools...  ...          4.7m
# 1    'A Better Business Dashboard For Founders And ...  ...          2.3m
# 2    'Story-driven online courses in game format fo...  ...          3.5m
# 3                  'Net Worth and Investments Tracker'  ...        705.9k
# 4                               'Finance for Founders'  ...        297.3k
# ..                                                 ...  ...           ...
# 308  'Libris teaches children to read by reading bo...  ...             0
# 309  'Chisel Analytics provides an on demand analyt...  ...            3m
# 310  'Largest community-curated collection of natur...  ...             0
# 311  'Web and mobile app development using latest t...  ...        705.7k
# 312  'KOYA pairs kindness and connection to create ...  ...        247.4k
#
# [313 rows x 19 columns]

# %%
#removing ~ sign from the pageviews column
df['pageviews'] = df['pageviews'].map(lambda x: x.lstrip('~').rstrip('aAbBcC'))

# %%
#removing $ sign from the amount_raised column
df['amount_raised'] = df['amount_raised'].map(lambda x: x.lstrip('$').rstrip('aAbBcC'))

# %%
#removing single quotes from the string values from the columns
for i, col in enumerate(df.columns):
    df.iloc[:, i] = df.iloc[:, i].str.replace("'", "")

# %%
df
# Out:
#                                            description  ... Alexa Ranking
# 0    #1 Social Justice Network: Civil Rights Tools,...  ...          4.7m
# 1    A Better Business Dashboard For Founders And C...  ...          2.3m
# 2    Story-driven online courses in game format for...  ...          3.5m
# 3                    Net Worth and Investments Tracker  ...        705.9k
# 4                                 Finance for Founders  ...        297.3k
# ..                                                 ...  ...           ...
# 308  Libris teaches children to read by reading boo...  ...             0
# 309  Chisel Analytics provides an on demand analyti...  ...            3m
# 310  Largest community-curated collection of natura...  ...             0
# 311  Web and mobile app development using latest te...  ...        705.7k
# 312  KOYA pairs kindness and connection to create p...  ...        247.4k
#
# [313 rows x 19 columns]
